# %%
cd /content/drive/MyDrive/GTS-main/code/XLnet/
# Out:
# /content/drive/MyDrive/GTS-main/code/XLnet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install flask_ngrok

# %%
# !pip install transformers==3

# %%
# !python main.py --task pair --mode train --dataset res14
# Out:
# 2021-06-23 17:47:59.090267: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 630/630 [00:43<00:00, 14.45it/s]
# Aspect term	P:0.70305	R:0.56996	F1:0.62955
# Opinion term	P:0.80464	R:0.49091	F1:0.60979
# pair	P:0.70950	R:0.22320	F1:0.33957
#
# Epoch:1
# 100% 630/630 [00:44<00:00, 14.04it/s]
# Aspect term	P:0.74148	R:0.76132	F1:0.75127
# Opinion term	P:0.79277	R:0.66465	F1:0.72308
# pair	P:0.68915	R:0.41301	F1:0.51648
#
# Epoch:2
# 100% 630/630 [00:44<00:00, 14.04it/s]
# Aspect term	P:0.76840	R:0.73045	F1:0.74895
# Opinion term	P:0.80645	R:0.75758	F1:0.78125
# pair	P:0.72704	R:0.50088	F1:0.59313
#
# Epoch:3
# 100% 630/630 [00:44<00:00, 14.03it/s]
# Aspect term	P:0.75048	R:0.79835	F1:0.77368
# Opinion term	P:0.79568	R:0.81818	F1:0.80677
# pair	P:0.68922	R:0.57293	F1:0.62572
#
# Epoch:4
# 100% 630/630 [00:44<00:00, 14.02it/s]
# Aspect term	P:0.74638	R:0.84774	F1:0.79383
# ...

# %%
# !python main.py --task triplet --mode train --dataset res14
# Out:
# 2021-06-28 14:25:17.703136: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 630/630 [01:12<00:00,  8.73it/s]
# Aspect term	P:0.71315	R:0.36831	F1:0.48575
# Opinion term	P:0.71963	R:0.15556	F1:0.25581
# triplet	P:0.66071	R:0.06503	F1:0.11840
#
# Epoch:1
# 100% 630/630 [01:13<00:00,  8.56it/s]
# Aspect term	P:0.66184	R:0.75309	F1:0.70452
# Opinion term	P:0.73589	R:0.65859	F1:0.69510
# triplet	P:0.56707	R:0.32689	F1:0.41472
#
# Epoch:2
# 100% 630/630 [01:13<00:00,  8.55it/s]
# Aspect term	P:0.69643	R:0.80247	F1:0.74570
# Opinion term	P:0.74206	R:0.80202	F1:0.77087
# triplet	P:0.60820	R:0.46924	F1:0.52976
#
# Epoch:3
# 100% 630/630 [01:13<00:00,  8.56it/s]
# Aspect term	P:0.70054	R:0.79424	F1:0.74446
# Opinion term	P:0.77609	R:0.82626	F1:0.80039
# triplet	P:0.61753	R:0.54482	F1:0.57890
#
# Epoch:4
# 100% 630/630 [01:13<00:00,  8.55it/s]
# Aspect term	P:0.71841	R:0.81893	F1:0.76538
# ...

# %%
# !python main.py --task pair --mode train --dataset res16
# Out:
# 2021-06-24 13:35:41.854351: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Downloading: 100% 798k/798k [00:00<00:00, 2.04MB/s]
# Downloading: 100% 760/760 [00:00<00:00, 517kB/s]
# Epoch:0
# 100% 432/432 [01:18<00:00,  5.51it/s]
# Aspect term	P:0.70000	R:0.28188	F1:0.40191
# Opinion term	P:0.73750	R:0.36086	F1:0.48460
# pair	P:0.65217	R:0.13081	F1:0.21792
#
# Epoch:1
# 100% 432/432 [01:18<00:00,  5.48it/s]
# Aspect term	P:0.71691	R:0.65436	F1:0.68421
# Opinion term	P:0.73482	R:0.70336	F1:0.71875
# pair	P:0.71739	R:0.38372	F1:0.50000
#
# Epoch:2
# 100% 432/432 [01:18<00:00,  5.47it/s]
# Aspect term	P:0.72364	R:0.66779	F1:0.69459
# Opinion term	P:0.77256	R:0.65443	F1:0.70861
# pair	P:0.73711	R:0.41570	F1:0.53160
#
# Epoch:3
# 100% 432/432 [01:18<00:00,  5.49it/s]
# Aspect term	P:0.74648	R:0.71141	F1:0.72852
# Opinion term	P:0.77500	R:0.75841	F1:0.76662
# pair	P:0.72685	R:0.45640	F1:0.56071
#
# Epoch:4
# ...

# %%
# !python main.py --task triplet --mode train --dataset res16
# Out:
# 2021-06-24 17:42:56.493410: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Downloading: 100% 798k/798k [00:00<00:00, 871kB/s]
# Downloading: 100% 760/760 [00:00<00:00, 660kB/s]
# Epoch:0
# 100% 432/432 [01:18<00:00,  5.52it/s]
# Aspect term	P:0.67754	R:0.62752	F1:0.65157
# Opinion term	P:0.63320	R:0.50153	F1:0.55973
# triplet	P:0.55280	R:0.25872	F1:0.35248
#
# Epoch:1
# 100% 432/432 [01:18<00:00,  5.49it/s]
# Aspect term	P:0.65057	R:0.76846	F1:0.70462
# Opinion term	P:0.72183	R:0.62691	F1:0.67103
# triplet	P:0.49621	R:0.38081	F1:0.43092
#
# Epoch:2
# 100% 432/432 [01:18<00:00,  5.49it/s]
# Aspect term	P:0.67500	R:0.81544	F1:0.73860
# Opinion term	P:0.76825	R:0.74006	F1:0.75389
# triplet	P:0.53395	R:0.50291	F1:0.51796
#
# Epoch:3
# 100% 432/432 [01:18<00:00,  5.49it/s]
# Aspect term	P:0.69859	R:0.83221	F1:0.75957
# Opinion term	P:0.74128	R:0.77982	F1:0.76006
# triplet	P:0.51958	R:0.57849	F1:0.54746
#
# Epoch:4
# ...

# %%
# !python main.py --task pair --mode train --dataset res15
# Out:
# 2021-06-25 06:58:45.326214: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Downloading: 100% 798k/798k [00:00<00:00, 2.34MB/s]
# Downloading: 100% 760/760 [00:00<00:00, 733kB/s]
# Epoch:0
# 100% 302/302 [00:54<00:00,  5.53it/s]
# Aspect term	P:0.33333	R:0.00976	F1:0.01896
# Opinion term	P:0.60000	R:0.04018	F1:0.07531
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 302/302 [00:55<00:00,  5.49it/s]
# Aspect term	P:0.68468	R:0.37073	F1:0.48101
# Opinion term	P:0.74684	R:0.26339	F1:0.38944
# pair	P:0.54717	R:0.12236	F1:0.20000
#
# Epoch:2
# 100% 302/302 [00:55<00:00,  5.45it/s]
# Aspect term	P:0.71585	R:0.63902	F1:0.67526
# Opinion term	P:0.72789	R:0.47768	F1:0.57682
# pair	P:0.61111	R:0.27848	F1:0.38261
#
# Epoch:3
# 100% 302/302 [00:55<00:00,  5.47it/s]
# Aspect term	P:0.75410	R:0.67317	F1:0.71134
# Opinion term	P:0.73134	R:0.65625	F1:0.69176
# pair	P:0.65563	R:0.41772	F1:0.51031
#
# Epoch:4
# ...

# %%
# !python main.py --task triplet --mode train --dataset res15
# Out:
# 2021-06-25 09:01:34.245221: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 302/302 [00:55<00:00,  5.46it/s]
# Aspect term	P:0.51163	R:0.10732	F1:0.17742
# Opinion term	P:0.77500	R:0.13839	F1:0.23485
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 302/302 [00:55<00:00,  5.40it/s]
# Aspect term	P:0.70625	R:0.55122	F1:0.61918
# Opinion term	P:0.71654	R:0.40625	F1:0.51852
# triplet	P:0.61111	R:0.04641	F1:0.08627
#
# Epoch:2
# 100% 302/302 [00:56<00:00,  5.38it/s]
# Aspect term	P:0.69565	R:0.70244	F1:0.69903
# Opinion term	P:0.71186	R:0.56250	F1:0.62843
# triplet	P:0.57143	R:0.28692	F1:0.38202
#
# Epoch:3
# 100% 302/302 [00:56<00:00,  5.37it/s]
# Aspect term	P:0.72277	R:0.71220	F1:0.71744
# Opinion term	P:0.74372	R:0.66071	F1:0.69976
# triplet	P:0.64602	R:0.30802	F1:0.41714
#
# Epoch:4
# 100% 302/302 [00:56<00:00,  5.39it/s]
# Aspect term	P:0.73934	R:0.76098	F1:0.75000
# ...

# %%
# !python main.py --task pair --mode train --dataset lap14
# Out:
# 2021-06-25 10:45:57.983679: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 450/450 [01:19<00:00,  5.63it/s]
# Aspect term	P:0.54545	R:0.14502	F1:0.22912
# Opinion term	P:0.76119	R:0.16346	F1:0.26913
# pair	P:0.43750	R:0.01842	F1:0.03535
#
# Epoch:1
# 100% 450/450 [01:20<00:00,  5.56it/s]
# Aspect term	P:0.67347	R:0.59819	F1:0.63360
# Opinion term	P:0.69545	R:0.49038	F1:0.57519
# pair	P:0.63830	R:0.23684	F1:0.34549
#
# Epoch:2
# 100% 450/450 [01:20<00:00,  5.56it/s]
# Aspect term	P:0.70000	R:0.69789	F1:0.69894
# Opinion term	P:0.73913	R:0.59936	F1:0.66195
# pair	P:0.69588	R:0.35526	F1:0.47038
#
# Epoch:3
# 100% 450/450 [01:20<00:00,  5.56it/s]
# Aspect term	P:0.70286	R:0.74320	F1:0.72247
# Opinion term	P:0.74368	R:0.66026	F1:0.69949
# pair	P:0.69136	R:0.44211	F1:0.53933
#
# Epoch:4
# 100% 450/450 [01:21<00:00,  5.55it/s]
# Aspect term	P:0.71976	R:0.73716	F1:0.72836
# ...

# %%
# !python main.py --task triplet --mode train --dataset lap14
# Out:
# 2021-06-25 19:14:14.089242: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Downloading: 100% 798k/798k [00:00<00:00, 1.49MB/s]
# Downloading: 100% 760/760 [00:00<00:00, 575kB/s]
# Epoch:0
# 100% 450/450 [00:49<00:00,  9.08it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:1.00000	R:0.00321	F1:0.00639
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 450/450 [00:50<00:00,  8.96it/s]
# Aspect term	P:0.62814	R:0.37764	F1:0.47170
# Opinion term	P:0.64773	R:0.18269	F1:0.28500
# triplet	P:0.55000	R:0.02895	F1:0.05500
#
# Epoch:2
# 100% 450/450 [00:50<00:00,  8.91it/s]
# Aspect term	P:0.65274	R:0.75529	F1:0.70028
# Opinion term	P:0.65546	R:0.50000	F1:0.56727
# triplet	P:0.57364	R:0.19474	F1:0.29077
#
# Epoch:3
# 100% 450/450 [00:50<00:00,  8.90it/s]
# Aspect term	P:0.70058	R:0.72810	F1:0.71407
# Opinion term	P:0.65789	R:0.64103	F1:0.64935
# triplet	P:0.50865	R:0.38684	F1:0.43946
#
# Epoch:4
# ...

# %%
# !python main.py --task triplet --mode train --dataset res14
# Out:
# 2021-07-14 20:43:28.326701: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 630/630 [00:43<00:00, 14.38it/s]
# Aspect term	P:0.68580	R:0.46708	F1:0.55569
# Opinion term	P:0.71633	R:0.50505	F1:0.59242
# triplet	P:0.64336	R:0.16169	F1:0.25843
#
# Epoch:1
# 100% 630/630 [00:45<00:00, 13.99it/s]
# Aspect term	P:0.65436	R:0.80247	F1:0.72089
# Opinion term	P:0.71193	R:0.78384	F1:0.74615
# triplet	P:0.49886	R:0.38489	F1:0.43452
#
# Epoch:2
# 100% 630/630 [00:45<00:00, 13.92it/s]
# Aspect term	P:0.70384	R:0.79218	F1:0.74540
# Opinion term	P:0.74212	R:0.80808	F1:0.77369
# triplet	P:0.55098	R:0.44640	F1:0.49320
#
# Epoch:3
# 100% 630/630 [00:45<00:00, 13.95it/s]
# Aspect term	P:0.73048	R:0.80864	F1:0.76758
# Opinion term	P:0.76749	R:0.82020	F1:0.79297
# triplet	P:0.62445	R:0.50264	F1:0.55696
#
# Epoch:4
# 100% 630/630 [00:45<00:00, 13.99it/s]
# Aspect term	P:0.75723	R:0.80864	F1:0.78209
# ...

# %%
# !python main.py --task triplet --mode train --dataset wine226
# Out:
# 2021-07-28 17:49:17.199312: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Downloading: 100% 798k/798k [00:00<00:00, 8.02MB/s]
# Traceback (most recent call last):
#   File "main.py", line 165, in <module>
#     train(args)
#   File "main.py", line 27, in train
#     instances_train = load_data_instances(train_sentence_packs, args)
#   File "/content/drive/MyDrive/GTS-main/code/XLnet/data.py", line 156, in load_data_instances
#     instances.append(Instance(tokenizer, sentence_pack, args))
#   File "/content/drive/MyDrive/GTS-main/code/XLnet/data.py", line 120, in __init__
#     start = self.token_range[l][0]
# IndexError: list index out of range

# %%
cd /content/drive/MyDrive/GTS-main/code/BertModel
# Out:
# /content/drive/MyDrive/GTS-main/code/BertModel

# %%
# !python main.py --task pair --mode train --dataset wine226
# Out:
# 2021-07-29 09:07:50.746801: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 94/94 [00:27<00:00,  3.48it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 94/94 [00:27<00:00,  3.46it/s]
# Aspect term	P:0.68421	R:0.10569	F1:0.18310
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 94/94 [00:27<00:00,  3.48it/s]
# Aspect term	P:0.71759	R:0.63008	F1:0.67100
# Opinion term	P:0.73438	R:0.71212	F1:0.72308
# pair	P:0.58537	R:0.34657	F1:0.43537
#
# Epoch:3
# 100% 94/94 [00:27<00:00,  3.47it/s]
# Aspect term	P:0.76500	R:0.62195	F1:0.68610
# Opinion term	P:0.77273	R:0.70833	F1:0.73913
# pair	P:0.73427	R:0.37906	F1:0.50000
#
# Epoch:4
# 100% 94/94 [00:27<00:00,  3.47it/s]
# Aspect term	P:0.76238	R:0.62602	F1:0.68750
# ...

# %%
# !python main.py --task triplet --mode train --dataset wine226
# Out:
# 2021-07-29 16:27:29.580992: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 94/94 [00:27<00:00,  3.38it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 94/94 [00:27<00:00,  3.37it/s]
# Aspect term	P:0.94118	R:0.06504	F1:0.12167
# Opinion term	P:1.00000	R:0.01515	F1:0.02985
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 94/94 [00:27<00:00,  3.37it/s]
# Aspect term	P:0.74178	R:0.64228	F1:0.68845
# Opinion term	P:0.81818	R:0.57955	F1:0.67849
# triplet	P:0.71014	R:0.17690	F1:0.28324
#
# Epoch:3
# 100% 94/94 [00:27<00:00,  3.37it/s]
# Aspect term	P:0.68635	R:0.75610	F1:0.71954
# Opinion term	P:0.68571	R:0.72727	F1:0.70588
# triplet	P:0.62759	R:0.32852	F1:0.43128
#
# Epoch:4
# 100% 94/94 [00:27<00:00,  3.37it/s]
# Aspect term	P:0.69963	R:0.77642	F1:0.73603
# ...

# %%
cd /content/drive/MyDrive/GTS-main/code/XLnet/
# Out:
# /content/drive/MyDrive/GTS-main/code/XLnet

# %%
# !python main.py --task pair --mode train --dataset wine226
# Out:
# 2021-07-29 13:24:10.089908: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 376/376 [01:06<00:00,  5.68it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 376/376 [01:06<00:00,  5.65it/s]
# Aspect term	P:0.70000	R:0.05691	F1:0.10526
# Opinion term	P:1.00000	R:0.00758	F1:0.01504
# pair	P:1.00000	R:0.00361	F1:0.00719
#
# Epoch:2
# 100% 376/376 [01:06<00:00,  5.64it/s]
# Aspect term	P:0.66839	R:0.52439	F1:0.58770
# Opinion term	P:0.87500	R:0.21212	F1:0.34146
# pair	P:0.81481	R:0.15884	F1:0.26586
#
# Epoch:3
# 100% 376/376 [01:06<00:00,  5.65it/s]
# Aspect term	P:0.65854	R:0.65854	F1:0.65854
# Opinion term	P:0.77419	R:0.45455	F1:0.57279
# pair	P:0.72034	R:0.30686	F1:0.43038
#
# Epoch:4
# 100% 376/376 [01:06<00:00,  5.65it/s]
# Aspect term	P:0.61842	R:0.76423	F1:0.68364
# ...

# %%
# !python main.py --task triplet --mode train --dataset wine226
# Out:
# 2021-07-30 05:20:58.736008: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Downloading: 100% 798k/798k [00:00<00:00, 860kB/s]
# Downloading: 100% 760/760 [00:00<00:00, 689kB/s]
# Epoch:0
# 100% 376/376 [01:08<00:00,  5.51it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 376/376 [01:08<00:00,  5.49it/s]
# Aspect term	P:0.38095	R:0.03252	F1:0.05993
# Opinion term	P:0.91667	R:0.04167	F1:0.07971
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 376/376 [01:08<00:00,  5.49it/s]
# Aspect term	P:0.78512	R:0.38618	F1:0.51771
# Opinion term	P:0.80597	R:0.20455	F1:0.32628
# triplet	P:0.61111	R:0.03971	F1:0.07458
#
# Epoch:3
# 100% 376/376 [01:08<00:00,  5.48it/s]
# Aspect term	P:0.71782	R:0.58943	F1:0.64732
# Opinion term	P:0.77193	R:0.50000	F1:0.60690
# triplet	P:0.63559	R:0.27076	F1:0.37975
#
# Epoch:4
# ...

# %%
# !python main.py --task triplet --mode predict --dataset res14
# Out:
# mode: predict
# Input Sentence:  the wine is youthfully wrapped in its full-bodied boldness.
# --------prediction of Triplet Start---------
# [{'Aspect-Span': ['wine'], 'Opinion-Span': ['youthfully', 'wrapped'], 'Sentiment': ['positive']}]
# -------------prediction of Triplet Ends-------

# %%
# !pip install pyngrok

# %%
! ngrok authtoken 1wwHZWaGAouhG8pzfJcbidE2gaN_7dUskopdQZodNVY2VH5dX
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
from pyngrok import ngrok
api = ngrok.connect(port='5000')

# %%
ngrok.kill()

# %%
# !python app.py --task triplet --mode predict1 --dataset res14
# Out:
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# The current process just got forked. Disabling parallelism to avoid deadlocks...
# To disable this warning, please explicitly set TOKENIZERS_PARALLELISM=(true | false)
#  * Running on http://94a6-104-198-103-122.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [14/Sep/2021 18:57:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Sep/2021 18:57:17] "GET /static/css/styles.css HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Sep/2021 18:57:17] "GET /static/8.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Sep/2021 18:57:19] "GET /favicon.ico HTTP/1.1" 404 -
# mode: predict
# Input Sentence:  This wine tastes amazing
# --------prediction of Triplet Start---------
# ...
