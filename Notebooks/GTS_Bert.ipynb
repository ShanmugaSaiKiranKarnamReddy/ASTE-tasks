# %%
pwd
# Out:
# '/content'

# %%
cd //content/drive/MyDrive/GTS-main/code/BertModel
# Out:
# /content/drive/MyDrive/GTS-main/code/BertModel

# %%
# !pip install transformers==3
# Out:
# Collecting transformers==3
#   Downloading transformers-3.0.0-py3-none-any.whl (754 kB)
#      |████████████████████████████████| 754 kB 6.9 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3) (4.62.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3) (21.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 53.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3) (1.19.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 71.8 MB/s
# Collecting tokenizers==0.8.0-rc4
#   Downloading tokenizers-0.8.0rc4-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 52.6 MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3) (2.4.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3) (1.15.0)
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.45 sentencepiece-0.1.96 tokenizers-0.8.0rc4 transformers-3.0.0

# %%
# !python main.py --task pair --mode train --dataset res14
# Out:
# 2021-04-06 14:04:32.519005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Epoch:0
# 100% 79/79 [01:16<00:00,  1.04it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.81643	R:0.34774	F1:0.48773
# Opinion term	P:0.86054	R:0.51111	F1:0.64132
# pair	P:0.89157	R:0.13005	F1:0.22699
#
# Epoch:2
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.78693	R:0.56996	F1:0.66110
# Opinion term	P:0.84483	R:0.79192	F1:0.81752
# pair	P:0.79600	R:0.34974	F1:0.48596
#
# Epoch:3
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.78016	R:0.82510	F1:0.80200
# Opinion term	P:0.74600	R:0.84848	F1:0.79395
# pair	P:0.78495	R:0.51318	F1:0.62062
#
# Epoch:4
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.81623	R:0.70370	F1:0.75580
# Opinion term	P:0.82195	R:0.80202	F1:0.81186
# pair	P:0.81957	R:0.47100	F1:0.59821
#
# Epoch:5
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.77895	R:0.76132	F1:0.77003
# Opinion term	P:0.82328	R:0.80000	F1:0.81148
# pair	P:0.75887	R:0.56415	F1:0.64718
#
# Epoch:6
# 100% 79/79 [01:17<00:00,  1.03it/s]
# Aspect term	P:0.79449	R:0.77160	F1:0.78288
# Opinion term	P:0.82661	R:0.82828	F1:0.82745
# pair	P:0.76940	R:0.60984	F1:0.68039
#
# Epoch:7
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.80638	R:0.77984	F1:0.79289
# Opinion term	P:0.83190	R:0.77980	F1:0.80501
# pair	P:0.78894	R:0.55185	F1:0.64943
#
# Epoch:8
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.80802	R:0.78807	F1:0.79792
# Opinion term	P:0.80120	R:0.80606	F1:0.80363
# pair	P:0.75171	R:0.57996	F1:0.65476
#
# Epoch:9
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.81524	R:0.72634	F1:0.76823
# Opinion term	P:0.80550	R:0.82828	F1:0.81673
# pair	P:0.76376	R:0.58524	F1:0.66269
#
# Epoch:10
# 100% 79/79 [01:17<00:00,  1.03it/s]
# Aspect term	P:0.77551	R:0.86008	F1:0.81561
# Opinion term	P:0.78938	R:0.87071	F1:0.82805
# pair	P:0.68833	R:0.72583	F1:0.70659
#
# Epoch:11
# 100% 79/79 [01:17<00:00,  1.03it/s]
# Aspect term	P:0.78435	R:0.84568	F1:0.81386
# Opinion term	P:0.79623	R:0.85253	F1:0.82341
# pair	P:0.72395	R:0.69596	F1:0.70968
#
# Epoch:12
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.77757	R:0.84156	F1:0.80830
# Opinion term	P:0.82495	R:0.82828	F1:0.82661
# pair	P:0.72439	R:0.68366	F1:0.70344
#
# Epoch:13
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.78090	R:0.85802	F1:0.81765
# Opinion term	P:0.81944	R:0.83434	F1:0.82683
# pair	P:0.74011	R:0.69069	F1:0.71455
#
# Epoch:14
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.77567	R:0.83951	F1:0.80632
# Opinion term	P:0.81213	R:0.83838	F1:0.82505
# pair	P:0.72678	R:0.70123	F1:0.71377
#
# Epoch:15
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.77672	R:0.83745	F1:0.80594
# Opinion term	P:0.83333	R:0.82828	F1:0.83080
# pair	P:0.73814	R:0.68366	F1:0.70985
#
# Epoch:16
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.78585	R:0.86831	F1:0.82502
# Opinion term	P:0.79096	R:0.84848	F1:0.81871
# pair	P:0.70745	R:0.70123	F1:0.70432
#
# Epoch:17
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.77256	R:0.88066	F1:0.82308
# Opinion term	P:0.74182	R:0.87071	F1:0.80112
# pair	P:0.63855	R:0.74517	F1:0.68775
#
# Epoch:18
# 100% 79/79 [01:17<00:00,  1.03it/s]
# Aspect term	P:0.79615	R:0.85185	F1:0.82306
# Opinion term	P:0.79323	R:0.85253	F1:0.82181
# pair	P:0.73443	R:0.70475	F1:0.71928
#
# Epoch:19
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.77323	R:0.85597	F1:0.81250
# Opinion term	P:0.82787	R:0.81616	F1:0.82197
# pair	P:0.73734	R:0.69069	F1:0.71325
#
# Epoch:20
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.79290	R:0.82716	F1:0.80967
# Opinion term	P:0.82574	R:0.84242	F1:0.83400
# pair	P:0.76190	R:0.67487	F1:0.71575
#
# Epoch:21
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.80972	R:0.82305	F1:0.81633
# Opinion term	P:0.82365	R:0.83030	F1:0.82696
# pair	P:0.74525	R:0.68893	F1:0.71598
#
# Epoch:22
# 100% 79/79 [01:17<00:00,  1.03it/s]
# Aspect term	P:0.80924	R:0.82922	F1:0.81911
# Opinion term	P:0.83004	R:0.84848	F1:0.83916
# pair	P:0.75139	R:0.71178	F1:0.73105
#
# Epoch:23
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.79769	R:0.85185	F1:0.82388
# Opinion term	P:0.81977	R:0.85455	F1:0.83680
# pair	P:0.71875	R:0.72759	F1:0.72314
#
# Epoch:24
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.79216	R:0.83128	F1:0.81124
# Opinion term	P:0.81980	R:0.83636	F1:0.82800
# pair	P:0.73743	R:0.69596	F1:0.71609
#
# Epoch:25
# 100% 79/79 [01:17<00:00,  1.03it/s]
# Aspect term	P:0.77632	R:0.84979	F1:0.81139
# Opinion term	P:0.81395	R:0.84848	F1:0.83086
# pair	P:0.71758	R:0.71002	F1:0.71378
#
# Epoch:26
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.76225	R:0.86420	F1:0.81003
# Opinion term	P:0.79511	R:0.85455	F1:0.82376
# pair	P:0.72152	R:0.70123	F1:0.71123
#
# Epoch:27
# 100% 79/79 [01:17<00:00,  1.03it/s]
# Aspect term	P:0.79127	R:0.85802	F1:0.82330
# Opinion term	P:0.80888	R:0.84646	F1:0.82725
# pair	P:0.73626	R:0.70650	F1:0.72108
#
# Epoch:28
# 100% 79/79 [01:17<00:00,  1.03it/s]
# Aspect term	P:0.80502	R:0.85802	F1:0.83068
# Opinion term	P:0.83665	R:0.84848	F1:0.84253
# pair	P:0.75614	R:0.70299	F1:0.72860
#
# Epoch:29
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.81474	R:0.84156	F1:0.82794
# Opinion term	P:0.81092	R:0.84040	F1:0.82540
# pair	P:0.75833	R:0.63972	F1:0.69399
#
# best epoch: 22	best dev pair f1: 0.73105
#
#
# Evaluation on testset:
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Aspect term	P:0.78065	R:0.85412	F1:0.81573
# Opinion term	P:0.81869	R:0.87204	F1:0.84452
# pair	P:0.72500	R:0.73232	F1:0.72864

# %%
# !python main.py --task pair --mode test --dataset res14
# Out:
# 2021-04-06 14:48:51.400591: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Evaluation on testset:
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Aspect term	P:0.78065	R:0.85412	F1:0.81573
# Opinion term	P:0.81869	R:0.87204	F1:0.84452
# pair	P:0.72500	R:0.73232	F1:0.72864

# %%
# !python main.py --task triplet --mode train --dataset res14
# Out:
# 2021-04-06 14:57:39.522474: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Epoch:0
# 100% 79/79 [01:09<00:00,  1.14it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 79/79 [01:16<00:00,  1.03it/s]
# Aspect term	P:0.61220	R:0.51646	F1:0.56027
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 79/79 [01:17<00:00,  1.01it/s]
# Aspect term	P:0.79196	R:0.68930	F1:0.73707
# Opinion term	P:0.79870	R:0.74545	F1:0.77116
# triplet	P:0.53365	R:0.19508	F1:0.28571
#
# Epoch:3
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.76265	R:0.80658	F1:0.78400
# Opinion term	P:0.77664	R:0.76566	F1:0.77111
# triplet	P:0.63782	R:0.34974	F1:0.45176
#
# Epoch:4
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.78710	R:0.75309	F1:0.76972
# Opinion term	P:0.80916	R:0.64242	F1:0.71622
# triplet	P:0.65158	R:0.25308	F1:0.36456
#
# Epoch:5
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.78323	R:0.78807	F1:0.78564
# Opinion term	P:0.81481	R:0.71111	F1:0.75944
# triplet	P:0.71617	R:0.38137	F1:0.49771
#
# Epoch:6
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.79654	R:0.75720	F1:0.77637
# Opinion term	P:0.83444	R:0.76364	F1:0.79747
# triplet	P:0.75873	R:0.42004	F1:0.54072
#
# Epoch:7
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.79116	R:0.81070	F1:0.80081
# Opinion term	P:0.80113	R:0.86263	F1:0.83074
# triplet	P:0.70892	R:0.53076	F1:0.60704
#
# Epoch:8
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.77132	R:0.87449	F1:0.81967
# Opinion term	P:0.76588	R:0.85253	F1:0.80688
# triplet	P:0.66116	R:0.56239	F1:0.60779
#
# Epoch:9
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.80196	R:0.84156	F1:0.82129
# Opinion term	P:0.80233	R:0.83636	F1:0.81899
# triplet	P:0.70536	R:0.55536	F1:0.62144
#
# Epoch:10
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.80932	R:0.78601	F1:0.79749
# Opinion term	P:0.79048	R:0.83838	F1:0.81373
# triplet	P:0.70678	R:0.56766	F1:0.62963
#
# Epoch:11
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.77881	R:0.86214	F1:0.81836
# Opinion term	P:0.76923	R:0.86869	F1:0.81594
# triplet	P:0.66857	R:0.61687	F1:0.64168
#
# Epoch:12
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.80606	R:0.82099	F1:0.81346
# Opinion term	P:0.79655	R:0.83838	F1:0.81693
# triplet	P:0.70124	R:0.59402	F1:0.64320
#
# Epoch:13
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.79771	R:0.86008	F1:0.82772
# Opinion term	P:0.76896	R:0.88081	F1:0.82109
# triplet	P:0.70250	R:0.64323	F1:0.67156
#
# Epoch:14
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.78682	R:0.83539	F1:0.81038
# Opinion term	P:0.77838	R:0.87273	F1:0.82286
# triplet	P:0.70019	R:0.63620	F1:0.66667
#
# Epoch:15
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.77396	R:0.88066	F1:0.82387
# Opinion term	P:0.77355	R:0.86263	F1:0.81566
# triplet	P:0.66546	R:0.64675	F1:0.65597
#
# Epoch:16
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.76277	R:0.86008	F1:0.80851
# Opinion term	P:0.81553	R:0.84848	F1:0.83168
# triplet	P:0.69000	R:0.60633	F1:0.64546
#
# Epoch:17
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.80000	R:0.83951	F1:0.81928
# Opinion term	P:0.82213	R:0.84040	F1:0.83117
# triplet	P:0.70259	R:0.61863	F1:0.65794
#
# Epoch:18
# 100% 79/79 [01:17<00:00,  1.03it/s]
# Aspect term	P:0.79017	R:0.86008	F1:0.82365
# Opinion term	P:0.80651	R:0.85051	F1:0.82793
# triplet	P:0.70445	R:0.61160	F1:0.65475
#
# Epoch:19
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.80321	R:0.82305	F1:0.81301
# Opinion term	P:0.81653	R:0.81818	F1:0.81736
# triplet	P:0.71310	R:0.60281	F1:0.65333
#
# Epoch:20
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.81081	R:0.80247	F1:0.80662
# Opinion term	P:0.81188	R:0.82828	F1:0.82000
# triplet	P:0.69574	R:0.57469	F1:0.62945
#
# Epoch:21
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.79537	R:0.84774	F1:0.82072
# Opinion term	P:0.80497	R:0.85051	F1:0.82711
# triplet	P:0.71633	R:0.61687	F1:0.66289
#
# Epoch:22
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.80312	R:0.84774	F1:0.82482
# Opinion term	P:0.80233	R:0.83636	F1:0.81899
# triplet	P:0.68714	R:0.62917	F1:0.65688
#
# Epoch:23
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.79457	R:0.84362	F1:0.81836
# Opinion term	P:0.80507	R:0.83434	F1:0.81944
# triplet	P:0.68362	R:0.63796	F1:0.66000
#
# Epoch:24
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.80000	R:0.83128	F1:0.81534
# Opinion term	P:0.81250	R:0.84040	F1:0.82622
# triplet	P:0.68164	R:0.61336	F1:0.64570
#
# Epoch:25
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.80709	R:0.84362	F1:0.82495
# Opinion term	P:0.80189	R:0.85859	F1:0.82927
# triplet	P:0.70784	R:0.63445	F1:0.66914
#
# Epoch:26
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.79688	R:0.83951	F1:0.81764
# Opinion term	P:0.80539	R:0.84444	F1:0.82446
# triplet	P:0.68872	R:0.62214	F1:0.65374
#
# Epoch:27
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.78799	R:0.86420	F1:0.82434
# Opinion term	P:0.80524	R:0.86869	F1:0.83576
# triplet	P:0.67917	R:0.63620	F1:0.65699
#
# Epoch:28
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.79658	R:0.86214	F1:0.82806
# Opinion term	P:0.81034	R:0.85455	F1:0.83186
# triplet	P:0.69376	R:0.64499	F1:0.66849
#
# Epoch:29
# 100% 79/79 [01:17<00:00,  1.02it/s]
# Aspect term	P:0.78879	R:0.86831	F1:0.82664
# Opinion term	P:0.80230	R:0.84444	F1:0.82283
# triplet	P:0.69639	R:0.64499	F1:0.66971
#
# best epoch: 13	best dev triplet f1: 0.67156
#
#
# Evaluation on testset:
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Aspect term	P:0.79082	R:0.87176	F1:0.82932
# Opinion term	P:0.75980	R:0.89573	F1:0.82219
# triplet	P:0.66838	R:0.65758	F1:0.66293

# %%
# !python main.py --task pair --mode train --dataset lap14
# Out:
# 2021-04-06 15:42:54.605917: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Epoch:0
# 100% 57/57 [00:53<00:00,  1.07it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.80000	R:0.20544	F1:0.32692
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 57/57 [00:54<00:00,  1.04it/s]
# Aspect term	P:0.75431	R:0.52870	F1:0.62167
# Opinion term	P:0.75980	R:0.49679	F1:0.60078
# pair	P:0.75000	R:0.02368	F1:0.04592
#
# Epoch:4
# 100% 57/57 [00:54<00:00,  1.04it/s]
# Aspect term	P:0.75633	R:0.72205	F1:0.73879
# Opinion term	P:0.69298	R:0.75962	F1:0.72477
# pair	P:0.68534	R:0.41842	F1:0.51961
#
# Epoch:5
# 100% 57/57 [00:55<00:00,  1.04it/s]
# Aspect term	P:0.72941	R:0.74924	F1:0.73920
# Opinion term	P:0.75789	R:0.69231	F1:0.72362
# pair	P:0.70667	R:0.41842	F1:0.52562
#
# Epoch:6
# 100% 57/57 [00:55<00:00,  1.04it/s]
# Aspect term	P:0.76266	R:0.72810	F1:0.74498
# Opinion term	P:0.78598	R:0.68269	F1:0.73070
# pair	P:0.73797	R:0.36316	F1:0.48677
#
# Epoch:7
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.75000	R:0.78852	F1:0.76878
# Opinion term	P:0.76568	R:0.74359	F1:0.75447
# pair	P:0.71654	R:0.47895	F1:0.57413
#
# Epoch:8
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.75811	R:0.77644	F1:0.76716
# Opinion term	P:0.77305	R:0.69872	F1:0.73401
# pair	P:0.70000	R:0.46053	F1:0.55556
#
# Epoch:9
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.77544	R:0.66767	F1:0.71753
# Opinion term	P:0.78030	R:0.66026	F1:0.71528
# pair	P:0.71226	R:0.39737	F1:0.51014
#
# Epoch:10
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.76061	R:0.75831	F1:0.75946
# Opinion term	P:0.73244	R:0.70192	F1:0.71686
# pair	P:0.69925	R:0.48947	F1:0.57585
#
# Epoch:11
# 100% 57/57 [00:55<00:00,  1.04it/s]
# Aspect term	P:0.76543	R:0.74924	F1:0.75725
# Opinion term	P:0.69419	R:0.72756	F1:0.71049
# pair	P:0.67797	R:0.52632	F1:0.59259
#
# Epoch:12
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.74772	R:0.74320	F1:0.74545
# Opinion term	P:0.69208	R:0.75641	F1:0.72282
# pair	P:0.63694	R:0.52632	F1:0.57637
#
# Epoch:13
# 100% 57/57 [00:55<00:00,  1.04it/s]
# Aspect term	P:0.73512	R:0.74622	F1:0.74063
# Opinion term	P:0.73941	R:0.72756	F1:0.73344
# pair	P:0.67138	R:0.50000	F1:0.57315
#
# Epoch:14
# 100% 57/57 [00:54<00:00,  1.04it/s]
# Aspect term	P:0.74926	R:0.76737	F1:0.75821
# Opinion term	P:0.70732	R:0.74359	F1:0.72500
# pair	P:0.65190	R:0.54211	F1:0.59195
#
# Epoch:15
# 100% 57/57 [00:55<00:00,  1.04it/s]
# Aspect term	P:0.74850	R:0.75529	F1:0.75188
# Opinion term	P:0.75248	R:0.73077	F1:0.74146
# pair	P:0.67785	R:0.53158	F1:0.59587
#
# Epoch:16
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.75214	R:0.79758	F1:0.77419
# Opinion term	P:0.70085	R:0.78846	F1:0.74208
# pair	P:0.62670	R:0.60526	F1:0.61580
#
# Epoch:17
# 100% 57/57 [00:55<00:00,  1.04it/s]
# Aspect term	P:0.75281	R:0.80967	F1:0.78020
# Opinion term	P:0.66759	R:0.77244	F1:0.71620
# pair	P:0.60000	R:0.60000	F1:0.60000
#
# Epoch:18
# 100% 57/57 [00:55<00:00,  1.04it/s]
# Aspect term	P:0.76250	R:0.73716	F1:0.74962
# Opinion term	P:0.71077	R:0.74038	F1:0.72527
# pair	P:0.61747	R:0.53947	F1:0.57584
#
# Epoch:19
# 100% 57/57 [00:54<00:00,  1.04it/s]
# Aspect term	P:0.72701	R:0.76435	F1:0.74521
# Opinion term	P:0.71131	R:0.76603	F1:0.73765
# pair	P:0.63415	R:0.54737	F1:0.58757
#
# Epoch:20
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.72237	R:0.84894	F1:0.78056
# Opinion term	P:0.67733	R:0.81410	F1:0.73945
# pair	P:0.62176	R:0.63158	F1:0.62663
#
# Epoch:21
# 100% 57/57 [00:54<00:00,  1.04it/s]
# Aspect term	P:0.69734	R:0.87009	F1:0.77419
# Opinion term	P:0.69679	R:0.76603	F1:0.72977
# pair	P:0.57108	R:0.61316	F1:0.59137
#
# Epoch:22
# 100% 57/57 [00:54<00:00,  1.04it/s]
# Aspect term	P:0.75224	R:0.76133	F1:0.75676
# Opinion term	P:0.70760	R:0.77564	F1:0.74006
# pair	P:0.62117	R:0.58684	F1:0.60352
#
# Epoch:23
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.74499	R:0.78550	F1:0.76471
# Opinion term	P:0.72434	R:0.79167	F1:0.75651
# pair	P:0.62500	R:0.60526	F1:0.61497
#
# Epoch:24
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.75000	R:0.79758	F1:0.77306
# Opinion term	P:0.72059	R:0.78526	F1:0.75153
# pair	P:0.64345	R:0.60789	F1:0.62517
#
# Epoch:25
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.75645	R:0.79758	F1:0.77647
# Opinion term	P:0.70958	R:0.75962	F1:0.73375
# pair	P:0.64035	R:0.57632	F1:0.60665
#
# Epoch:26
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.74148	R:0.78852	F1:0.76428
# Opinion term	P:0.71302	R:0.77244	F1:0.74154
# pair	P:0.63529	R:0.56842	F1:0.60000
#
# Epoch:27
# 100% 57/57 [00:55<00:00,  1.04it/s]
# Aspect term	P:0.76737	R:0.76737	F1:0.76737
# Opinion term	P:0.70809	R:0.78526	F1:0.74468
# pair	P:0.63905	R:0.56842	F1:0.60167
#
# Epoch:28
# 100% 57/57 [00:55<00:00,  1.03it/s]
# Aspect term	P:0.74277	R:0.77644	F1:0.75923
# Opinion term	P:0.69027	R:0.75000	F1:0.71889
# pair	P:0.61721	R:0.54737	F1:0.58020
#
# Epoch:29
# 100% 57/57 [00:55<00:00,  1.04it/s]
# Aspect term	P:0.73789	R:0.78248	F1:0.75953
# Opinion term	P:0.69971	R:0.76923	F1:0.73282
# pair	P:0.61605	R:0.56579	F1:0.58985
#
# best epoch: 20	best dev pair f1: 0.62663
#
#
# Evaluation on testset:
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Aspect term	P:0.74669	R:0.84582	F1:0.79317
# Opinion term	P:0.70290	R:0.81513	F1:0.75486
# pair	P:0.64381	R:0.62018	F1:0.63178

# %%
# !python main.py --task pair --mode train --dataset res15
# Out:
# 2021-04-06 16:25:15.802103: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Epoch:0
# 100% 38/38 [00:32<00:00,  1.16it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 38/38 [00:34<00:00,  1.11it/s]
# Aspect term	P:0.52381	R:0.16098	F1:0.24627
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 38/38 [00:36<00:00,  1.05it/s]
# Aspect term	P:0.70492	R:0.62927	F1:0.66495
# Opinion term	P:0.88889	R:0.28571	F1:0.43243
# pair	P:0.80435	R:0.15612	F1:0.26148
#
# Epoch:3
# 100% 38/38 [00:37<00:00,  1.03it/s]
# Aspect term	P:0.70925	R:0.78537	F1:0.74537
# Opinion term	P:0.73820	R:0.76786	F1:0.75274
# pair	P:0.72656	R:0.39241	F1:0.50959
#
# Epoch:4
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.71861	R:0.80976	F1:0.76147
# Opinion term	P:0.73361	R:0.79911	F1:0.76496
# pair	P:0.69681	R:0.55274	F1:0.61647
#
# Epoch:5
# 100% 38/38 [00:37<00:00,  1.02it/s]
# Aspect term	P:0.80233	R:0.67317	F1:0.73210
# Opinion term	P:0.84173	R:0.52232	F1:0.64463
# pair	P:0.92063	R:0.24473	F1:0.38667
#
# Epoch:6
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.77885	R:0.79024	F1:0.78450
# Opinion term	P:0.79245	R:0.75000	F1:0.77064
# pair	P:0.81013	R:0.54008	F1:0.64810
#
# Epoch:7
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.75000	R:0.76098	F1:0.75545
# Opinion term	P:0.82857	R:0.64732	F1:0.72682
# pair	P:0.85470	R:0.42194	F1:0.56497
#
# Epoch:8
# 100% 38/38 [00:36<00:00,  1.04it/s]
# Aspect term	P:0.75652	R:0.84878	F1:0.80000
# Opinion term	P:0.75000	R:0.84375	F1:0.79412
# pair	P:0.68584	R:0.65401	F1:0.66955
#
# Epoch:9
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.74370	R:0.86341	F1:0.79910
# Opinion term	P:0.73864	R:0.87054	F1:0.79918
# pair	P:0.65200	R:0.68776	F1:0.66940
#
# Epoch:10
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.72289	R:0.87805	F1:0.79295
# Opinion term	P:0.76172	R:0.87054	F1:0.81250
# pair	P:0.66154	R:0.72574	F1:0.69215
#
# Epoch:11
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.76419	R:0.85366	F1:0.80645
# Opinion term	P:0.76984	R:0.86607	F1:0.81513
# pair	P:0.70886	R:0.70886	F1:0.70886
#
# Epoch:12
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.79724	R:0.84390	F1:0.81991
# Opinion term	P:0.79741	R:0.82589	F1:0.81140
# pair	P:0.80513	R:0.66245	F1:0.72685
#
# Epoch:13
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.76496	R:0.87317	F1:0.81549
# Opinion term	P:0.76680	R:0.86607	F1:0.81342
# pair	P:0.72687	R:0.69620	F1:0.71121
#
# Epoch:14
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.76652	R:0.84878	F1:0.80556
# Opinion term	P:0.78543	R:0.86607	F1:0.82378
# pair	P:0.71245	R:0.70042	F1:0.70638
#
# Epoch:15
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.75214	R:0.85854	F1:0.80182
# Opinion term	P:0.74436	R:0.88393	F1:0.80816
# pair	P:0.65504	R:0.71308	F1:0.68283
#
# Epoch:16
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.72199	R:0.84878	F1:0.78027
# Opinion term	P:0.78750	R:0.84375	F1:0.81466
# pair	P:0.73303	R:0.68354	F1:0.70742
#
# Epoch:17
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.77130	R:0.83902	F1:0.80374
# Opinion term	P:0.81333	R:0.81696	F1:0.81514
# pair	P:0.74419	R:0.67511	F1:0.70796
#
# Epoch:18
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.74894	R:0.85854	F1:0.80000
# Opinion term	P:0.72963	R:0.87946	F1:0.79757
# pair	P:0.68852	R:0.70886	F1:0.69854
#
# Epoch:19
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.71951	R:0.86341	F1:0.78492
# Opinion term	P:0.72527	R:0.88393	F1:0.79678
# pair	P:0.69658	R:0.68776	F1:0.69214
#
# Epoch:20
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.75000	R:0.86341	F1:0.80272
# Opinion term	P:0.71636	R:0.87946	F1:0.78958
# pair	P:0.65370	R:0.70886	F1:0.68016
#
# Epoch:21
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.75641	R:0.86341	F1:0.80638
# Opinion term	P:0.79032	R:0.87500	F1:0.83051
# pair	P:0.74890	R:0.71730	F1:0.73276
#
# Epoch:22
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.77586	R:0.87805	F1:0.82380
# Opinion term	P:0.79032	R:0.87500	F1:0.83051
# pair	P:0.75330	R:0.72152	F1:0.73707
#
# Epoch:23
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.76522	R:0.85854	F1:0.80920
# Opinion term	P:0.76062	R:0.87946	F1:0.81573
# pair	P:0.72034	R:0.71730	F1:0.71882
#
# Epoch:24
# 100% 38/38 [00:36<00:00,  1.04it/s]
# Aspect term	P:0.75630	R:0.87805	F1:0.81264
# Opinion term	P:0.75573	R:0.88393	F1:0.81481
# pair	P:0.68775	R:0.73418	F1:0.71020
#
# Epoch:25
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.78761	R:0.86829	F1:0.82599
# Opinion term	P:0.81013	R:0.85714	F1:0.83297
# pair	P:0.74672	R:0.72152	F1:0.73391
#
# Epoch:26
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.77489	R:0.87317	F1:0.82110
# Opinion term	P:0.76628	R:0.89286	F1:0.82474
# pair	P:0.71311	R:0.73418	F1:0.72349
#
# Epoch:27
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.77056	R:0.86829	F1:0.81651
# Opinion term	P:0.76448	R:0.88393	F1:0.81988
# pair	P:0.69600	R:0.73418	F1:0.71458
#
# Epoch:28
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.76596	R:0.87805	F1:0.81818
# Opinion term	P:0.76357	R:0.87946	F1:0.81743
# pair	P:0.72803	R:0.73418	F1:0.73109
#
# Epoch:29
# 100% 38/38 [00:36<00:00,  1.03it/s]
# Aspect term	P:0.78125	R:0.85366	F1:0.81585
# Opinion term	P:0.78000	R:0.87054	F1:0.82278
# pair	P:0.75000	R:0.70886	F1:0.72885
#
# best epoch: 22	best dev pair f1: 0.73707
#
#
# Evaluation on testset:
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Aspect term	P:0.75322	R:0.80505	F1:0.77827
# Opinion term	P:0.75542	R:0.82543	F1:0.78888
# pair	P:0.69488	R:0.63804	F1:0.66525

# %%
# !python main.py --task pair --mode train --dataset res16
# Out:
# 2021-04-06 16:46:03.589848: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Epoch:0
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.57988	R:0.32886	F1:0.41970
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.75909	R:0.56040	F1:0.64479
# Opinion term	P:0.86000	R:0.26300	F1:0.40281
# pair	P:0.82759	R:0.13953	F1:0.23881
#
# Epoch:3
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.76266	R:0.80872	F1:0.78502
# Opinion term	P:0.82051	R:0.68502	F1:0.74667
# pair	P:0.84831	R:0.43895	F1:0.57854
#
# Epoch:4
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.73407	R:0.88926	F1:0.80425
# Opinion term	P:0.76124	R:0.82875	F1:0.79356
# pair	P:0.68555	R:0.70349	F1:0.69440
#
# Epoch:5
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.80374	R:0.86577	F1:0.83360
# Opinion term	P:0.79827	R:0.84709	F1:0.82196
# pair	P:0.71429	R:0.66860	F1:0.69069
#
# Epoch:6
# 100% 54/54 [00:52<00:00,  1.03it/s]
# Aspect term	P:0.79100	R:0.82550	F1:0.80788
# Opinion term	P:0.81169	R:0.76453	F1:0.78740
# pair	P:0.76030	R:0.59012	F1:0.66448
#
# Epoch:7
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.82639	R:0.79866	F1:0.81229
# Opinion term	P:0.83612	R:0.76453	F1:0.79872
# pair	P:0.81600	R:0.59302	F1:0.68687
#
# Epoch:8
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.75216	R:0.87584	F1:0.80930
# Opinion term	P:0.81040	R:0.81040	F1:0.81040
# pair	P:0.72381	R:0.66279	F1:0.69196
#
# Epoch:9
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.75783	R:0.89262	F1:0.81972
# Opinion term	P:0.77049	R:0.86239	F1:0.81385
# pair	P:0.67380	R:0.73256	F1:0.70195
#
# Epoch:10
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.74930	R:0.90268	F1:0.81887
# Opinion term	P:0.80233	R:0.84404	F1:0.82265
# pair	P:0.71965	R:0.72384	F1:0.72174
#
# Epoch:11
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.76696	R:0.87248	F1:0.81633
# Opinion term	P:0.80473	R:0.83180	F1:0.81805
# pair	P:0.68678	R:0.69477	F1:0.69075
#
# Epoch:12
# 100% 54/54 [00:52<00:00,  1.03it/s]
# Aspect term	P:0.77015	R:0.86577	F1:0.81517
# Opinion term	P:0.79487	R:0.85321	F1:0.82301
# pair	P:0.71212	R:0.68314	F1:0.69733
#
# Epoch:13
# 100% 54/54 [00:52<00:00,  1.03it/s]
# Aspect term	P:0.74854	R:0.85906	F1:0.80000
# Opinion term	P:0.79412	R:0.82569	F1:0.80960
# pair	P:0.69118	R:0.68314	F1:0.68713
#
# Epoch:14
# 100% 54/54 [00:52<00:00,  1.03it/s]
# Aspect term	P:0.76855	R:0.86913	F1:0.81575
# Opinion term	P:0.81627	R:0.82875	F1:0.82246
# pair	P:0.71687	R:0.69186	F1:0.70414
#
# Epoch:15
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.75802	R:0.87248	F1:0.81123
# Opinion term	P:0.77809	R:0.84709	F1:0.81113
# pair	P:0.68169	R:0.70349	F1:0.69242
#
# Epoch:16
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.77381	R:0.87248	F1:0.82019
# Opinion term	P:0.77008	R:0.85015	F1:0.80814
# pair	P:0.68333	R:0.71512	F1:0.69886
#
# Epoch:17
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.76504	R:0.89597	F1:0.82535
# Opinion term	P:0.74865	R:0.84709	F1:0.79484
# pair	P:0.66057	R:0.73547	F1:0.69601
#
# Epoch:18
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.78788	R:0.87248	F1:0.82803
# Opinion term	P:0.76712	R:0.85627	F1:0.80925
# pair	P:0.68392	R:0.72965	F1:0.70605
#
# Epoch:19
# 100% 54/54 [00:52<00:00,  1.03it/s]
# Aspect term	P:0.72087	R:0.89262	F1:0.79760
# Opinion term	P:0.74474	R:0.86544	F1:0.80057
# pair	P:0.63210	R:0.74419	F1:0.68358
#
# Epoch:20
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.76163	R:0.87919	F1:0.81620
# Opinion term	P:0.79772	R:0.85627	F1:0.82596
# pair	P:0.68937	R:0.73547	F1:0.71167
#
# Epoch:21
# 100% 54/54 [00:52<00:00,  1.03it/s]
# Aspect term	P:0.75767	R:0.82886	F1:0.79167
# Opinion term	P:0.78028	R:0.84709	F1:0.81232
# pair	P:0.66575	R:0.70058	F1:0.68272
#
# Epoch:22
# 100% 54/54 [00:52<00:00,  1.03it/s]
# Aspect term	P:0.75645	R:0.88591	F1:0.81607
# Opinion term	P:0.75815	R:0.85321	F1:0.80288
# pair	P:0.65464	R:0.73837	F1:0.69399
#
# Epoch:23
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.75714	R:0.88926	F1:0.81790
# Opinion term	P:0.75134	R:0.85933	F1:0.80171
# pair	P:0.65063	R:0.74709	F1:0.69553
#
# Epoch:24
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.76453	R:0.88255	F1:0.81931
# Opinion term	P:0.76438	R:0.85321	F1:0.80636
# pair	P:0.66406	R:0.74128	F1:0.70055
#
# Epoch:25
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.74785	R:0.87584	F1:0.80680
# Opinion term	P:0.76712	R:0.85627	F1:0.80925
# pair	P:0.64796	R:0.73837	F1:0.69022
#
# Epoch:26
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.76081	R:0.88591	F1:0.81860
# Opinion term	P:0.80466	R:0.84404	F1:0.82388
# pair	P:0.68595	R:0.72384	F1:0.70438
#
# Epoch:27
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.73775	R:0.85906	F1:0.79380
# Opinion term	P:0.82812	R:0.81040	F1:0.81917
# pair	P:0.71338	R:0.65116	F1:0.68085
#
# Epoch:28
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.71429	R:0.87248	F1:0.78550
# Opinion term	P:0.75871	R:0.86544	F1:0.80857
# pair	P:0.63772	R:0.74709	F1:0.68809
#
# Epoch:29
# 100% 54/54 [00:52<00:00,  1.02it/s]
# Aspect term	P:0.75367	R:0.86242	F1:0.80438
# Opinion term	P:0.78804	R:0.88685	F1:0.83453
# pair	P:0.69755	R:0.74419	F1:0.72011
#
# best epoch: 10	best dev pair f1: 0.72174
#
#
# Evaluation on testset:
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Aspect term	P:0.69284	R:0.87253	F1:0.77237
# Opinion term	P:0.81641	R:0.87265	F1:0.84359
# pair	P:0.68966	R:0.73359	F1:0.71094

# %%
# !python main.py --task triplet --mode train --dataset lap14
# Out:
# 2021-04-07 10:24:01.942087: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Epoch:0
# 100% 57/57 [01:40<00:00,  1.77s/it]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.75000	R:0.22659	F1:0.34803
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.73290	R:0.67976	F1:0.70533
# Opinion term	P:0.73288	R:0.68590	F1:0.70861
# triplet	P:0.61111	R:0.17368	F1:0.27049
#
# Epoch:4
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.67112	R:0.75831	F1:0.71206
# Opinion term	P:0.70874	R:0.70192	F1:0.70531
# triplet	P:0.59286	R:0.21842	F1:0.31923
#
# Epoch:5
# 100% 57/57 [01:42<00:00,  1.81s/it]
# Aspect term	P:0.59488	R:0.84290	F1:0.69750
# Opinion term	P:0.68693	R:0.72436	F1:0.70515
# triplet	P:0.48519	R:0.34474	F1:0.40308
#
# Epoch:6
# 100% 57/57 [01:42<00:00,  1.81s/it]
# Aspect term	P:0.75000	R:0.62538	F1:0.68204
# Opinion term	P:0.76838	R:0.66987	F1:0.71575
# triplet	P:0.72441	R:0.24211	F1:0.36292
#
# Epoch:7
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.76797	R:0.70997	F1:0.73783
# Opinion term	P:0.78339	R:0.69551	F1:0.73684
# triplet	P:0.71951	R:0.31053	F1:0.43382
#
# Epoch:8
# 100% 57/57 [01:43<00:00,  1.81s/it]
# Aspect term	P:0.74691	R:0.73112	F1:0.73893
# Opinion term	P:0.75244	R:0.74038	F1:0.74637
# triplet	P:0.66667	R:0.35789	F1:0.46575
#
# Epoch:9
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.76119	R:0.77039	F1:0.76577
# Opinion term	P:0.74684	R:0.75641	F1:0.75159
# triplet	P:0.61172	R:0.43947	F1:0.51149
#
# Epoch:10
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.76106	R:0.77946	F1:0.77015
# Opinion term	P:0.77044	R:0.78526	F1:0.77778
# triplet	P:0.64835	R:0.46579	F1:0.54211
#
# Epoch:11
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.74561	R:0.77039	F1:0.75780
# Opinion term	P:0.76471	R:0.75000	F1:0.75728
# triplet	P:0.63433	R:0.44737	F1:0.52469
#
# Epoch:12
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.77039	R:0.77039	F1:0.77039
# Opinion term	P:0.74110	R:0.73397	F1:0.73752
# triplet	P:0.60289	R:0.43947	F1:0.50837
#
# Epoch:13
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.77044	R:0.74018	F1:0.75501
# Opinion term	P:0.76471	R:0.70833	F1:0.73544
# triplet	P:0.65490	R:0.43947	F1:0.52598
#
# Epoch:14
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.75641	R:0.71299	F1:0.73406
# Opinion term	P:0.78351	R:0.73077	F1:0.75622
# triplet	P:0.65759	R:0.44474	F1:0.53061
#
# Epoch:15
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.74336	R:0.76133	F1:0.75224
# Opinion term	P:0.74448	R:0.75641	F1:0.75040
# triplet	P:0.62409	R:0.45000	F1:0.52294
#
# Epoch:16
# 100% 57/57 [01:42<00:00,  1.81s/it]
# Aspect term	P:0.76603	R:0.72205	F1:0.74339
# Opinion term	P:0.76948	R:0.75962	F1:0.76452
# triplet	P:0.59786	R:0.44211	F1:0.50832
#
# Epoch:17
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.73611	R:0.80060	F1:0.76700
# Opinion term	P:0.64737	R:0.78846	F1:0.71098
# triplet	P:0.53179	R:0.48421	F1:0.50689
#
# Epoch:18
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.73067	R:0.82779	F1:0.77620
# Opinion term	P:0.71637	R:0.78526	F1:0.74924
# triplet	P:0.55153	R:0.52105	F1:0.53586
#
# Epoch:19
# 100% 57/57 [01:43<00:00,  1.81s/it]
# Aspect term	P:0.77713	R:0.80060	F1:0.78869
# Opinion term	P:0.72644	R:0.76603	F1:0.74571
# triplet	P:0.60248	R:0.51053	F1:0.55271
#
# Epoch:20
# 100% 57/57 [01:42<00:00,  1.81s/it]
# Aspect term	P:0.76338	R:0.81873	F1:0.79009
# Opinion term	P:0.72754	R:0.77885	F1:0.75232
# triplet	P:0.58934	R:0.49474	F1:0.53791
#
# Epoch:21
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.74561	R:0.77039	F1:0.75780
# Opinion term	P:0.72189	R:0.78205	F1:0.75077
# triplet	P:0.57729	R:0.48158	F1:0.52511
#
# Epoch:22
# 100% 57/57 [01:42<00:00,  1.81s/it]
# Aspect term	P:0.73816	R:0.80060	F1:0.76812
# Opinion term	P:0.68750	R:0.77564	F1:0.72892
# triplet	P:0.54701	R:0.50526	F1:0.52531
#
# Epoch:23
# 100% 57/57 [01:42<00:00,  1.81s/it]
# Aspect term	P:0.75912	R:0.62840	F1:0.68760
# Opinion term	P:0.75333	R:0.72436	F1:0.73856
# triplet	P:0.59924	R:0.41316	F1:0.48910
#
# Epoch:24
# 100% 57/57 [01:43<00:00,  1.81s/it]
# Aspect term	P:0.77457	R:0.80967	F1:0.79173
# Opinion term	P:0.75159	R:0.75641	F1:0.75399
# triplet	P:0.61935	R:0.50526	F1:0.55652
#
# Epoch:25
# 100% 57/57 [01:42<00:00,  1.80s/it]
# Aspect term	P:0.75910	R:0.81873	F1:0.78779
# Opinion term	P:0.69540	R:0.77564	F1:0.73333
# triplet	P:0.53203	R:0.50263	F1:0.51691
#
# Epoch:26
# 100% 57/57 [01:42<00:00,  1.81s/it]
# Aspect term	P:0.76204	R:0.81269	F1:0.78655
# Opinion term	P:0.69252	R:0.80128	F1:0.74294
# triplet	P:0.53846	R:0.51579	F1:0.52688
#
# Epoch:27
# 100% 57/57 [01:43<00:00,  1.81s/it]
# Aspect term	P:0.77538	R:0.76133	F1:0.76829
# Opinion term	P:0.73333	R:0.77564	F1:0.75389
# triplet	P:0.57751	R:0.50000	F1:0.53597
#
# Epoch:28
# 100% 57/57 [01:43<00:00,  1.81s/it]
# Aspect term	P:0.76989	R:0.81873	F1:0.79356
# Opinion term	P:0.69553	R:0.79808	F1:0.74328
# triplet	P:0.56286	R:0.51842	F1:0.53973
#
# Epoch:29
# 100% 57/57 [01:43<00:00,  1.81s/it]
# Aspect term	P:0.77746	R:0.81269	F1:0.79468
# Opinion term	P:0.72866	R:0.76603	F1:0.74687
# triplet	P:0.58333	R:0.51579	F1:0.54749
#
# best epoch: 24	best dev triplet f1: 0.55652
#
#
# Evaluation on testset:
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Aspect term	P:0.76162	R:0.80728	F1:0.78378
# Opinion term	P:0.79449	R:0.78782	F1:0.79114
# triplet	P:0.61623	R:0.51560	F1:0.56144

# %%
# !python main.py --task triplet --mode train --dataset res15
# Out:
# 2021-04-07 11:23:00.067735: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Epoch:0
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.22222	R:0.00976	F1:0.01869
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.75000	R:0.02927	F1:0.05634
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.70325	R:0.84390	F1:0.76718
# Opinion term	P:0.74545	R:0.73214	F1:0.73874
# triplet	P:0.81818	R:0.03797	F1:0.07258
#
# Epoch:4
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.76974	R:0.57073	F1:0.65546
# Opinion term	P:0.91250	R:0.32589	F1:0.48026
# triplet	P:0.50000	R:0.01266	F1:0.02469
#
# Epoch:5
# 100% 38/38 [01:09<00:00,  1.83s/it]
# Aspect term	P:0.80392	R:0.60000	F1:0.68715
# Opinion term	P:0.78873	R:0.50000	F1:0.61202
# triplet	P:0.68421	R:0.05485	F1:0.10156
#
# Epoch:6
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.74737	R:0.69268	F1:0.71899
# Opinion term	P:0.73733	R:0.71429	F1:0.72562
# triplet	P:0.69231	R:0.30380	F1:0.42229
#
# Epoch:7
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.74882	R:0.77073	F1:0.75962
# Opinion term	P:0.73234	R:0.87946	F1:0.79919
# triplet	P:0.56497	R:0.42194	F1:0.48309
#
# Epoch:8
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.76712	R:0.81951	F1:0.79245
# Opinion term	P:0.78279	R:0.85268	F1:0.81624
# triplet	P:0.65761	R:0.51055	F1:0.57482
#
# Epoch:9
# 100% 38/38 [01:08<00:00,  1.81s/it]
# Aspect term	P:0.76786	R:0.83902	F1:0.80186
# Opinion term	P:0.78661	R:0.83929	F1:0.81210
# triplet	P:0.70520	R:0.51477	F1:0.59512
#
# Epoch:10
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.77358	R:0.80000	F1:0.78657
# Opinion term	P:0.77328	R:0.85268	F1:0.81104
# triplet	P:0.68449	R:0.54008	F1:0.60377
#
# Epoch:11
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.76077	R:0.77561	F1:0.76812
# Opinion term	P:0.78947	R:0.80357	F1:0.79646
# triplet	P:0.68342	R:0.57384	F1:0.62385
#
# Epoch:12
# 100% 38/38 [01:08<00:00,  1.82s/it]
# Aspect term	P:0.77626	R:0.82927	F1:0.80189
# Opinion term	P:0.77912	R:0.86607	F1:0.82030
# triplet	P:0.73184	R:0.55274	F1:0.62981
#
# Epoch:13
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.77830	R:0.80488	F1:0.79137
# Opinion term	P:0.79747	R:0.84375	F1:0.81996
# triplet	P:0.75956	R:0.58650	F1:0.66190
#
# Epoch:14
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.75325	R:0.84878	F1:0.79817
# Opinion term	P:0.77600	R:0.86607	F1:0.81857
# triplet	P:0.72449	R:0.59916	F1:0.65589
#
# Epoch:15
# 100% 38/38 [01:08<00:00,  1.81s/it]
# Aspect term	P:0.76623	R:0.86341	F1:0.81193
# Opinion term	P:0.75094	R:0.88839	F1:0.81391
# triplet	P:0.69863	R:0.64557	F1:0.67105
#
# Epoch:16
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.76623	R:0.86341	F1:0.81193
# Opinion term	P:0.73723	R:0.90179	F1:0.81124
# triplet	P:0.66245	R:0.66245	F1:0.66245
#
# Epoch:17
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.77093	R:0.85366	F1:0.81019
# Opinion term	P:0.75093	R:0.90179	F1:0.81947
# triplet	P:0.68354	R:0.68354	F1:0.68354
#
# Epoch:18
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.77434	R:0.85366	F1:0.81206
# Opinion term	P:0.74532	R:0.88839	F1:0.81059
# triplet	P:0.66390	R:0.67511	F1:0.66946
#
# Epoch:19
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.76293	R:0.86341	F1:0.81007
# Opinion term	P:0.74444	R:0.89732	F1:0.81377
# triplet	P:0.65200	R:0.68776	F1:0.66940
#
# Epoch:20
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.73394	R:0.78049	F1:0.75650
# Opinion term	P:0.76562	R:0.87500	F1:0.81667
# triplet	P:0.62931	R:0.61603	F1:0.62260
#
# Epoch:21
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.76018	R:0.81951	F1:0.78873
# Opinion term	P:0.77419	R:0.85714	F1:0.81356
# triplet	P:0.67111	R:0.63713	F1:0.65368
#
# Epoch:22
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.76577	R:0.82927	F1:0.79625
# Opinion term	P:0.77689	R:0.87054	F1:0.82105
# triplet	P:0.69298	R:0.66667	F1:0.67957
#
# Epoch:23
# 100% 38/38 [01:08<00:00,  1.82s/it]
# Aspect term	P:0.76856	R:0.85854	F1:0.81106
# Opinion term	P:0.75379	R:0.88839	F1:0.81557
# triplet	P:0.66953	R:0.65823	F1:0.66383
#
# Epoch:24
# 100% 38/38 [01:09<00:00,  1.82s/it]
# Aspect term	P:0.77632	R:0.86341	F1:0.81755
# Opinion term	P:0.75862	R:0.88393	F1:0.81649
# triplet	P:0.68201	R:0.68776	F1:0.68487
#
# Epoch:25
# 100% 38/38 [01:09<00:00,  1.83s/it]
# Aspect term	P:0.77974	R:0.86341	F1:0.81944
# Opinion term	P:0.75194	R:0.86607	F1:0.80498
# triplet	P:0.67234	R:0.66667	F1:0.66949
#
# Epoch:26
# 100% 38/38 [01:09<00:00,  1.84s/it]
# Aspect term	P:0.76316	R:0.84878	F1:0.80370
# Opinion term	P:0.76923	R:0.84821	F1:0.80679
# triplet	P:0.65401	R:0.65401	F1:0.65401
#
# Epoch:27
# 100% 38/38 [01:09<00:00,  1.84s/it]
# Aspect term	P:0.76623	R:0.86341	F1:0.81193
# Opinion term	P:0.73723	R:0.90179	F1:0.81124
# triplet	P:0.63855	R:0.67089	F1:0.65432
#
# Epoch:28
# 100% 38/38 [01:09<00:00,  1.83s/it]
# Aspect term	P:0.77253	R:0.87805	F1:0.82192
# Opinion term	P:0.73091	R:0.89732	F1:0.80561
# triplet	P:0.64314	R:0.69198	F1:0.66667
#
# Epoch:29
# 100% 38/38 [01:09<00:00,  1.83s/it]
# Aspect term	P:0.77253	R:0.87805	F1:0.82192
# Opinion term	P:0.73783	R:0.87946	F1:0.80244
# triplet	P:0.64050	R:0.65401	F1:0.64718
#
# best epoch: 24	best dev triplet f1: 0.68487
#
#
# Evaluation on testset:
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Aspect term	P:0.74214	R:0.81193	F1:0.77547
# Opinion term	P:0.75775	R:0.84267	F1:0.79796
# triplet	P:0.60613	R:0.56646	F1:0.58562

# %%
# !python main.py --task triplet --mode train --dataset res16
# Out:
# 2021-04-07 12:10:48.817501: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Epoch:0
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.49057	R:0.17450	F1:0.25743
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.77297	R:0.47987	F1:0.59213
# Opinion term	P:0.79931	R:0.70642	F1:0.75000
# triplet	P:0.79167	R:0.11047	F1:0.19388
#
# Epoch:3
# 100% 54/54 [01:39<00:00,  1.85s/it]
# Aspect term	P:0.77848	R:0.82550	F1:0.80130
# Opinion term	P:0.78451	R:0.71254	F1:0.74679
# triplet	P:0.72028	R:0.29942	F1:0.42300
#
# Epoch:4
# 100% 54/54 [01:39<00:00,  1.85s/it]
# Aspect term	P:0.77663	R:0.75839	F1:0.76740
# Opinion term	P:0.76033	R:0.84404	F1:0.80000
# triplet	P:0.66960	R:0.44186	F1:0.53240
#
# Epoch:5
# 100% 54/54 [01:39<00:00,  1.85s/it]
# Aspect term	P:0.79699	R:0.71141	F1:0.75177
# Opinion term	P:0.82283	R:0.63914	F1:0.71945
# triplet	P:0.76224	R:0.31686	F1:0.44764
#
# Epoch:6
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.73273	R:0.81879	F1:0.77338
# Opinion term	P:0.78571	R:0.77370	F1:0.77966
# triplet	P:0.69484	R:0.43023	F1:0.53142
#
# Epoch:7
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.73887	R:0.83557	F1:0.78425
# Opinion term	P:0.77198	R:0.85933	F1:0.81331
# triplet	P:0.67407	R:0.52907	F1:0.59283
#
# Epoch:8
# 100% 54/54 [01:39<00:00,  1.85s/it]
# Aspect term	P:0.74640	R:0.86913	F1:0.80310
# Opinion term	P:0.79213	R:0.86239	F1:0.82577
# triplet	P:0.63063	R:0.61047	F1:0.62038
#
# Epoch:9
# 100% 54/54 [01:39<00:00,  1.85s/it]
# Aspect term	P:0.76877	R:0.85906	F1:0.81141
# Opinion term	P:0.79050	R:0.86544	F1:0.82628
# triplet	P:0.64653	R:0.62209	F1:0.63407
#
# Epoch:10
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.77644	R:0.86242	F1:0.81717
# Opinion term	P:0.78333	R:0.86239	F1:0.82096
# triplet	P:0.67485	R:0.63953	F1:0.65672
#
# Epoch:11
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.77219	R:0.87584	F1:0.82075
# Opinion term	P:0.80229	R:0.85627	F1:0.82840
# triplet	P:0.65029	R:0.65407	F1:0.65217
#
# Epoch:12
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.76946	R:0.86242	F1:0.81329
# Opinion term	P:0.80342	R:0.86239	F1:0.83186
# triplet	P:0.65116	R:0.65116	F1:0.65116
#
# Epoch:13
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.74221	R:0.87919	F1:0.80492
# Opinion term	P:0.79282	R:0.87768	F1:0.83309
# triplet	P:0.67638	R:0.67442	F1:0.67540
#
# Epoch:14
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.76316	R:0.87584	F1:0.81563
# Opinion term	P:0.76408	R:0.87156	F1:0.81429
# triplet	P:0.66106	R:0.68605	F1:0.67332
#
# Epoch:15
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.78354	R:0.86242	F1:0.82109
# Opinion term	P:0.77688	R:0.88379	F1:0.82690
# triplet	P:0.68060	R:0.66279	F1:0.67158
#
# Epoch:16
# 100% 54/54 [01:39<00:00,  1.85s/it]
# Aspect term	P:0.78354	R:0.86242	F1:0.82109
# Opinion term	P:0.81214	R:0.85933	F1:0.83507
# triplet	P:0.69811	R:0.64535	F1:0.67069
#
# Epoch:17
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.79128	R:0.85235	F1:0.82068
# Opinion term	P:0.79609	R:0.87156	F1:0.83212
# triplet	P:0.68358	R:0.66570	F1:0.67452
#
# Epoch:18
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.76667	R:0.84899	F1:0.80573
# Opinion term	P:0.79272	R:0.86544	F1:0.82749
# triplet	P:0.65306	R:0.65116	F1:0.65211
#
# Epoch:19
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.73315	R:0.87584	F1:0.79817
# Opinion term	P:0.75000	R:0.88991	F1:0.81399
# triplet	P:0.62125	R:0.66279	F1:0.64135
#
# Epoch:20
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.76232	R:0.88255	F1:0.81804
# Opinion term	P:0.79666	R:0.87462	F1:0.83382
# triplet	P:0.64246	R:0.66860	F1:0.65527
#
# Epoch:21
# 100% 54/54 [01:39<00:00,  1.85s/it]
# Aspect term	P:0.75893	R:0.85570	F1:0.80442
# Opinion term	P:0.81609	R:0.86850	F1:0.84148
# triplet	P:0.68111	R:0.63953	F1:0.65967
#
# Epoch:22
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.76190	R:0.85906	F1:0.80757
# Opinion term	P:0.79552	R:0.86850	F1:0.83041
# triplet	P:0.66269	R:0.64535	F1:0.65390
#
# Epoch:23
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.79375	R:0.85235	F1:0.82201
# Opinion term	P:0.80966	R:0.87156	F1:0.83947
# triplet	P:0.68827	R:0.64826	F1:0.66766
#
# Epoch:24
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.77508	R:0.85570	F1:0.81340
# Opinion term	P:0.80563	R:0.87462	F1:0.83871
# triplet	P:0.67868	R:0.65698	F1:0.66765
#
# Epoch:25
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.75072	R:0.86913	F1:0.80560
# Opinion term	P:0.81197	R:0.87156	F1:0.84071
# triplet	P:0.66469	R:0.65116	F1:0.65786
#
# Epoch:26
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.74148	R:0.87584	F1:0.80308
# Opinion term	P:0.79387	R:0.87156	F1:0.83090
# triplet	P:0.65000	R:0.68023	F1:0.66477
#
# Epoch:27
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.74926	R:0.85235	F1:0.79749
# Opinion term	P:0.81556	R:0.86544	F1:0.83976
# triplet	P:0.64571	R:0.65698	F1:0.65130
#
# Epoch:28
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.77676	R:0.85235	F1:0.81280
# Opinion term	P:0.81924	R:0.85933	F1:0.83881
# triplet	P:0.73026	R:0.64535	F1:0.68519
#
# Epoch:29
# 100% 54/54 [01:39<00:00,  1.84s/it]
# Aspect term	P:0.76347	R:0.85570	F1:0.80696
# Opinion term	P:0.80392	R:0.87768	F1:0.83918
# triplet	P:0.67953	R:0.66570	F1:0.67254
#
# best epoch: 28	best dev triplet f1: 0.68519
#
#
# Evaluation on testset:
# Calling BertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Aspect term	P:0.76448	R:0.87033	F1:0.81398
# Opinion term	P:0.85600	R:0.89353	F1:0.87436
# triplet	P:0.72727	R:0.66409	F1:0.69425

# %%
cd //content/drive/MyDrive/GTS-main/code/BertModel_Predict/
# Out:
# /content/drive/MyDrive/GTS-main/code/BertModel_Predict

# %%
# !python main.py --task triplet --mode predict --dataset res14
# Out:
# 2021-08-14 13:07:01.042533: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# mode: predict
# --------prediction of Triplet Start---------
# [{'Aspect-Span': ['BANANA', 'PUDDING'], 'Opinion-Span': ['NEVER', 'SEEN'], 'Sentiment': 'negative'}, {'Aspect-Span': ['staff'], 'Opinion-Span': ['arrogant'], 'Sentiment': 'negative'}, {'Aspect-Span': ['service'], 'Opinion-Span': ['prompt', 'friendly'], 'Sentiment': 'positive'}, {'Aspect-Span': ['spot'], 'Opinion-Span': ['hot'], 'Sentiment': 'negative'}, {'Aspect-Span': ['downstairs', 'scene'], 'Opinion-Span': ['cool'], 'Sentiment': 'positive'}]
# -------------prediction of Triplet Ends-------

# %%
# !python main.py --task triplet --mode train --dataset res14
# Out:
# 2021-08-11 16:02:33.644843: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 40/40 [00:40<00:00,  1.02s/it]
# Aspect term	P:0.41304	R:0.07819	F1:0.13149
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.75102	R:0.37860	F1:0.50342
# Opinion term	P:0.89610	R:0.27879	F1:0.42527
# triplet	P:0.71429	R:0.02636	F1:0.05085
#
# Epoch:3
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.81793	R:0.61934	F1:0.70492
# Opinion term	P:0.86810	R:0.57172	F1:0.68940
# triplet	P:0.73333	R:0.01933	F1:0.03767
#
# Epoch:4
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78288	R:0.77160	F1:0.77720
# Opinion term	P:0.81986	R:0.71717	F1:0.76509
# triplet	P:0.70414	R:0.20914	F1:0.32249
#
# Epoch:5
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80964	R:0.65638	F1:0.72500
# Opinion term	P:0.83791	R:0.67879	F1:0.75000
# triplet	P:0.70714	R:0.17399	F1:0.27927
#
# Epoch:6
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78419	R:0.75514	F1:0.76939
# Opinion term	P:0.82536	R:0.69697	F1:0.75575
# triplet	P:0.68085	R:0.28120	F1:0.39801
#
# Epoch:7
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.77183	R:0.80041	F1:0.78586
# Opinion term	P:0.82932	R:0.76566	F1:0.79622
# triplet	P:0.69625	R:0.35852	F1:0.47332
#
# Epoch:8
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.76238	R:0.79218	F1:0.77699
# Opinion term	P:0.82303	R:0.59192	F1:0.68860
# triplet	P:0.70732	R:0.30580	F1:0.42699
#
# Epoch:9
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.75461	R:0.84156	F1:0.79572
# Opinion term	P:0.78501	R:0.80404	F1:0.79441
# triplet	P:0.69133	R:0.47627	F1:0.56400
#
# Epoch:10
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.74296	R:0.86831	F1:0.80076
# Opinion term	P:0.75801	R:0.86061	F1:0.80605
# triplet	P:0.60980	R:0.59051	F1:0.60000
#
# Epoch:11
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.76866	R:0.84774	F1:0.80626
# Opinion term	P:0.76268	R:0.85051	F1:0.80420
# triplet	P:0.65166	R:0.58524	F1:0.61667
#
# Epoch:12
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78835	R:0.83539	F1:0.81119
# Opinion term	P:0.79337	R:0.82222	F1:0.80754
# triplet	P:0.67865	R:0.56415	F1:0.61612
#
# Epoch:13
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.77735	R:0.83333	F1:0.80437
# Opinion term	P:0.79271	R:0.83434	F1:0.81299
# triplet	P:0.66599	R:0.57469	F1:0.61698
#
# Epoch:14
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78143	R:0.83128	F1:0.80558
# Opinion term	P:0.79264	R:0.82626	F1:0.80910
# triplet	P:0.66870	R:0.57821	F1:0.62017
#
# Epoch:15
# 100% 40/40 [00:40<00:00,  1.02s/it]
# Aspect term	P:0.77079	R:0.85802	F1:0.81207
# Opinion term	P:0.79350	R:0.83838	F1:0.81532
# triplet	P:0.65571	R:0.59578	F1:0.62431
#
# Epoch:16
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78503	R:0.84156	F1:0.81231
# Opinion term	P:0.79310	R:0.83636	F1:0.81416
# triplet	P:0.64540	R:0.60457	F1:0.62432
#
# Epoch:17
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.75730	R:0.85391	F1:0.80271
# Opinion term	P:0.78937	R:0.84040	F1:0.81409
# triplet	P:0.65478	R:0.61336	F1:0.63339
#
# Epoch:18
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.76103	R:0.85185	F1:0.80388
# Opinion term	P:0.79961	R:0.83838	F1:0.81854
# triplet	P:0.65858	R:0.62039	F1:0.63891
#
# Epoch:19
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.75360	R:0.86214	F1:0.80422
# Opinion term	P:0.77390	R:0.85051	F1:0.81039
# triplet	P:0.64571	R:0.59578	F1:0.61974
#
# Epoch:20
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.76792	R:0.83745	F1:0.80118
# Opinion term	P:0.80588	R:0.83030	F1:0.81791
# triplet	P:0.66734	R:0.58172	F1:0.62160
#
# Epoch:21
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78947	R:0.83333	F1:0.81081
# Opinion term	P:0.78667	R:0.83434	F1:0.80980
# triplet	P:0.67928	R:0.59930	F1:0.63679
#
# Epoch:22
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78409	R:0.85185	F1:0.81657
# Opinion term	P:0.77879	R:0.86061	F1:0.81766
# triplet	P:0.66479	R:0.62390	F1:0.64370
#
# Epoch:23
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78558	R:0.85185	F1:0.81737
# Opinion term	P:0.78612	R:0.84646	F1:0.81518
# triplet	P:0.68627	R:0.61511	F1:0.64875
#
# Epoch:24
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.75439	R:0.88477	F1:0.81439
# Opinion term	P:0.77941	R:0.85657	F1:0.81617
# triplet	P:0.62284	R:0.63269	F1:0.62772
#
# Epoch:25
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78599	R:0.83128	F1:0.80800
# Opinion term	P:0.81518	R:0.84646	F1:0.83053
# triplet	P:0.67323	R:0.60105	F1:0.63510
#
# Epoch:26
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78682	R:0.83539	F1:0.81038
# Opinion term	P:0.80464	R:0.84040	F1:0.82213
# triplet	P:0.69583	R:0.58699	F1:0.63680
#
# Epoch:27
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79151	R:0.84362	F1:0.81673
# Opinion term	P:0.80312	R:0.83232	F1:0.81746
# triplet	P:0.69538	R:0.58172	F1:0.63349
#
# Epoch:28
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.76994	R:0.85391	F1:0.80976
# Opinion term	P:0.78067	R:0.84848	F1:0.81317
# triplet	P:0.66870	R:0.57821	F1:0.62017
#
# Epoch:29
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78346	R:0.81893	F1:0.80080
# Opinion term	P:0.81641	R:0.84444	F1:0.83019
# triplet	P:0.69710	R:0.59051	F1:0.63939
#
# Epoch:30
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.79102	R:0.83333	F1:0.81162
# Opinion term	P:0.81437	R:0.82424	F1:0.81928
# triplet	P:0.70940	R:0.58348	F1:0.64031
#
# Epoch:31
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78782	R:0.82510	F1:0.80603
# Opinion term	P:0.82922	R:0.81414	F1:0.82161
# triplet	P:0.71588	R:0.56239	F1:0.62992
#
# Epoch:32
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78805	R:0.84156	F1:0.81393
# Opinion term	P:0.81336	R:0.83636	F1:0.82470
# triplet	P:0.70386	R:0.57645	F1:0.63382
#
# Epoch:33
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80338	R:0.78189	F1:0.79249
# Opinion term	P:0.82839	R:0.78990	F1:0.80869
# triplet	P:0.71963	R:0.54130	F1:0.61785
#
# Epoch:34
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80612	R:0.81276	F1:0.80943
# Opinion term	P:0.83333	R:0.74747	F1:0.78807
# triplet	P:0.70686	R:0.52548	F1:0.60282
#
# Epoch:35
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.77820	R:0.83745	F1:0.80674
# Opinion term	P:0.78424	R:0.84444	F1:0.81323
# triplet	P:0.67600	R:0.59402	F1:0.63237
#
# Epoch:36
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.75277	R:0.83951	F1:0.79377
# Opinion term	P:0.79961	R:0.83030	F1:0.81467
# triplet	P:0.65451	R:0.59930	F1:0.62569
#
# Epoch:37
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.76667	R:0.85185	F1:0.80702
# Opinion term	P:0.77716	R:0.85253	F1:0.81310
# triplet	P:0.63717	R:0.63269	F1:0.63492
#
# Epoch:38
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.74589	R:0.83951	F1:0.78993
# Opinion term	P:0.77656	R:0.85657	F1:0.81460
# triplet	P:0.63472	R:0.61687	F1:0.62567
#
# Epoch:39
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.73286	R:0.85802	F1:0.79052
# Opinion term	P:0.76782	R:0.84848	F1:0.80614
# triplet	P:0.62301	R:0.61863	F1:0.62081
#
# Epoch:40
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.75949	R:0.86420	F1:0.80847
# Opinion term	P:0.79848	R:0.84848	F1:0.82272
# triplet	P:0.64182	R:0.62039	F1:0.63092
#
# Epoch:41
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.79029	R:0.83745	F1:0.81319
# Opinion term	P:0.80658	R:0.84242	F1:0.82411
# triplet	P:0.65602	R:0.61336	F1:0.63397
#
# Epoch:42
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.71912	R:0.87449	F1:0.78923
# Opinion term	P:0.76882	R:0.86667	F1:0.81481
# triplet	P:0.61398	R:0.64851	F1:0.63077
#
# Epoch:43
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.75223	R:0.86831	F1:0.80611
# Opinion term	P:0.79580	R:0.84242	F1:0.81845
# triplet	P:0.64416	R:0.62039	F1:0.63205
#
# Epoch:44
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78067	R:0.86420	F1:0.82031
# Opinion term	P:0.79584	R:0.85051	F1:0.82227
# triplet	P:0.66920	R:0.61863	F1:0.64292
#
# Epoch:45
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.74517	R:0.87243	F1:0.80379
# Opinion term	P:0.78253	R:0.85051	F1:0.81510
# triplet	P:0.64935	R:0.61511	F1:0.63177
#
# Epoch:46
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79502	R:0.85391	F1:0.82341
# Opinion term	P:0.79174	R:0.85253	F1:0.82101
# triplet	P:0.67232	R:0.62742	F1:0.64909
#
# Epoch:47
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79845	R:0.84774	F1:0.82236
# Opinion term	P:0.81690	R:0.82020	F1:0.81855
# triplet	P:0.68200	R:0.59930	F1:0.63798
#
# Epoch:48
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78879	R:0.86831	F1:0.82664
# Opinion term	P:0.80354	R:0.82626	F1:0.81474
# triplet	P:0.66409	R:0.60457	F1:0.63293
#
# Epoch:49
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78464	R:0.86214	F1:0.82157
# Opinion term	P:0.79389	R:0.84040	F1:0.81649
# triplet	P:0.64909	R:0.62742	F1:0.63807
#
# Epoch:50
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.77966	R:0.85185	F1:0.81416
# Opinion term	P:0.79584	R:0.85051	F1:0.82227
# triplet	P:0.64580	R:0.63445	F1:0.64007
#
# Epoch:51
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.77778	R:0.87860	F1:0.82512
# Opinion term	P:0.79848	R:0.84848	F1:0.82272
# triplet	P:0.64865	R:0.63269	F1:0.64057
#
# Epoch:52
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79699	R:0.87243	F1:0.83301
# Opinion term	P:0.80784	R:0.83232	F1:0.81990
# triplet	P:0.65607	R:0.61687	F1:0.63587
#
# Epoch:53
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78571	R:0.83745	F1:0.81076
# Opinion term	P:0.79923	R:0.83636	F1:0.81737
# triplet	P:0.65725	R:0.61336	F1:0.63455
#
# Epoch:54
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.77532	R:0.86626	F1:0.81827
# Opinion term	P:0.80038	R:0.85859	F1:0.82846
# triplet	P:0.65233	R:0.63972	F1:0.64596
#
# Epoch:55
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79310	R:0.85185	F1:0.82143
# Opinion term	P:0.81118	R:0.85051	F1:0.83037
# triplet	P:0.66790	R:0.63620	F1:0.65167
#
# Epoch:56
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80117	R:0.84568	F1:0.82282
# Opinion term	P:0.81274	R:0.85051	F1:0.83119
# triplet	P:0.67103	R:0.63093	F1:0.65036
#
# Epoch:57
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.76812	R:0.87243	F1:0.81696
# Opinion term	P:0.80422	R:0.84646	F1:0.82480
# triplet	P:0.66000	R:0.63796	F1:0.64879
#
# Epoch:58
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79691	R:0.84774	F1:0.82154
# Opinion term	P:0.81431	R:0.85051	F1:0.83202
# triplet	P:0.67225	R:0.63445	F1:0.65280
#
# Epoch:59
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78049	R:0.85597	F1:0.81649
# Opinion term	P:0.81275	R:0.82424	F1:0.81846
# triplet	P:0.66229	R:0.62039	F1:0.64065
#
# Epoch:60
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.76679	R:0.84568	F1:0.80431
# Opinion term	P:0.80502	R:0.84242	F1:0.82330
# triplet	P:0.63445	R:0.63445	F1:0.63445
#
# Epoch:61
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.76130	R:0.86626	F1:0.81039
# Opinion term	P:0.78637	R:0.86263	F1:0.82274
# triplet	P:0.66415	R:0.61863	F1:0.64058
#
# Epoch:62
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.77064	R:0.86420	F1:0.81474
# Opinion term	P:0.80000	R:0.85657	F1:0.82732
# triplet	P:0.65809	R:0.62917	F1:0.64331
#
# Epoch:63
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.76654	R:0.81070	F1:0.78800
# Opinion term	P:0.81299	R:0.83434	F1:0.82353
# triplet	P:0.66731	R:0.60984	F1:0.63728
#
# Epoch:64
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.76471	R:0.82922	F1:0.79566
# Opinion term	P:0.81128	R:0.84242	F1:0.82656
# triplet	P:0.67118	R:0.60984	F1:0.63904
#
# Epoch:65
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.81144	R:0.78807	F1:0.79958
# Opinion term	P:0.81799	R:0.78990	F1:0.80370
# triplet	P:0.68595	R:0.58348	F1:0.63058
#
# Epoch:66
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78450	R:0.85391	F1:0.81773
# Opinion term	P:0.79008	R:0.83636	F1:0.81256
# triplet	P:0.64182	R:0.62039	F1:0.63092
#
# Epoch:67
# 100% 40/40 [00:40<00:00,  1.02s/it]
# Aspect term	P:0.79511	R:0.87037	F1:0.83104
# Opinion term	P:0.82072	R:0.83232	F1:0.82648
# triplet	P:0.67167	R:0.62917	F1:0.64973
#
# Epoch:68
# 100% 40/40 [00:40<00:00,  1.02s/it]
# Aspect term	P:0.77138	R:0.85391	F1:0.81055
# Opinion term	P:0.80925	R:0.84848	F1:0.82840
# triplet	P:0.65434	R:0.62214	F1:0.63784
#
# Epoch:69
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80153	R:0.86420	F1:0.83168
# Opinion term	P:0.81395	R:0.84848	F1:0.83086
# triplet	P:0.67286	R:0.63620	F1:0.65402
#
# Epoch:70
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80998	R:0.86831	F1:0.83813
# Opinion term	P:0.81800	R:0.84444	F1:0.83101
# triplet	P:0.67412	R:0.63620	F1:0.65461
#
# Epoch:71
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79771	R:0.86008	F1:0.82772
# Opinion term	P:0.80897	R:0.83838	F1:0.82341
# triplet	P:0.66357	R:0.62742	F1:0.64499
#
# Epoch:72
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80381	R:0.86831	F1:0.83482
# Opinion term	P:0.80859	R:0.83636	F1:0.82224
# triplet	P:0.66791	R:0.62917	F1:0.64796
#
# Epoch:73
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80614	R:0.86420	F1:0.83416
# Opinion term	P:0.80620	R:0.84040	F1:0.82295
# triplet	P:0.66790	R:0.63620	F1:0.65167
#
# Epoch:74
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79962	R:0.86214	F1:0.82970
# Opinion term	P:0.84058	R:0.82020	F1:0.83027
# triplet	P:0.68138	R:0.62390	F1:0.65138
#
# Epoch:75
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80303	R:0.87243	F1:0.83629
# Opinion term	P:0.79813	R:0.86263	F1:0.82913
# triplet	P:0.66850	R:0.64148	F1:0.65471
#
# Epoch:76
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80851	R:0.86008	F1:0.83350
# Opinion term	P:0.82490	R:0.85657	F1:0.84044
# triplet	P:0.67472	R:0.63796	F1:0.65583
#
# Epoch:77
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80843	R:0.86831	F1:0.83730
# Opinion term	P:0.81034	R:0.85455	F1:0.83186
# triplet	P:0.66667	R:0.62917	F1:0.64738
#
# Epoch:78
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79213	R:0.87037	F1:0.82941
# Opinion term	P:0.81431	R:0.85051	F1:0.83202
# triplet	P:0.66917	R:0.62566	F1:0.64668
#
# Epoch:79
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78558	R:0.87449	F1:0.82765
# Opinion term	P:0.81346	R:0.85455	F1:0.83350
# triplet	P:0.65653	R:0.64499	F1:0.65071
#
# Epoch:80
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78142	R:0.88272	F1:0.82899
# Opinion term	P:0.80529	R:0.86061	F1:0.83203
# triplet	P:0.65647	R:0.64148	F1:0.64889
#
# Epoch:81
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.81765	R:0.85802	F1:0.83735
# Opinion term	P:0.81800	R:0.84444	F1:0.83101
# triplet	P:0.68008	R:0.62390	F1:0.65078
#
# Epoch:82
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.81008	R:0.86008	F1:0.83433
# Opinion term	P:0.80608	R:0.85657	F1:0.83056
# triplet	P:0.66052	R:0.62917	F1:0.64446
#
# Epoch:83
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80153	R:0.86420	F1:0.83168
# Opinion term	P:0.81641	R:0.84444	F1:0.83019
# triplet	P:0.65804	R:0.62566	F1:0.64144
#
# Epoch:84
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80688	R:0.86831	F1:0.83647
# Opinion term	P:0.81496	R:0.83636	F1:0.82552
# triplet	P:0.66978	R:0.63093	F1:0.64977
#
# Epoch:85
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.80614	R:0.86420	F1:0.83416
# Opinion term	P:0.82446	R:0.84444	F1:0.83433
# triplet	P:0.67228	R:0.63093	F1:0.65095
#
# Epoch:86
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79468	R:0.86008	F1:0.82609
# Opinion term	P:0.81518	R:0.84646	F1:0.83053
# triplet	P:0.67420	R:0.62917	F1:0.65091
#
# Epoch:87
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78479	R:0.87037	F1:0.82537
# Opinion term	P:0.80306	R:0.84848	F1:0.82515
# triplet	P:0.65699	R:0.63620	F1:0.64643
#
# Epoch:88
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79362	R:0.87037	F1:0.83023
# Opinion term	P:0.81165	R:0.84444	F1:0.82772
# triplet	P:0.66851	R:0.63796	F1:0.65288
#
# Epoch:89
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80545	R:0.85185	F1:0.82800
# Opinion term	P:0.80614	R:0.84848	F1:0.82677
# triplet	P:0.66972	R:0.64148	F1:0.65530
#
# Epoch:90
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78349	R:0.87860	F1:0.82832
# Opinion term	P:0.78519	R:0.85657	F1:0.81932
# triplet	P:0.63653	R:0.60633	F1:0.62106
#
# Epoch:91
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79848	R:0.86420	F1:0.83004
# Opinion term	P:0.76619	R:0.86061	F1:0.81066
# triplet	P:0.64706	R:0.63796	F1:0.64248
#
# Epoch:92
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80350	R:0.84979	F1:0.82600
# Opinion term	P:0.79806	R:0.83030	F1:0.81386
# triplet	P:0.66165	R:0.61863	F1:0.63942
#
# Epoch:93
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.78771	R:0.87037	F1:0.82698
# Opinion term	P:0.79580	R:0.84242	F1:0.81845
# triplet	P:0.65062	R:0.64148	F1:0.64602
#
# Epoch:94
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80309	R:0.85597	F1:0.82869
# Opinion term	P:0.80000	R:0.82424	F1:0.81194
# triplet	P:0.66667	R:0.63269	F1:0.64923
#
# Epoch:95
# 100% 40/40 [00:41<00:00,  1.04s/it]
# Aspect term	P:0.80626	R:0.84774	F1:0.82648
# Opinion term	P:0.80196	R:0.82626	F1:0.81393
# triplet	P:0.67568	R:0.61511	F1:0.64397
#
# Epoch:96
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79423	R:0.84979	F1:0.82107
# Opinion term	P:0.79497	R:0.83030	F1:0.81225
# triplet	P:0.66052	R:0.62917	F1:0.64446
#
# Epoch:97
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80039	R:0.84979	F1:0.82435
# Opinion term	P:0.79648	R:0.82222	F1:0.80915
# triplet	P:0.66168	R:0.62214	F1:0.64130
#
# Epoch:98
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78544	R:0.84362	F1:0.81349
# Opinion term	P:0.77298	R:0.83232	F1:0.80156
# triplet	P:0.65056	R:0.61511	F1:0.63234
#
# Epoch:99
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80273	R:0.84568	F1:0.82365
# Opinion term	P:0.78917	R:0.82424	F1:0.80632
# triplet	P:0.65858	R:0.62039	F1:0.63891
#
# Epoch:100
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79576	R:0.84979	F1:0.82189
# Opinion term	P:0.80118	R:0.82222	F1:0.81157
# triplet	P:0.66730	R:0.61687	F1:0.64110
#
# Epoch:101
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79310	R:0.85185	F1:0.82143
# Opinion term	P:0.79079	R:0.83232	F1:0.81102
# triplet	P:0.64899	R:0.62390	F1:0.63620
#
# Epoch:102
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78293	R:0.86831	F1:0.82341
# Opinion term	P:0.76600	R:0.84646	F1:0.80422
# triplet	P:0.64528	R:0.63620	F1:0.64071
#
# Epoch:103
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80906	R:0.84568	F1:0.82696
# Opinion term	P:0.80588	R:0.83030	F1:0.81791
# triplet	P:0.66604	R:0.62390	F1:0.64428
#
# Epoch:104
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79447	R:0.82716	F1:0.81048
# Opinion term	P:0.80115	R:0.84646	F1:0.82318
# triplet	P:0.67810	R:0.62566	F1:0.65082
#
# Epoch:105
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.76577	R:0.87449	F1:0.81652
# Opinion term	P:0.80230	R:0.84444	F1:0.82283
# triplet	P:0.64973	R:0.62917	F1:0.63929
#
# Epoch:106
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80038	R:0.85802	F1:0.82820
# Opinion term	P:0.80460	R:0.84848	F1:0.82596
# triplet	P:0.65574	R:0.63269	F1:0.64401
#
# Epoch:107
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80588	R:0.84568	F1:0.82530
# Opinion term	P:0.82591	R:0.82424	F1:0.82508
# triplet	P:0.69138	R:0.60633	F1:0.64607
#
# Epoch:108
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78887	R:0.84568	F1:0.81629
# Opinion term	P:0.79658	R:0.84646	F1:0.82076
# triplet	P:0.65099	R:0.63269	F1:0.64171
#
# Epoch:109
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79572	R:0.84156	F1:0.81800
# Opinion term	P:0.82122	R:0.84444	F1:0.83267
# triplet	P:0.67547	R:0.62917	F1:0.65150
#
# Epoch:110
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78817	R:0.84979	F1:0.81782
# Opinion term	P:0.81299	R:0.83434	F1:0.82353
# triplet	P:0.66286	R:0.61160	F1:0.63620
#
# Epoch:111
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79806	R:0.84568	F1:0.82118
# Opinion term	P:0.80971	R:0.84242	F1:0.82574
# triplet	P:0.66912	R:0.63972	F1:0.65409
#
# Epoch:112
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79732	R:0.85802	F1:0.82656
# Opinion term	P:0.80464	R:0.84040	F1:0.82213
# triplet	P:0.66486	R:0.64499	F1:0.65477
#
# Epoch:113
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80980	R:0.84979	F1:0.82932
# Opinion term	P:0.79468	R:0.84444	F1:0.81881
# triplet	P:0.65045	R:0.63445	F1:0.64235
#
# Epoch:114
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.79389	R:0.85597	F1:0.82376
# Opinion term	P:0.81676	R:0.84646	F1:0.83135
# triplet	P:0.66486	R:0.64499	F1:0.65477
#
# Epoch:115
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80000	R:0.84774	F1:0.82318
# Opinion term	P:0.82540	R:0.84040	F1:0.83283
# triplet	P:0.66853	R:0.63093	F1:0.64919
#
# Epoch:116
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.80078	R:0.84362	F1:0.82164
# Opinion term	P:0.82435	R:0.83434	F1:0.82932
# triplet	P:0.65989	R:0.62742	F1:0.64324
#
# Epoch:117
# 100% 40/40 [00:40<00:00,  1.02s/it]
# Aspect term	P:0.79497	R:0.84568	F1:0.81954
# Opinion term	P:0.81854	R:0.83838	F1:0.82834
# triplet	P:0.69080	R:0.62039	F1:0.65370
#
# Epoch:118
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.77095	R:0.85185	F1:0.80938
# Opinion term	P:0.79771	R:0.84444	F1:0.82041
# triplet	P:0.65234	R:0.61336	F1:0.63225
#
# Epoch:119
# 100% 40/40 [00:41<00:00,  1.03s/it]
# Aspect term	P:0.78352	R:0.84156	F1:0.81151
# Opinion term	P:0.82051	R:0.84040	F1:0.83034
# triplet	P:0.67748	R:0.62390	F1:0.64959
#
# best epoch: 76	best dev triplet f1: 0.65583
#
#
# Evaluation on testset:
# Aspect term	P:0.78321	R:0.86706	F1:0.82300
# Opinion term	P:0.80916	R:0.87915	F1:0.84270
# triplet	P:0.68938	R:0.69495	F1:0.69215

# %%
import main

# %%
main.predict('res14')
# Out:
# mode: predict
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1b6a49f7a1d2> in <module>()
# ----> 1 main.predict('res14')
#
# /content/drive/My Drive/GTS-main/code/BertModel_Predict/main.py in predict(args)
#     117 def predict(args):
#     118     print("mode: predict")
# --> 119     model_path = args.model_dir + 'bert' + args.task +'.pt'
#     120     model = torch.load(model_path).to(args.device)
#     121     model.eval()
#
# AttributeError: 'str' object has no attribute 'model_dir'

# %%
index = [1,3,4,7]
index = [al,ar,pl,pr]
Senetence = 'HI bro siddarth, are you fine. WHat are you doing'
list_sentence = Senetence.split()
print(list_sentence[index[1]],)
# Out:
# are

# %%
import numpy as np
aspect_indexes = index[:2]
aspect_terms = [list_sentence[i] for i in aspect_indexes]
print(aspect_terms)
# Out:
# ['bro', 'are']

# %%
aspect_terms1= ['bro','bro']
np.unique(aspect_terms).
# Out:
# array(['are', 'bro'], dtype='<U3')

# %%
aspect_terms = np.array(aspect_terms)
print(np.unique(aspect_terms)[0])
# Out:
# are

# %%
import json 
json_read = json.load(open('/content/drive/MyDrive/GTS-main/data/res14/test1.json'))

# %%
print(len(json_read))
# Out:
# 2

# %%
import data
read_data =data.DataIterator()

# %%
terms = ['bro','bro']
print(len(np.unique(terms)))
# Out:
# 1

# %%
# !pip install flask_ngrok
# Out:
# Collecting flask_ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask_ngrok) (2.23.0)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask_ngrok) (1.1.4)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_ngrok) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_ngrok) (1.0.1)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_ngrok) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_ngrok) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask_ngrok) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask_ngrok) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask_ngrok) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask_ngrok) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask_ngrok) (3.0.4)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25

# %%
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-5.1.0.tar.gz (745 kB)
#      |████████████████████████████████| 745 kB 8.4 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok) (3.13)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19006 sha256=02b9b2a7ad22a444a35da3769d5fba075d4c6d5ae6e6e11e1ccf878c04b127e6
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-5.1.0

# %%
! ngrok authtoken 1wwHZWaGAouhG8pzfJcbidE2gaN_7dUskopdQZodNVY2VH5dX
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
from pyngrok import ngrok
api = ngrok.connect(port='5000')

# %%
ngrok.kill()

# %%
# !python app.py --task triplet --mode predict1 --dataset wine226
# Out:
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# The current process just got forked. Disabling parallelism to avoid deadlocks...
# To disable this warning, please explicitly set TOKENIZERS_PARALLELISM=(true | false)
#  * Running on http://afb3-34-125-192-100.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [14/Sep/2021 18:36:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Sep/2021 18:36:14] "GET /static/css/styles.css HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Sep/2021 18:36:14] "GET /static/3.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Sep/2021 18:36:15] "GET /favicon.ico HTTP/1.1" 404 -
# mode: predict
# Downloading: 100% 433/433 [00:00<00:00, 401kB/s]
# Downloading: 100% 232k/232k [00:00<00:00, 941kB/s]
# Input Sentence:  A bright, engaging style that offers great value to those partial to a typical Maipo Cab. It works because it’s made in a deliberately fresher style, with notes of red pepper and blackcurrant. Perfect pizza wine.
# --------prediction of Triplet Start---------
# [{'Input Sentence': 'A bright, engaging style that offers great value to those partial to a typical Maipo Cab. It works because it’s made in a deliberately fresher style, with notes of red pepper and blackcurrant. Perfect pizza wine.', 'triplets': [{'Aspect-Span': ['style'], 'Opinion-Span': ['bright,', 'engaging'], 'Sentiment': ['positive']}, {'Aspect-Span': ['Maipo'], 'Opinion-Span': ['bright,', 'engaging'], 'Sentiment': ['positive']}, {'Aspect-Span': ['Maipo'], 'Opinion-Span': ['great'], 'Sentiment': ['positive']}, {'Aspect-Span': ['notes', 'pepper'], 'Opinion-Span': ['fresher'], 'Sentiment': ['positive']}, {'Aspect-Span': ['pizza', 'wine.'], 'Opinion-Span': ['Perfect'], 'Sentiment': ['positive']}]}]
# -------------prediction of Triplet Ends-------
# 127.0.0.1 - - [14/Sep/2021 18:37:58] "POST /predict1 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Sep/2021 18:37:58] "GET /static/css/styles.css HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Sep/2021 18:38:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Sep/2021 18:38:58] "GET /static/css/styles.css HTTP/1.1" 404 -
