# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/GTS-main/code/RobertaModel
# Out:
# /content/drive/MyDrive/GTS-main/code/RobertaModel

# %%
# !pip install transformers==3
# Out:
# Collecting transformers==3
#   Downloading transformers-3.0.0-py3-none-any.whl (754 kB)
#      |████████████████████████████████| 754 kB 4.0 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3) (2019.12.20)
# Collecting tokenizers==0.8.0-rc4
#   Downloading tokenizers-0.8.0rc4-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 20.1 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3) (3.0.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3) (21.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 32.8 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3) (1.19.5)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 60.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3) (2.23.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3) (2021.5.30)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3) (1.0.1)
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.45 sentencepiece-0.1.96 tokenizers-0.8.0rc4 transformers-3.0.0

# %%
# !python main.py --task pair --mode train --dataset res14
# Out:
# 2021-08-10 10:26:05.124779: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Downloading: 100% 232k/232k [00:00<00:00, 314kB/s]
# Epoch:0
# 100% 158/158 [00:45<00:00,  3.50it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.75659	R:0.76749	F1:0.76200
# Opinion term	P:0.77828	R:0.69495	F1:0.73426
# pair	P:0.79286	R:0.39016	F1:0.52297
#
# Epoch:2
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.73188	R:0.83128	F1:0.77842
# Opinion term	P:0.81210	R:0.75960	F1:0.78497
# pair	P:0.74347	R:0.55009	F1:0.63232
#
# Epoch:3
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.82243	R:0.72428	F1:0.77024
# Opinion term	P:0.83220	R:0.74141	F1:0.78419
# pair	P:0.83072	R:0.46573	F1:0.59685
#
# Epoch:4
# 100% 158/158 [00:45<00:00,  3.50it/s]
# Aspect term	P:0.81840	R:0.71399	F1:0.76264
# Opinion term	P:0.83441	R:0.78384	F1:0.80833
# pair	P:0.79843	R:0.53603	F1:0.64143
#
# Epoch:5
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77442	R:0.68519	F1:0.72707
# Opinion term	P:0.83503	R:0.82828	F1:0.83164
# pair	P:0.79093	R:0.55185	F1:0.65010
#
# Epoch:6
# 100% 158/158 [00:45<00:00,  3.50it/s]
# Aspect term	P:0.77927	R:0.83539	F1:0.80636
# Opinion term	P:0.83570	R:0.83232	F1:0.83401
# pair	P:0.79698	R:0.64851	F1:0.71512
#
# Epoch:7
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.76515	R:0.83128	F1:0.79684
# Opinion term	P:0.80725	R:0.85455	F1:0.83023
# pair	P:0.73938	R:0.67311	F1:0.70469
#
# Epoch:8
# 100% 158/158 [00:45<00:00,  3.50it/s]
# Aspect term	P:0.77734	R:0.81893	F1:0.79760
# Opinion term	P:0.79626	R:0.86061	F1:0.82718
# pair	P:0.74517	R:0.67838	F1:0.71021
#
# Epoch:9
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.77055	R:0.82922	F1:0.79881
# Opinion term	P:0.79705	R:0.87273	F1:0.83317
# pair	P:0.73978	R:0.69947	F1:0.71906
#
# Epoch:10
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.76604	R:0.83539	F1:0.79921
# Opinion term	P:0.81532	R:0.83838	F1:0.82669
# pair	P:0.72427	R:0.65554	F1:0.68819
#
# Epoch:11
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.76749	R:0.83539	F1:0.80000
# Opinion term	P:0.79562	R:0.88081	F1:0.83605
# pair	P:0.73346	R:0.70123	F1:0.71698
#
# Epoch:12
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.77425	R:0.85391	F1:0.81213
# Opinion term	P:0.78097	R:0.87879	F1:0.82700
# pair	P:0.71675	R:0.72935	F1:0.72300
#
# Epoch:13
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.76022	R:0.84156	F1:0.79883
# Opinion term	P:0.77601	R:0.88889	F1:0.82863
# pair	P:0.69463	R:0.72759	F1:0.71073
#
# Epoch:14
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.76054	R:0.81687	F1:0.78770
# Opinion term	P:0.81871	R:0.84848	F1:0.83333
# pair	P:0.75049	R:0.67663	F1:0.71165
#
# Epoch:15
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77778	R:0.80658	F1:0.79192
# Opinion term	P:0.83104	R:0.85455	F1:0.84263
# pair	P:0.72968	R:0.67838	F1:0.70310
#
# Epoch:16
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.78675	R:0.78189	F1:0.78431
# Opinion term	P:0.81250	R:0.86667	F1:0.83871
# pair	P:0.76639	R:0.65729	F1:0.70766
#
# Epoch:17
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.76938	R:0.83745	F1:0.80197
# Opinion term	P:0.80980	R:0.83434	F1:0.82189
# pair	P:0.74115	R:0.69947	F1:0.71971
#
# Epoch:18
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.80866	R:0.73045	F1:0.76757
# Opinion term	P:0.81928	R:0.82424	F1:0.82175
# pair	P:0.75210	R:0.62917	F1:0.68517
#
# Epoch:19
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78068	R:0.79835	F1:0.78942
# Opinion term	P:0.82669	R:0.83838	F1:0.83250
# pair	P:0.75926	R:0.64851	F1:0.69953
#
# Epoch:20
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77905	R:0.84156	F1:0.80910
# Opinion term	P:0.80464	R:0.84040	F1:0.82213
# pair	P:0.73557	R:0.69420	F1:0.71429
#
# Epoch:21
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.78024	R:0.79630	F1:0.78819
# Opinion term	P:0.80194	R:0.83434	F1:0.81782
# pair	P:0.73674	R:0.68366	F1:0.70921
#
# Epoch:22
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.77273	R:0.80453	F1:0.78831
# Opinion term	P:0.82020	R:0.82020	F1:0.82020
# pair	P:0.78105	R:0.65202	F1:0.71073
#
# Epoch:23
# 100% 158/158 [00:45<00:00,  3.50it/s]
# Aspect term	P:0.78113	R:0.85185	F1:0.81496
# Opinion term	P:0.81445	R:0.84242	F1:0.82820
# pair	P:0.75573	R:0.69596	F1:0.72461
#
# Epoch:24
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.78530	R:0.83539	F1:0.80957
# Opinion term	P:0.82258	R:0.82424	F1:0.82341
# pair	P:0.77966	R:0.64675	F1:0.70701
#
# Epoch:25
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.76208	R:0.84362	F1:0.80078
# Opinion term	P:0.82178	R:0.83838	F1:0.83000
# pair	P:0.75100	R:0.66257	F1:0.70401
#
# Epoch:26
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.75315	R:0.86008	F1:0.80307
# Opinion term	P:0.81336	R:0.83636	F1:0.82470
# pair	P:0.74563	R:0.67487	F1:0.70849
#
# Epoch:27
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.79324	R:0.82099	F1:0.80688
# Opinion term	P:0.81481	R:0.84444	F1:0.82937
# pair	P:0.74586	R:0.71178	F1:0.72842
#
# Epoch:28
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.73440	R:0.84774	F1:0.78701
# Opinion term	P:0.79550	R:0.85657	F1:0.82490
# pair	P:0.71403	R:0.68893	F1:0.70125
#
# Epoch:29
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.77298	R:0.84774	F1:0.80864
# Opinion term	P:0.80769	R:0.84848	F1:0.82759
# pair	P:0.73307	R:0.64675	F1:0.68721
#
# Epoch:30
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.76515	R:0.83128	F1:0.79684
# Opinion term	P:0.79554	R:0.86465	F1:0.82865
# pair	P:0.72007	R:0.68717	F1:0.70324
#
# Epoch:31
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.78210	R:0.82716	F1:0.80400
# Opinion term	P:0.80798	R:0.85859	F1:0.83252
# pair	P:0.73635	R:0.68717	F1:0.71091
#
# Epoch:32
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77973	R:0.82305	F1:0.80080
# Opinion term	P:0.80228	R:0.85253	F1:0.82664
# pair	P:0.71248	R:0.69244	F1:0.70232
#
# Epoch:33
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.77930	R:0.82099	F1:0.79960
# Opinion term	P:0.78938	R:0.87071	F1:0.82805
# pair	P:0.69191	R:0.70650	F1:0.69913
#
# Epoch:34
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.76699	R:0.81276	F1:0.78921
# Opinion term	P:0.78850	R:0.85859	F1:0.82205
# pair	P:0.70377	R:0.68893	F1:0.69627
#
# Epoch:35
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.75551	R:0.84568	F1:0.79806
# Opinion term	P:0.80614	R:0.84848	F1:0.82677
# pair	P:0.70863	R:0.69244	F1:0.70044
#
# Epoch:36
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.78656	R:0.81893	F1:0.80242
# Opinion term	P:0.78545	R:0.85051	F1:0.81668
# pair	P:0.69014	R:0.68893	F1:0.68953
#
# Epoch:37
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77383	R:0.85185	F1:0.81097
# Opinion term	P:0.80153	R:0.84848	F1:0.82434
# pair	P:0.72432	R:0.70650	F1:0.71530
#
# Epoch:38
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.78544	R:0.84362	F1:0.81349
# Opinion term	P:0.81563	R:0.82222	F1:0.81891
# pair	P:0.73148	R:0.69420	F1:0.71235
#
# Epoch:39
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78435	R:0.84568	F1:0.81386
# Opinion term	P:0.79924	R:0.84444	F1:0.82122
# pair	P:0.72395	R:0.69596	F1:0.70968
#
# Epoch:40
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78090	R:0.85802	F1:0.81765
# Opinion term	P:0.81165	R:0.84444	F1:0.82772
# pair	P:0.73098	R:0.69244	F1:0.71119
#
# Epoch:41
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78178	R:0.84774	F1:0.81343
# Opinion term	P:0.81226	R:0.85657	F1:0.83382
# pair	P:0.71809	R:0.71178	F1:0.71492
#
# Epoch:42
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.79151	R:0.84362	F1:0.81673
# Opinion term	P:0.81431	R:0.85051	F1:0.83202
# pair	P:0.70775	R:0.70650	F1:0.70712
#
# Epoch:43
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77331	R:0.87037	F1:0.81897
# Opinion term	P:0.79323	R:0.85253	F1:0.82181
# pair	P:0.70753	R:0.71002	F1:0.70877
#
# Epoch:44
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.80233	R:0.85185	F1:0.82635
# Opinion term	P:0.81226	R:0.85657	F1:0.83382
# pair	P:0.72744	R:0.70826	F1:0.71772
#
# Epoch:45
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.80116	R:0.85391	F1:0.82669
# Opinion term	P:0.81925	R:0.84242	F1:0.83068
# pair	P:0.72958	R:0.70650	F1:0.71786
#
# Epoch:46
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.80664	R:0.84979	F1:0.82766
# Opinion term	P:0.81532	R:0.83838	F1:0.82669
# pair	P:0.74579	R:0.70123	F1:0.72283
#
# Epoch:47
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.79200	R:0.81481	F1:0.80325
# Opinion term	P:0.79389	R:0.84040	F1:0.81649
# pair	P:0.73714	R:0.68014	F1:0.70750
#
# Epoch:48
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.78468	R:0.77984	F1:0.78225
# Opinion term	P:0.82020	R:0.82020	F1:0.82020
# pair	P:0.72201	R:0.65729	F1:0.68813
#
# Epoch:49
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.79119	R:0.84979	F1:0.81944
# Opinion term	P:0.80639	R:0.81616	F1:0.81124
# pair	P:0.76134	R:0.67838	F1:0.71747
#
# Epoch:50
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.77239	R:0.85185	F1:0.81018
# Opinion term	P:0.79732	R:0.84242	F1:0.81925
# pair	P:0.71429	R:0.69420	F1:0.70410
#
# Epoch:51
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.80081	R:0.81070	F1:0.80573
# Opinion term	P:0.81693	R:0.83838	F1:0.82752
# pair	P:0.72542	R:0.68717	F1:0.70578
#
# Epoch:52
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78598	R:0.85391	F1:0.81854
# Opinion term	P:0.79554	R:0.86465	F1:0.82865
# pair	P:0.71053	R:0.71178	F1:0.71115
#
# Epoch:53
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.78998	R:0.84362	F1:0.81592
# Opinion term	P:0.80952	R:0.82424	F1:0.81682
# pair	P:0.73596	R:0.69069	F1:0.71260
#
# Epoch:54
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.73712	R:0.85391	F1:0.79123
# Opinion term	P:0.79344	R:0.83030	F1:0.81145
# pair	P:0.69395	R:0.68541	F1:0.68966
#
# Epoch:55
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.76000	R:0.86008	F1:0.80695
# Opinion term	P:0.81712	R:0.84848	F1:0.83251
# pair	P:0.71324	R:0.68190	F1:0.69721
#
# Epoch:56
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78788	R:0.80247	F1:0.79511
# Opinion term	P:0.77577	R:0.86667	F1:0.81870
# pair	P:0.71165	R:0.67663	F1:0.69369
#
# Epoch:57
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78030	R:0.84774	F1:0.81262
# Opinion term	P:0.78014	R:0.88889	F1:0.83097
# pair	P:0.67758	R:0.72759	F1:0.70169
#
# Epoch:58
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.80855	R:0.81687	F1:0.81269
# Opinion term	P:0.82294	R:0.82626	F1:0.82460
# pair	P:0.74131	R:0.67487	F1:0.70653
#
# Epoch:59
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.79842	R:0.83128	F1:0.81452
# Opinion term	P:0.82377	R:0.81212	F1:0.81790
# pair	P:0.73346	R:0.68190	F1:0.70674
#
# Epoch:60
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77756	R:0.82716	F1:0.80160
# Opinion term	P:0.83537	R:0.83030	F1:0.83283
# pair	P:0.73184	R:0.69069	F1:0.71067
#
# Epoch:61
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.79116	R:0.81070	F1:0.80081
# Opinion term	P:0.82908	R:0.85253	F1:0.84064
# pair	P:0.73897	R:0.70650	F1:0.72237
#
# Epoch:62
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.79365	R:0.82305	F1:0.80808
# Opinion term	P:0.83000	R:0.83838	F1:0.83417
# pair	P:0.72232	R:0.69947	F1:0.71071
#
# Epoch:63
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77273	R:0.80453	F1:0.78831
# Opinion term	P:0.80851	R:0.84444	F1:0.82609
# pair	P:0.70072	R:0.68717	F1:0.69388
#
# Epoch:64
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.77159	R:0.82716	F1:0.79841
# Opinion term	P:0.81431	R:0.85051	F1:0.83202
# pair	P:0.71429	R:0.70299	F1:0.70859
#
# Epoch:65
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78161	R:0.83951	F1:0.80952
# Opinion term	P:0.81748	R:0.85051	F1:0.83366
# pair	P:0.74535	R:0.70475	F1:0.72448
#
# Epoch:66
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.80709	R:0.84362	F1:0.82495
# Opinion term	P:0.80474	R:0.89091	F1:0.84564
# pair	P:0.73124	R:0.73638	F1:0.73380
#
# Epoch:67
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77688	R:0.78807	F1:0.78243
# Opinion term	P:0.79623	R:0.85253	F1:0.82341
# pair	P:0.69792	R:0.70650	F1:0.70218
#
# Epoch:68
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.75479	R:0.81070	F1:0.78175
# Opinion term	P:0.83755	R:0.80202	F1:0.81940
# pair	P:0.76104	R:0.66608	F1:0.71040
#
# Epoch:69
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.80376	R:0.79218	F1:0.79793
# Opinion term	P:0.83476	R:0.78586	F1:0.80957
# pair	P:0.75420	R:0.63093	F1:0.68708
#
# Epoch:70
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.76381	R:0.82510	F1:0.79327
# Opinion term	P:0.77860	R:0.85253	F1:0.81389
# pair	P:0.68537	R:0.70826	F1:0.69663
#
# Epoch:71
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77864	R:0.82510	F1:0.80120
# Opinion term	P:0.80507	R:0.83434	F1:0.81944
# pair	P:0.69821	R:0.68717	F1:0.69265
#
# Epoch:72
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.79545	R:0.79218	F1:0.79381
# Opinion term	P:0.83570	R:0.83232	F1:0.83401
# pair	P:0.72401	R:0.67311	F1:0.69763
#
# Epoch:73
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.76938	R:0.83745	F1:0.80197
# Opinion term	P:0.82353	R:0.84848	F1:0.83582
# pair	P:0.70504	R:0.68893	F1:0.69689
#
# Epoch:74
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.75836	R:0.83951	F1:0.79688
# Opinion term	P:0.80571	R:0.85455	F1:0.82941
# pair	P:0.68729	R:0.70299	F1:0.69505
#
# Epoch:75
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78411	R:0.79218	F1:0.78813
# Opinion term	P:0.84124	R:0.82424	F1:0.83265
# pair	P:0.71940	R:0.67135	F1:0.69455
#
# Epoch:76
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.76460	R:0.86214	F1:0.81044
# Opinion term	P:0.78899	R:0.86869	F1:0.82692
# pair	P:0.67928	R:0.72583	F1:0.70178
#
# Epoch:77
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.76529	R:0.79835	F1:0.78147
# Opinion term	P:0.82178	R:0.83838	F1:0.83000
# pair	P:0.73245	R:0.67838	F1:0.70438
#
# Epoch:78
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.80041	R:0.80864	F1:0.80450
# Opinion term	P:0.83534	R:0.84040	F1:0.83787
# pair	P:0.73501	R:0.66784	F1:0.69982
#
# Epoch:79
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77299	R:0.81276	F1:0.79238
# Opinion term	P:0.81690	R:0.82020	F1:0.81855
# pair	P:0.72264	R:0.67311	F1:0.69700
#
# Epoch:80
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.76046	R:0.82305	F1:0.79051
# Opinion term	P:0.75265	R:0.86061	F1:0.80302
# pair	P:0.67993	R:0.69069	F1:0.68527
#
# Epoch:81
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.74457	R:0.84568	F1:0.79191
# Opinion term	P:0.77390	R:0.85051	F1:0.81039
# pair	P:0.68007	R:0.71353	F1:0.69640
#
# Epoch:82
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.75385	R:0.80658	F1:0.77932
# Opinion term	P:0.81128	R:0.84242	F1:0.82656
# pair	P:0.71560	R:0.68541	F1:0.70018
#
# Epoch:83
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77426	R:0.80453	F1:0.78910
# Opinion term	P:0.81637	R:0.82626	F1:0.82129
# pair	P:0.71614	R:0.67838	F1:0.69675
#
# Epoch:84
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.74731	R:0.85802	F1:0.79885
# Opinion term	P:0.78424	R:0.84444	F1:0.81323
# pair	P:0.68342	R:0.71705	F1:0.69983
#
# Epoch:85
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.78905	R:0.80041	F1:0.79469
# Opinion term	P:0.83130	R:0.82626	F1:0.82877
# pair	P:0.72243	R:0.66784	F1:0.69406
#
# Epoch:86
# 100% 158/158 [00:45<00:00,  3.49it/s]
# Aspect term	P:0.76099	R:0.81893	F1:0.78890
# Opinion term	P:0.82261	R:0.85253	F1:0.83730
# pair	P:0.70714	R:0.69596	F1:0.70151
#
# Epoch:87
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.76128	R:0.83333	F1:0.79568
# Opinion term	P:0.81359	R:0.84646	F1:0.82970
# pair	P:0.70833	R:0.68717	F1:0.69759
#
# Epoch:88
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.76996	R:0.83333	F1:0.80040
# Opinion term	P:0.83068	R:0.84242	F1:0.83651
# pair	P:0.74187	R:0.68190	F1:0.71062
#
# Epoch:89
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78423	R:0.77778	F1:0.78099
# Opinion term	P:0.80038	R:0.84242	F1:0.82087
# pair	P:0.71107	R:0.66608	F1:0.68784
#
# Epoch:90
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.76311	R:0.80864	F1:0.78521
# Opinion term	P:0.80784	R:0.83232	F1:0.81990
# pair	P:0.71186	R:0.66432	F1:0.68727
#
# Epoch:91
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77621	R:0.79218	F1:0.78411
# Opinion term	P:0.84298	R:0.82424	F1:0.83350
# pair	P:0.74510	R:0.66784	F1:0.70436
#
# Epoch:92
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.78156	R:0.80247	F1:0.79188
# Opinion term	P:0.79699	R:0.85657	F1:0.82571
# pair	P:0.69751	R:0.68893	F1:0.69319
#
# Epoch:93
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.75187	R:0.82922	F1:0.78865
# Opinion term	P:0.78947	R:0.84848	F1:0.81792
# pair	P:0.68750	R:0.69596	F1:0.69170
#
# Epoch:94
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.73985	R:0.82510	F1:0.78016
# Opinion term	P:0.78119	R:0.87273	F1:0.82443
# pair	P:0.67563	R:0.70650	F1:0.69072
#
# Epoch:95
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.77291	R:0.79835	F1:0.78543
# Opinion term	P:0.82857	R:0.82020	F1:0.82437
# pair	P:0.73438	R:0.66081	F1:0.69565
#
# Epoch:96
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.77381	R:0.80247	F1:0.78788
# Opinion term	P:0.81431	R:0.85051	F1:0.83202
# pair	P:0.72477	R:0.69420	F1:0.70916
#
# Epoch:97
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.75915	R:0.81070	F1:0.78408
# Opinion term	P:0.81333	R:0.86263	F1:0.83725
# pair	P:0.70951	R:0.70826	F1:0.70888
#
# Epoch:98
# 100% 158/158 [00:45<00:00,  3.48it/s]
# Aspect term	P:0.75828	R:0.80041	F1:0.77878
# Opinion term	P:0.81923	R:0.86061	F1:0.83941
# pair	P:0.71585	R:0.69069	F1:0.70304
#
# Epoch:99
# 100% 158/158 [00:45<00:00,  3.47it/s]
# Aspect term	P:0.75236	R:0.81893	F1:0.78424
# Opinion term	P:0.80979	R:0.86869	F1:0.83821
# pair	P:0.69844	R:0.70826	F1:0.70332
#
# best epoch: 66	best dev pair f1: 0.73380
#
#
# Evaluation on testset:
# Aspect term	P:0.79596	R:0.88118	F1:0.83640
# Opinion term	P:0.79350	R:0.89692	F1:0.84205
# pair	P:0.70605	R:0.76667	F1:0.73511

# %%
# !python main.py --task triplet --mode train --dataset res14
# Out:
# 2021-08-10 11:51:56.477492: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 158/158 [00:46<00:00,  3.39it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:1.00000	R:0.00606	F1:0.01205
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 158/158 [00:46<00:00,  3.38it/s]
# Aspect term	P:0.77902	R:0.71811	F1:0.74732
# Opinion term	P:0.81674	R:0.72929	F1:0.77054
# triplet	P:0.71875	R:0.20211	F1:0.31550
#
# Epoch:2
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77922	R:0.74074	F1:0.75949
# Opinion term	P:0.81739	R:0.75960	F1:0.78743
# triplet	P:0.70229	R:0.32337	F1:0.44284
#
# Epoch:3
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.76578	R:0.77366	F1:0.76970
# Opinion term	P:0.80200	R:0.81010	F1:0.80603
# triplet	P:0.70060	R:0.41125	F1:0.51827
#
# Epoch:4
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.75045	R:0.85391	F1:0.79885
# Opinion term	P:0.77920	R:0.86263	F1:0.81879
# triplet	P:0.64392	R:0.53076	F1:0.58189
#
# Epoch:5
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.79787	R:0.77160	F1:0.78452
# Opinion term	P:0.81542	R:0.81212	F1:0.81377
# triplet	P:0.70720	R:0.50088	F1:0.58642
#
# Epoch:6
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77318	R:0.80658	F1:0.78953
# Opinion term	P:0.83084	R:0.78384	F1:0.80665
# triplet	P:0.70531	R:0.51318	F1:0.59410
#
# Epoch:7
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.78525	R:0.74486	F1:0.76452
# Opinion term	P:0.83983	R:0.78384	F1:0.81087
# triplet	P:0.69951	R:0.49912	F1:0.58256
#
# Epoch:8
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.80046	R:0.70988	F1:0.75245
# Opinion term	P:0.79918	R:0.78788	F1:0.79349
# triplet	P:0.66106	R:0.48330	F1:0.55838
#
# Epoch:9
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.74603	R:0.87037	F1:0.80342
# Opinion term	P:0.81055	R:0.83838	F1:0.82423
# triplet	P:0.62082	R:0.58699	F1:0.60343
#
# Epoch:10
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77206	R:0.86420	F1:0.81553
# Opinion term	P:0.80347	R:0.84242	F1:0.82249
# triplet	P:0.66604	R:0.62039	F1:0.64240
#
# Epoch:11
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.80321	R:0.82305	F1:0.81301
# Opinion term	P:0.80943	R:0.83232	F1:0.82072
# triplet	P:0.66535	R:0.59402	F1:0.62767
#
# Epoch:12
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.78958	R:0.84156	F1:0.81474
# Opinion term	P:0.82669	R:0.83838	F1:0.83250
# triplet	P:0.68472	R:0.62214	F1:0.65193
#
# Epoch:13
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.76415	R:0.83333	F1:0.79724
# Opinion term	P:0.83232	R:0.83232	F1:0.83232
# triplet	P:0.66019	R:0.59754	F1:0.62731
#
# Epoch:14
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77203	R:0.82922	F1:0.79960
# Opinion term	P:0.82677	R:0.84848	F1:0.83749
# triplet	P:0.67113	R:0.61687	F1:0.64286
#
# Epoch:15
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.78405	R:0.82922	F1:0.80600
# Opinion term	P:0.83468	R:0.83636	F1:0.83552
# triplet	P:0.68317	R:0.60633	F1:0.64246
#
# Epoch:16
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.78501	R:0.81893	F1:0.80161
# Opinion term	P:0.82874	R:0.85051	F1:0.83948
# triplet	P:0.67248	R:0.60984	F1:0.63963
#
# Epoch:17
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77079	R:0.85802	F1:0.81207
# Opinion term	P:0.81961	R:0.84444	F1:0.83184
# triplet	P:0.68061	R:0.62917	F1:0.65388
#
# Epoch:18
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.78543	R:0.79835	F1:0.79184
# Opinion term	P:0.83166	R:0.83838	F1:0.83501
# triplet	P:0.66601	R:0.59578	F1:0.62894
#
# Epoch:19
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.76415	R:0.83333	F1:0.79724
# Opinion term	P:0.79231	R:0.83232	F1:0.81182
# triplet	P:0.66403	R:0.59051	F1:0.62512
#
# Epoch:20
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.76596	R:0.81481	F1:0.78963
# Opinion term	P:0.81418	R:0.85859	F1:0.83579
# triplet	P:0.63738	R:0.59930	F1:0.61775
#
# Epoch:21
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77400	R:0.79630	F1:0.78499
# Opinion term	P:0.82213	R:0.84040	F1:0.83117
# triplet	P:0.62992	R:0.56239	F1:0.59424
#
# Epoch:22
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77451	R:0.81276	F1:0.79317
# Opinion term	P:0.77860	R:0.85253	F1:0.81389
# triplet	P:0.63553	R:0.60984	F1:0.62242
#
# Epoch:23
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.78435	R:0.84568	F1:0.81386
# Opinion term	P:0.80645	R:0.85859	F1:0.83170
# triplet	P:0.64043	R:0.62917	F1:0.63475
#
# Epoch:24
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.80361	R:0.82510	F1:0.81421
# Opinion term	P:0.80502	R:0.84242	F1:0.82330
# triplet	P:0.66157	R:0.60808	F1:0.63370
#
# Epoch:25
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.80769	R:0.82099	F1:0.81429
# Opinion term	P:0.83027	R:0.82020	F1:0.82520
# triplet	P:0.68474	R:0.59930	F1:0.63918
#
# Epoch:26
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.81633	R:0.82305	F1:0.81967
# Opinion term	P:0.82087	R:0.84242	F1:0.83151
# triplet	P:0.69643	R:0.61687	F1:0.65424
#
# Epoch:27
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.80906	R:0.84568	F1:0.82696
# Opinion term	P:0.80814	R:0.84242	F1:0.82493
# triplet	P:0.67669	R:0.63269	F1:0.65395
#
# Epoch:28
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.80388	R:0.85185	F1:0.82717
# Opinion term	P:0.80732	R:0.84646	F1:0.82643
# triplet	P:0.66976	R:0.63445	F1:0.65162
#
# Epoch:29
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.80156	R:0.84774	F1:0.82400
# Opinion term	P:0.80502	R:0.84242	F1:0.82330
# triplet	P:0.65683	R:0.62566	F1:0.64086
#
# Epoch:30
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.81386	R:0.84568	F1:0.82947
# Opinion term	P:0.81729	R:0.84040	F1:0.82869
# triplet	P:0.66667	R:0.62566	F1:0.64551
#
# Epoch:31
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.79808	R:0.85391	F1:0.82505
# Opinion term	P:0.80228	R:0.85253	F1:0.82664
# triplet	P:0.67098	R:0.63796	F1:0.65405
#
# Epoch:32
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.80876	R:0.83539	F1:0.82186
# Opinion term	P:0.83333	R:0.81818	F1:0.82569
# triplet	P:0.67641	R:0.60984	F1:0.64140
#
# Epoch:33
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.81275	R:0.83951	F1:0.82591
# Opinion term	P:0.81044	R:0.84646	F1:0.82806
# triplet	P:0.66605	R:0.63445	F1:0.64986
#
# Epoch:34
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77306	R:0.86214	F1:0.81518
# Opinion term	P:0.80038	R:0.85051	F1:0.82468
# triplet	P:0.65225	R:0.63620	F1:0.64413
#
# Epoch:35
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.79843	R:0.83951	F1:0.81846
# Opinion term	P:0.82927	R:0.82424	F1:0.82675
# triplet	P:0.66601	R:0.59578	F1:0.62894
#
# Epoch:36
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.79218	R:0.79218	F1:0.79218
# Opinion term	P:0.83648	R:0.80606	F1:0.82099
# triplet	P:0.67546	R:0.58524	F1:0.62712
#
# Epoch:37
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.74690	R:0.86831	F1:0.80304
# Opinion term	P:0.80357	R:0.81818	F1:0.81081
# triplet	P:0.66790	R:0.63269	F1:0.64982
#
# Epoch:38
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.79463	R:0.85185	F1:0.82224
# Opinion term	P:0.77231	R:0.85657	F1:0.81226
# triplet	P:0.64211	R:0.64323	F1:0.64267
#
# Epoch:39
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77992	R:0.83128	F1:0.80478
# Opinion term	P:0.81874	R:0.81212	F1:0.81542
# triplet	P:0.67262	R:0.59578	F1:0.63187
#
# Epoch:40
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.76008	R:0.81481	F1:0.78649
# Opinion term	P:0.79580	R:0.84242	F1:0.81845
# triplet	P:0.62852	R:0.58875	F1:0.60799
#
# Epoch:41
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.73694	R:0.84156	F1:0.78578
# Opinion term	P:0.82495	R:0.82828	F1:0.82661
# triplet	P:0.64786	R:0.58524	F1:0.61496
#
# Epoch:42
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.75138	R:0.83951	F1:0.79300
# Opinion term	P:0.76460	R:0.87273	F1:0.81509
# triplet	P:0.60642	R:0.63093	F1:0.61843
#
# Epoch:43
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.76437	R:0.82099	F1:0.79167
# Opinion term	P:0.82520	R:0.82020	F1:0.82270
# triplet	P:0.66929	R:0.59754	F1:0.63138
#
# Epoch:44
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.79716	R:0.80864	F1:0.80286
# Opinion term	P:0.80000	R:0.84040	F1:0.81970
# triplet	P:0.65564	R:0.59227	F1:0.62235
#
# Epoch:45
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.77606	R:0.82716	F1:0.80080
# Opinion term	P:0.81092	R:0.84040	F1:0.82540
# triplet	P:0.65217	R:0.60633	F1:0.62842
#
# Epoch:46
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77524	R:0.83745	F1:0.80514
# Opinion term	P:0.81518	R:0.84646	F1:0.83053
# triplet	P:0.64440	R:0.62742	F1:0.63580
#
# Epoch:47
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.78378	R:0.83539	F1:0.80876
# Opinion term	P:0.81729	R:0.84040	F1:0.82869
# triplet	P:0.66171	R:0.62566	F1:0.64318
#
# Epoch:48
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77462	R:0.84156	F1:0.80671
# Opinion term	P:0.81925	R:0.84242	F1:0.83068
# triplet	P:0.67041	R:0.62917	F1:0.64914
#
# Epoch:49
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.76571	R:0.82716	F1:0.79525
# Opinion term	P:0.80943	R:0.83232	F1:0.82072
# triplet	P:0.64338	R:0.61511	F1:0.62893
#
# Epoch:50
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.78906	R:0.83128	F1:0.80962
# Opinion term	P:0.80153	R:0.84848	F1:0.82434
# triplet	P:0.64706	R:0.63796	F1:0.64248
#
# Epoch:51
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.77674	R:0.85185	F1:0.81256
# Opinion term	P:0.80388	R:0.83636	F1:0.81980
# triplet	P:0.63327	R:0.62214	F1:0.62766
#
# Epoch:52
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.79208	R:0.82305	F1:0.80727
# Opinion term	P:0.81336	R:0.83636	F1:0.82470
# triplet	P:0.64469	R:0.61863	F1:0.63139
#
# Epoch:53
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.74630	R:0.82922	F1:0.78558
# Opinion term	P:0.81600	R:0.82424	F1:0.82010
# triplet	P:0.63722	R:0.59578	F1:0.61580
#
# Epoch:54
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.81935	R:0.78395	F1:0.80126
# Opinion term	P:0.82341	R:0.81010	F1:0.81670
# triplet	P:0.67944	R:0.59227	F1:0.63286
#
# Epoch:55
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.77351	R:0.82922	F1:0.80040
# Opinion term	P:0.80571	R:0.85455	F1:0.82941
# triplet	P:0.63752	R:0.61511	F1:0.62612
#
# Epoch:56
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.79290	R:0.82716	F1:0.80967
# Opinion term	P:0.80190	R:0.85051	F1:0.82549
# triplet	P:0.65568	R:0.62917	F1:0.64215
#
# Epoch:57
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.78474	R:0.82510	F1:0.80441
# Opinion term	P:0.81657	R:0.83636	F1:0.82635
# triplet	P:0.65047	R:0.61160	F1:0.63043
#
# Epoch:58
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.79430	R:0.80247	F1:0.79836
# Opinion term	P:0.80777	R:0.84040	F1:0.82376
# triplet	P:0.66288	R:0.61511	F1:0.63810
#
# Epoch:59
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.78277	R:0.86008	F1:0.81961
# Opinion term	P:0.81262	R:0.85859	F1:0.83497
# triplet	P:0.63497	R:0.65729	F1:0.64594
#
# Epoch:60
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.79596	R:0.81070	F1:0.80326
# Opinion term	P:0.78868	R:0.84444	F1:0.81561
# triplet	P:0.64325	R:0.61160	F1:0.62703
#
# Epoch:61
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.79922	R:0.84362	F1:0.82082
# Opinion term	P:0.79777	R:0.86869	F1:0.83172
# triplet	P:0.64706	R:0.63796	F1:0.64248
#
# Epoch:62
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.76623	R:0.84979	F1:0.80585
# Opinion term	P:0.83065	R:0.83232	F1:0.83148
# triplet	P:0.65562	R:0.62566	F1:0.64029
#
# Epoch:63
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.76705	R:0.83333	F1:0.79882
# Opinion term	P:0.79851	R:0.86465	F1:0.83026
# triplet	P:0.63715	R:0.64499	F1:0.64105
#
# Epoch:64
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.78914	R:0.77778	F1:0.78342
# Opinion term	P:0.84026	R:0.77576	F1:0.80672
# triplet	P:0.70276	R:0.58172	F1:0.63654
#
# Epoch:65
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.77087	R:0.81687	F1:0.79321
# Opinion term	P:0.81346	R:0.85455	F1:0.83350
# triplet	P:0.64457	R:0.61511	F1:0.62950
#
# Epoch:66
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.78346	R:0.81893	F1:0.80080
# Opinion term	P:0.82495	R:0.82828	F1:0.82661
# triplet	P:0.67184	R:0.60808	F1:0.63838
#
# Epoch:67
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.78846	R:0.84362	F1:0.81511
# Opinion term	P:0.82961	R:0.82626	F1:0.82794
# triplet	P:0.66858	R:0.61336	F1:0.63978
#
# Epoch:68
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.76015	R:0.84774	F1:0.80156
# Opinion term	P:0.81783	R:0.85253	F1:0.83482
# triplet	P:0.65889	R:0.64499	F1:0.65187
#
# Epoch:69
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.75636	R:0.85597	F1:0.80309
# Opinion term	P:0.82669	R:0.83838	F1:0.83250
# triplet	P:0.66248	R:0.64851	F1:0.65542
#
# Epoch:70
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.78161	R:0.83951	F1:0.80952
# Opinion term	P:0.82400	R:0.83232	F1:0.82814
# triplet	P:0.67228	R:0.63093	F1:0.65095
#
# Epoch:71
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.78035	R:0.83333	F1:0.80597
# Opinion term	P:0.80418	R:0.85455	F1:0.82860
# triplet	P:0.65058	R:0.59227	F1:0.62006
#
# Epoch:72
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.79755	R:0.80247	F1:0.80000
# Opinion term	P:0.82051	R:0.84040	F1:0.83034
# triplet	P:0.67098	R:0.63796	F1:0.65405
#
# Epoch:73
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.74542	R:0.83745	F1:0.78876
# Opinion term	P:0.80614	R:0.84848	F1:0.82677
# triplet	P:0.61872	R:0.62742	F1:0.62304
#
# Epoch:74
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.78235	R:0.82099	F1:0.80120
# Opinion term	P:0.81548	R:0.83030	F1:0.82282
# triplet	P:0.66794	R:0.61511	F1:0.64044
#
# Epoch:75
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.77203	R:0.82922	F1:0.79960
# Opinion term	P:0.81574	R:0.85859	F1:0.83661
# triplet	P:0.67037	R:0.63620	F1:0.65284
#
# Epoch:76
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.78156	R:0.80247	F1:0.79188
# Opinion term	P:0.81042	R:0.78586	F1:0.79795
# triplet	P:0.66667	R:0.56942	F1:0.61422
#
# Epoch:77
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.78917	R:0.83951	F1:0.81356
# Opinion term	P:0.82281	R:0.81616	F1:0.81947
# triplet	P:0.63947	R:0.59227	F1:0.61496
#
# Epoch:78
# 100% 158/158 [00:46<00:00,  3.37it/s]
# Aspect term	P:0.76580	R:0.84774	F1:0.80469
# Opinion term	P:0.80906	R:0.83030	F1:0.81954
# triplet	P:0.65746	R:0.62742	F1:0.64209
#
# Epoch:79
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.82265	R:0.79218	F1:0.80713
# Opinion term	P:0.81925	R:0.84242	F1:0.83068
# triplet	P:0.67366	R:0.62039	F1:0.64593
#
# Epoch:80
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.79344	R:0.84568	F1:0.81873
# Opinion term	P:0.83162	R:0.81818	F1:0.82485
# triplet	P:0.67235	R:0.62390	F1:0.64722
#
# Epoch:81
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.81237	R:0.81070	F1:0.81153
# Opinion term	P:0.82107	R:0.83434	F1:0.82766
# triplet	P:0.65974	R:0.61336	F1:0.63570
#
# Epoch:82
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.79008	R:0.85185	F1:0.81980
# Opinion term	P:0.81524	R:0.86465	F1:0.83922
# triplet	P:0.64632	R:0.63269	F1:0.63943
#
# Epoch:83
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.83047	R:0.79630	F1:0.81303
# Opinion term	P:0.82422	R:0.85253	F1:0.83813
# triplet	P:0.70482	R:0.61687	F1:0.65792
#
# Epoch:84
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.81386	R:0.84568	F1:0.82947
# Opinion term	P:0.81836	R:0.84646	F1:0.83217
# triplet	P:0.66854	R:0.62742	F1:0.64733
#
# Epoch:85
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.79641	R:0.82099	F1:0.80851
# Opinion term	P:0.80777	R:0.84040	F1:0.82376
# triplet	P:0.67066	R:0.59051	F1:0.62804
#
# Epoch:86
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.79843	R:0.83951	F1:0.81846
# Opinion term	P:0.79922	R:0.82828	F1:0.81349
# triplet	P:0.65909	R:0.61160	F1:0.63446
#
# Epoch:87
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.79719	R:0.81687	F1:0.80691
# Opinion term	P:0.81226	R:0.85657	F1:0.83382
# triplet	P:0.66160	R:0.61160	F1:0.63562
#
# Epoch:88
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.77193	R:0.81481	F1:0.79279
# Opinion term	P:0.81200	R:0.82020	F1:0.81608
# triplet	P:0.66119	R:0.56591	F1:0.60985
#
# Epoch:89
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.78035	R:0.83333	F1:0.80597
# Opinion term	P:0.82041	R:0.81212	F1:0.81624
# triplet	P:0.66535	R:0.59402	F1:0.62767
#
# Epoch:90
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.77159	R:0.82716	F1:0.79841
# Opinion term	P:0.81909	R:0.83232	F1:0.82565
# triplet	P:0.62718	R:0.56766	F1:0.59594
#
# Epoch:91
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.76287	R:0.85391	F1:0.80583
# Opinion term	P:0.80507	R:0.83434	F1:0.81944
# triplet	P:0.64839	R:0.60281	F1:0.62477
#
# Epoch:92
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.79029	R:0.83745	F1:0.81319
# Opinion term	P:0.82661	R:0.82828	F1:0.82745
# triplet	P:0.65085	R:0.60281	F1:0.62591
#
# Epoch:93
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.76568	R:0.85391	F1:0.80739
# Opinion term	P:0.79231	R:0.83232	F1:0.81182
# triplet	P:0.62057	R:0.61511	F1:0.61783
#
# Epoch:94
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.79234	R:0.80864	F1:0.80041
# Opinion term	P:0.80039	R:0.83434	F1:0.81701
# triplet	P:0.64486	R:0.60633	F1:0.62500
#
# Epoch:95
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.79764	R:0.83539	F1:0.81608
# Opinion term	P:0.80507	R:0.83434	F1:0.81944
# triplet	P:0.65018	R:0.62390	F1:0.63677
#
# Epoch:96
# 100% 158/158 [00:46<00:00,  3.36it/s]
# Aspect term	P:0.78958	R:0.84156	F1:0.81474
# Opinion term	P:0.81746	R:0.83232	F1:0.82482
# triplet	P:0.65333	R:0.60281	F1:0.62706
#
# Epoch:97
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.77649	R:0.82922	F1:0.80199
# Opinion term	P:0.81186	R:0.80202	F1:0.80691
# triplet	P:0.63774	R:0.59402	F1:0.61510
#
# Epoch:98
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.76692	R:0.83951	F1:0.80157
# Opinion term	P:0.79537	R:0.83232	F1:0.81343
# triplet	P:0.64286	R:0.60105	F1:0.62125
#
# Epoch:99
# 100% 158/158 [00:47<00:00,  3.36it/s]
# Aspect term	P:0.75787	R:0.79218	F1:0.77465
# Opinion term	P:0.81557	R:0.80404	F1:0.80977
# triplet	P:0.60558	R:0.60984	F1:0.60771
#
# best epoch: 83	best dev triplet f1: 0.65792
#
#
# Evaluation on testset:
# Aspect term	P:0.81053	R:0.81529	F1:0.81290
# Opinion term	P:0.83019	R:0.88626	F1:0.85731
# triplet	P:0.70346	R:0.65657	F1:0.67921

# %%
# !python main.py --task pair --mode train --dataset res15
# Out:
# 2021-08-10 13:30:27.707211: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75349	R:0.79024	F1:0.77143
# Opinion term	P:0.95946	R:0.31696	F1:0.47651
# pair	P:1.00000	R:0.07595	F1:0.14118
#
# Epoch:2
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.74884	R:0.78537	F1:0.76667
# Opinion term	P:0.77027	R:0.76339	F1:0.76682
# pair	P:0.75595	R:0.53586	F1:0.62716
#
# Epoch:3
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.80663	R:0.71220	F1:0.75648
# Opinion term	P:0.78261	R:0.80357	F1:0.79295
# pair	P:0.83212	R:0.48101	F1:0.60963
#
# Epoch:4
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.83648	R:0.64878	F1:0.73077
# Opinion term	P:0.76419	R:0.78125	F1:0.77263
# pair	P:0.81061	R:0.45148	F1:0.57995
#
# Epoch:5
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75105	R:0.86829	F1:0.80543
# Opinion term	P:0.71377	R:0.87946	F1:0.78800
# pair	P:0.65234	R:0.70464	F1:0.67748
#
# Epoch:6
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.82143	R:0.78537	F1:0.80299
# Opinion term	P:0.75391	R:0.86161	F1:0.80417
# pair	P:0.74146	R:0.64135	F1:0.68778
#
# Epoch:7
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.76444	R:0.83902	F1:0.80000
# Opinion term	P:0.74254	R:0.88839	F1:0.80894
# pair	P:0.73543	R:0.69198	F1:0.71304
#
# Epoch:8
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.78788	R:0.88780	F1:0.83486
# Opinion term	P:0.78800	R:0.87946	F1:0.83122
# pair	P:0.73840	R:0.73840	F1:0.73840
#
# Epoch:9
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.75806	R:0.91707	F1:0.83002
# Opinion term	P:0.77011	R:0.89732	F1:0.82887
# pair	P:0.69173	R:0.77637	F1:0.73161
#
# Epoch:10
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.79221	R:0.89268	F1:0.83945
# Opinion term	P:0.76357	R:0.87946	F1:0.81743
# pair	P:0.68898	R:0.73840	F1:0.71283
#
# Epoch:11
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.76987	R:0.89756	F1:0.82883
# Opinion term	P:0.75969	R:0.87500	F1:0.81328
# pair	P:0.71713	R:0.75949	F1:0.73770
#
# Epoch:12
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.76271	R:0.87805	F1:0.81633
# Opinion term	P:0.75969	R:0.87500	F1:0.81328
# pair	P:0.70293	R:0.70886	F1:0.70588
#
# Epoch:13
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.76371	R:0.88293	F1:0.81900
# Opinion term	P:0.76426	R:0.89732	F1:0.82546
# pair	P:0.71721	R:0.73840	F1:0.72765
#
# Epoch:14
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.80176	R:0.88780	F1:0.84259
# Opinion term	P:0.76718	R:0.89732	F1:0.82716
# pair	P:0.73859	R:0.75105	F1:0.74477
#
# Epoch:15
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77922	R:0.87805	F1:0.82569
# Opinion term	P:0.76923	R:0.89286	F1:0.82645
# pair	P:0.70238	R:0.74684	F1:0.72393
#
# Epoch:16
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.76786	R:0.83902	F1:0.80186
# Opinion term	P:0.77953	R:0.88393	F1:0.82845
# pair	P:0.71429	R:0.71730	F1:0.71579
#
# Epoch:17
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.76423	R:0.91707	F1:0.83370
# Opinion term	P:0.69896	R:0.90179	F1:0.78752
# pair	P:0.67273	R:0.78059	F1:0.72266
#
# Epoch:18
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.78099	R:0.92195	F1:0.84564
# Opinion term	P:0.77108	R:0.85714	F1:0.81184
# pair	P:0.71255	R:0.74262	F1:0.72727
#
# Epoch:19
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.78541	R:0.89268	F1:0.83562
# Opinion term	P:0.73408	R:0.87500	F1:0.79837
# pair	P:0.69478	R:0.72996	F1:0.71193
#
# Epoch:20
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.78481	R:0.90732	F1:0.84163
# Opinion term	P:0.76863	R:0.87500	F1:0.81837
# pair	P:0.72047	R:0.77215	F1:0.74542
#
# Epoch:21
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75200	R:0.91707	F1:0.82637
# Opinion term	P:0.73801	R:0.89286	F1:0.80808
# pair	P:0.68132	R:0.78481	F1:0.72941
#
# Epoch:22
# 100% 76/76 [00:21<00:00,  3.52it/s]
# Aspect term	P:0.76824	R:0.87317	F1:0.81735
# Opinion term	P:0.76265	R:0.87500	F1:0.81497
# pair	P:0.72614	R:0.73840	F1:0.73222
#
# Epoch:23
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.79188	R:0.76098	F1:0.77612
# Opinion term	P:0.75000	R:0.84375	F1:0.79412
# pair	P:0.67123	R:0.62025	F1:0.64474
#
# Epoch:24
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77193	R:0.85854	F1:0.81293
# Opinion term	P:0.76892	R:0.86161	F1:0.81263
# pair	P:0.70445	R:0.73418	F1:0.71901
#
# Epoch:25
# 100% 76/76 [00:21<00:00,  3.52it/s]
# Aspect term	P:0.78414	R:0.86829	F1:0.82407
# Opinion term	P:0.79253	R:0.85268	F1:0.82151
# pair	P:0.75234	R:0.67932	F1:0.71397
#
# Epoch:26
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.78802	R:0.83415	F1:0.81043
# Opinion term	P:0.78814	R:0.83036	F1:0.80870
# pair	P:0.75943	R:0.67932	F1:0.71715
#
# Epoch:27
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77542	R:0.89268	F1:0.82993
# Opinion term	P:0.74902	R:0.85268	F1:0.79749
# pair	P:0.69841	R:0.74262	F1:0.71984
#
# Epoch:28
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.76754	R:0.85366	F1:0.80831
# Opinion term	P:0.73333	R:0.83482	F1:0.78079
# pair	P:0.72523	R:0.67932	F1:0.70153
#
# Epoch:29
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.78125	R:0.85366	F1:0.81585
# Opinion term	P:0.78367	R:0.85714	F1:0.81876
# pair	P:0.71861	R:0.70042	F1:0.70940
#
# Epoch:30
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.79310	R:0.89756	F1:0.84211
# Opinion term	P:0.77917	R:0.83482	F1:0.80603
# pair	P:0.71849	R:0.72152	F1:0.72000
#
# Epoch:31
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.76446	R:0.90244	F1:0.82774
# Opinion term	P:0.74713	R:0.87054	F1:0.80412
# pair	P:0.69170	R:0.73840	F1:0.71429
#
# Epoch:32
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77056	R:0.86829	F1:0.81651
# Opinion term	P:0.76744	R:0.88393	F1:0.82158
# pair	P:0.69498	R:0.75949	F1:0.72581
#
# Epoch:33
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.79730	R:0.86341	F1:0.82904
# Opinion term	P:0.77075	R:0.87054	F1:0.81761
# pair	P:0.73140	R:0.74684	F1:0.73904
#
# Epoch:34
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.76087	R:0.85366	F1:0.80460
# Opinion term	P:0.72894	R:0.88839	F1:0.80080
# pair	P:0.71489	R:0.70886	F1:0.71186
#
# Epoch:35
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.74400	R:0.90732	F1:0.81758
# Opinion term	P:0.76400	R:0.85268	F1:0.80591
# pair	P:0.70916	R:0.75105	F1:0.72951
#
# Epoch:36
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75207	R:0.88780	F1:0.81432
# Opinion term	P:0.73408	R:0.87500	F1:0.79837
# pair	P:0.67669	R:0.75949	F1:0.71571
#
# Epoch:37
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.75720	R:0.89756	F1:0.82143
# Opinion term	P:0.74525	R:0.87500	F1:0.80493
# pair	P:0.67803	R:0.75527	F1:0.71457
#
# Epoch:38
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75934	R:0.89268	F1:0.82063
# Opinion term	P:0.74713	R:0.87054	F1:0.80412
# pair	P:0.68726	R:0.75105	F1:0.71774
#
# Epoch:39
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.75820	R:0.90244	F1:0.82405
# Opinion term	P:0.74427	R:0.87054	F1:0.80247
# pair	P:0.69231	R:0.75949	F1:0.72435
#
# Epoch:40
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.74590	R:0.88780	F1:0.81069
# Opinion term	P:0.74809	R:0.87500	F1:0.80658
# pair	P:0.68077	R:0.74684	F1:0.71227
#
# Epoch:41
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75519	R:0.88780	F1:0.81614
# Opinion term	P:0.76984	R:0.86607	F1:0.81513
# pair	P:0.69960	R:0.74684	F1:0.72245
#
# Epoch:42
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.76471	R:0.88780	F1:0.82167
# Opinion term	P:0.76078	R:0.86607	F1:0.81002
# pair	P:0.70635	R:0.75105	F1:0.72802
#
# Epoch:43
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75833	R:0.88780	F1:0.81798
# Opinion term	P:0.75984	R:0.86161	F1:0.80753
# pair	P:0.70850	R:0.73840	F1:0.72314
#
# Epoch:44
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.75934	R:0.89268	F1:0.82063
# Opinion term	P:0.75581	R:0.87054	F1:0.80913
# pair	P:0.68182	R:0.75949	F1:0.71856
#
# Epoch:45
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.76033	R:0.89756	F1:0.82327
# Opinion term	P:0.75290	R:0.87054	F1:0.80745
# pair	P:0.70039	R:0.75949	F1:0.72874
#
# Epoch:46
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.75820	R:0.90244	F1:0.82405
# Opinion term	P:0.75385	R:0.87500	F1:0.80992
# pair	P:0.69202	R:0.76793	F1:0.72800
#
# Epoch:47
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.75620	R:0.89268	F1:0.81879
# Opinion term	P:0.76863	R:0.87500	F1:0.81837
# pair	P:0.72065	R:0.75105	F1:0.73554
#
# Epoch:48
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.76132	R:0.90244	F1:0.82589
# Opinion term	P:0.73063	R:0.88393	F1:0.80000
# pair	P:0.69349	R:0.76371	F1:0.72691
#
# Epoch:49
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77542	R:0.89268	F1:0.82993
# Opinion term	P:0.75875	R:0.87054	F1:0.81081
# pair	P:0.68045	R:0.76371	F1:0.71968
#
# Epoch:50
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77311	R:0.89756	F1:0.83070
# Opinion term	P:0.80342	R:0.83929	F1:0.82096
# pair	P:0.73894	R:0.70464	F1:0.72138
#
# Epoch:51
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75934	R:0.89268	F1:0.82063
# Opinion term	P:0.72519	R:0.84821	F1:0.78189
# pair	P:0.63774	R:0.71308	F1:0.67331
#
# Epoch:52
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77021	R:0.88293	F1:0.82273
# Opinion term	P:0.76210	R:0.84375	F1:0.80085
# pair	P:0.69835	R:0.71308	F1:0.70564
#
# Epoch:53
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.77872	R:0.89268	F1:0.83182
# Opinion term	P:0.74525	R:0.87500	F1:0.80493
# pair	P:0.69444	R:0.73840	F1:0.71575
#
# Epoch:54
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.77350	R:0.88293	F1:0.82460
# Opinion term	P:0.76984	R:0.86607	F1:0.81513
# pair	P:0.70850	R:0.73840	F1:0.72314
#
# Epoch:55
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.77253	R:0.87805	F1:0.82192
# Opinion term	P:0.76285	R:0.86161	F1:0.80922
# pair	P:0.70204	R:0.72574	F1:0.71369
#
# Epoch:56
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.77350	R:0.88293	F1:0.82460
# Opinion term	P:0.75000	R:0.85714	F1:0.80000
# pair	P:0.68526	R:0.72574	F1:0.70492
#
# Epoch:57
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77872	R:0.89268	F1:0.83182
# Opinion term	P:0.74903	R:0.86607	F1:0.80331
# pair	P:0.69323	R:0.73418	F1:0.71311
#
# Epoch:58
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.78448	R:0.88780	F1:0.83295
# Opinion term	P:0.76587	R:0.86161	F1:0.81092
# pair	P:0.70565	R:0.73840	F1:0.72165
#
# Epoch:59
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.77682	R:0.88293	F1:0.82648
# Opinion term	P:0.74806	R:0.86161	F1:0.80083
# pair	P:0.70161	R:0.73418	F1:0.71753
#
# Epoch:60
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.78017	R:0.88293	F1:0.82838
# Opinion term	P:0.74903	R:0.86607	F1:0.80331
# pair	P:0.69685	R:0.74684	F1:0.72098
#
# Epoch:61
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.78448	R:0.88780	F1:0.83295
# Opinion term	P:0.77823	R:0.86161	F1:0.81780
# pair	P:0.71901	R:0.73418	F1:0.72651
#
# Epoch:62
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.78355	R:0.88293	F1:0.83028
# Opinion term	P:0.78455	R:0.86161	F1:0.82128
# pair	P:0.72269	R:0.72574	F1:0.72421
#
# Epoch:63
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.78355	R:0.88293	F1:0.83028
# Opinion term	P:0.78049	R:0.85714	F1:0.81702
# pair	P:0.71545	R:0.74262	F1:0.72878
#
# Epoch:64
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.78541	R:0.89268	F1:0.83562
# Opinion term	P:0.78138	R:0.86161	F1:0.81953
# pair	P:0.72358	R:0.75105	F1:0.73706
#
# Epoch:65
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77922	R:0.87805	F1:0.82569
# Opinion term	P:0.78661	R:0.83929	F1:0.81210
# pair	P:0.72961	R:0.71730	F1:0.72340
#
# Epoch:66
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.76987	R:0.89756	F1:0.82883
# Opinion term	P:0.75984	R:0.86161	F1:0.80753
# pair	P:0.71837	R:0.74262	F1:0.73029
#
# Epoch:67
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.78788	R:0.88780	F1:0.83486
# Opinion term	P:0.76400	R:0.85268	F1:0.80591
# pair	P:0.71774	R:0.75105	F1:0.73402
#
# Epoch:68
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.77966	R:0.89756	F1:0.83447
# Opinion term	P:0.75194	R:0.86607	F1:0.80498
# pair	P:0.71371	R:0.74684	F1:0.72990
#
# Epoch:69
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.77083	R:0.90244	F1:0.83146
# Opinion term	P:0.75781	R:0.86607	F1:0.80833
# pair	P:0.70385	R:0.77215	F1:0.73642
#
# Epoch:70
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.76763	R:0.90244	F1:0.82960
# Opinion term	P:0.74903	R:0.86607	F1:0.80331
# pair	P:0.71032	R:0.75527	F1:0.73211
#
# Epoch:71
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77178	R:0.90732	F1:0.83408
# Opinion term	P:0.75000	R:0.85714	F1:0.80000
# pair	P:0.71429	R:0.75949	F1:0.73620
#
# Epoch:72
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77406	R:0.90244	F1:0.83333
# Opinion term	P:0.74708	R:0.85714	F1:0.79834
# pair	P:0.69922	R:0.75527	F1:0.72617
#
# Epoch:73
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.78070	R:0.86829	F1:0.82217
# Opinion term	P:0.75573	R:0.88393	F1:0.81481
# pair	P:0.72996	R:0.72996	F1:0.72996
#
# Epoch:74
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.78696	R:0.88293	F1:0.83218
# Opinion term	P:0.76400	R:0.85268	F1:0.80591
# pair	P:0.72199	R:0.73418	F1:0.72803
#
# Epoch:75
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.75309	R:0.89268	F1:0.81696
# Opinion term	P:0.72161	R:0.87946	F1:0.79276
# pair	P:0.64528	R:0.72152	F1:0.68127
#
# Epoch:76
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.76667	R:0.89756	F1:0.82697
# Opinion term	P:0.79167	R:0.84821	F1:0.81897
# pair	P:0.76419	R:0.73840	F1:0.75107
#
# Epoch:77
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77974	R:0.86341	F1:0.81944
# Opinion term	P:0.82870	R:0.79911	F1:0.81364
# pair	P:0.80729	R:0.65401	F1:0.72261
#
# Epoch:78
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.76526	R:0.79512	F1:0.77990
# Opinion term	P:0.75465	R:0.90625	F1:0.82353
# pair	P:0.72851	R:0.67932	F1:0.70306
#
# Epoch:79
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77974	R:0.86341	F1:0.81944
# Opinion term	P:0.74906	R:0.89286	F1:0.81466
# pair	P:0.67647	R:0.77637	F1:0.72299
#
# Epoch:80
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.70412	R:0.91707	F1:0.79661
# Opinion term	P:0.72587	R:0.83929	F1:0.77847
# pair	P:0.65079	R:0.69198	F1:0.67076
#
# Epoch:81
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75847	R:0.87317	F1:0.81179
# Opinion term	P:0.74419	R:0.85714	F1:0.79668
# pair	P:0.66031	R:0.72996	F1:0.69339
#
# Epoch:82
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77872	R:0.89268	F1:0.83182
# Opinion term	P:0.74905	R:0.87946	F1:0.80903
# pair	P:0.69141	R:0.74684	F1:0.71805
#
# Epoch:83
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.76923	R:0.87805	F1:0.82005
# Opinion term	P:0.75188	R:0.89286	F1:0.81633
# pair	P:0.70120	R:0.74262	F1:0.72131
#
# Epoch:84
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.76695	R:0.88293	F1:0.82086
# Opinion term	P:0.73962	R:0.87500	F1:0.80164
# pair	P:0.66667	R:0.74262	F1:0.70259
#
# Epoch:85
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77119	R:0.88780	F1:0.82540
# Opinion term	P:0.76654	R:0.87946	F1:0.81913
# pair	P:0.68679	R:0.76793	F1:0.72510
#
# Epoch:86
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.77682	R:0.88293	F1:0.82648
# Opinion term	P:0.77689	R:0.87054	F1:0.82105
# pair	P:0.71200	R:0.75105	F1:0.73101
#
# Epoch:87
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.77682	R:0.88293	F1:0.82648
# Opinion term	P:0.77912	R:0.86607	F1:0.82030
# pair	P:0.73029	R:0.74262	F1:0.73640
#
# Epoch:88
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.77876	R:0.85854	F1:0.81671
# Opinion term	P:0.73485	R:0.86607	F1:0.79508
# pair	P:0.69388	R:0.71730	F1:0.70539
#
# Epoch:89
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75949	R:0.87805	F1:0.81448
# Opinion term	P:0.71536	R:0.85268	F1:0.77800
# pair	P:0.64684	R:0.73418	F1:0.68775
#
# Epoch:90
# 100% 76/76 [00:21<00:00,  3.48it/s]
# Aspect term	P:0.78070	R:0.86829	F1:0.82217
# Opinion term	P:0.77733	R:0.85714	F1:0.81529
# pair	P:0.67568	R:0.73840	F1:0.70565
#
# Epoch:91
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.78319	R:0.86341	F1:0.82135
# Opinion term	P:0.76892	R:0.86161	F1:0.81263
# pair	P:0.67442	R:0.73418	F1:0.70303
#
# Epoch:92
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.77253	R:0.87805	F1:0.82192
# Opinion term	P:0.75781	R:0.86607	F1:0.80833
# pair	P:0.69170	R:0.73840	F1:0.71429
#
# Epoch:93
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.78027	R:0.84878	F1:0.81308
# Opinion term	P:0.72015	R:0.86161	F1:0.78455
# pair	P:0.65038	R:0.72996	F1:0.68787
#
# Epoch:94
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.75620	R:0.89268	F1:0.81879
# Opinion term	P:0.73783	R:0.87946	F1:0.80244
# pair	P:0.66421	R:0.75949	F1:0.70866
#
# Epoch:95
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.75847	R:0.87317	F1:0.81179
# Opinion term	P:0.73308	R:0.87054	F1:0.79592
# pair	P:0.65056	R:0.73840	F1:0.69170
#
# Epoch:96
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.76754	R:0.85366	F1:0.80831
# Opinion term	P:0.68401	R:0.82143	F1:0.74645
# pair	P:0.64706	R:0.69620	F1:0.67073
#
# Epoch:97
# 100% 76/76 [00:21<00:00,  3.49it/s]
# Aspect term	P:0.75833	R:0.88780	F1:0.81798
# Opinion term	P:0.73384	R:0.86161	F1:0.79261
# pair	P:0.66288	R:0.73840	F1:0.69860
#
# Epoch:98
# 100% 76/76 [00:21<00:00,  3.50it/s]
# Aspect term	P:0.75000	R:0.87805	F1:0.80899
# Opinion term	P:0.76707	R:0.85268	F1:0.80761
# pair	P:0.70886	R:0.70886	F1:0.70886
#
# Epoch:99
# 100% 76/76 [00:21<00:00,  3.51it/s]
# Aspect term	P:0.75304	R:0.90732	F1:0.82301
# Opinion term	P:0.74340	R:0.87946	F1:0.80573
# pair	P:0.67537	R:0.76371	F1:0.71683
#
# best epoch: 76	best dev pair f1: 0.75107
#
#
# Evaluation on testset:
# Aspect term	P:0.75424	R:0.81651	F1:0.78414
# Opinion term	P:0.78468	R:0.81681	F1:0.80042
# pair	P:0.69651	R:0.65235	F1:0.67371

# %%
# !python main.py --task triplet --mode train --dataset res15
# Out:
# 2021-08-10 14:12:50.422112: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 76/76 [00:22<00:00,  3.44it/s]
# Aspect term	P:0.80000	R:0.15610	F1:0.26122
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.82911	R:0.63902	F1:0.72176
# Opinion term	P:0.79894	R:0.67411	F1:0.73123
# triplet	P:0.63636	R:0.17722	F1:0.27723
#
# Epoch:2
# 100% 76/76 [00:22<00:00,  3.44it/s]
# Aspect term	P:0.78836	R:0.72683	F1:0.75635
# Opinion term	P:0.82222	R:0.49554	F1:0.61838
# triplet	P:0.74194	R:0.19409	F1:0.30769
#
# Epoch:3
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.77130	R:0.83902	F1:0.80374
# Opinion term	P:0.76796	R:0.62054	F1:0.68642
# triplet	P:0.76042	R:0.30802	F1:0.43844
#
# Epoch:4
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.78947	R:0.87805	F1:0.83141
# Opinion term	P:0.77959	R:0.85268	F1:0.81450
# triplet	P:0.71649	R:0.58650	F1:0.64501
#
# Epoch:5
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.78070	R:0.86829	F1:0.82217
# Opinion term	P:0.73408	R:0.87500	F1:0.79837
# triplet	P:0.70000	R:0.59072	F1:0.64073
#
# Epoch:6
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.77273	R:0.91220	F1:0.83669
# Opinion term	P:0.67354	R:0.87500	F1:0.76117
# triplet	P:0.60558	R:0.64135	F1:0.62295
#
# Epoch:7
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.80275	R:0.85366	F1:0.82742
# Opinion term	P:0.81696	R:0.81696	F1:0.81696
# triplet	P:0.72165	R:0.59072	F1:0.64965
#
# Epoch:8
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.71984	R:0.90244	F1:0.80087
# Opinion term	P:0.69310	R:0.89732	F1:0.78210
# triplet	P:0.61132	R:0.68354	F1:0.64542
#
# Epoch:9
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.79111	R:0.86829	F1:0.82791
# Opinion term	P:0.72491	R:0.87054	F1:0.79108
# triplet	P:0.64557	R:0.64557	F1:0.64557
#
# Epoch:10
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.78319	R:0.86341	F1:0.82135
# Opinion term	P:0.77778	R:0.84375	F1:0.80942
# triplet	P:0.64583	R:0.65401	F1:0.64990
#
# Epoch:11
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.78448	R:0.88780	F1:0.83295
# Opinion term	P:0.73684	R:0.87500	F1:0.80000
# triplet	P:0.63008	R:0.65401	F1:0.64182
#
# Epoch:12
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.78571	R:0.85854	F1:0.82051
# Opinion term	P:0.74800	R:0.83482	F1:0.78903
# triplet	P:0.69014	R:0.62025	F1:0.65333
#
# Epoch:13
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.79452	R:0.84878	F1:0.82075
# Opinion term	P:0.75309	R:0.81696	F1:0.78373
# triplet	P:0.68116	R:0.59494	F1:0.63514
#
# Epoch:14
# 100% 76/76 [00:22<00:00,  3.44it/s]
# Aspect term	P:0.77922	R:0.87805	F1:0.82569
# Opinion term	P:0.76285	R:0.86161	F1:0.80922
# triplet	P:0.66809	R:0.66245	F1:0.66525
#
# Epoch:15
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.77533	R:0.85854	F1:0.81481
# Opinion term	P:0.75094	R:0.88839	F1:0.81391
# triplet	P:0.64876	R:0.66245	F1:0.65553
#
# Epoch:16
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.77253	R:0.87805	F1:0.82192
# Opinion term	P:0.69625	R:0.91071	F1:0.78917
# triplet	P:0.61390	R:0.67089	F1:0.64113
#
# Epoch:17
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.77974	R:0.86341	F1:0.81944
# Opinion term	P:0.75494	R:0.85268	F1:0.80084
# triplet	P:0.63675	R:0.62869	F1:0.63270
#
# Epoch:18
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.79111	R:0.86829	F1:0.82791
# Opinion term	P:0.77215	R:0.81696	F1:0.79393
# triplet	P:0.65333	R:0.62025	F1:0.63636
#
# Epoch:19
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.74704	R:0.92195	F1:0.82533
# Opinion term	P:0.75769	R:0.87946	F1:0.81405
# triplet	P:0.67234	R:0.66667	F1:0.66949
#
# Epoch:20
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.80995	R:0.87317	F1:0.84038
# Opinion term	P:0.76033	R:0.82143	F1:0.78970
# triplet	P:0.67136	R:0.60338	F1:0.63556
#
# Epoch:21
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.78509	R:0.87317	F1:0.82679
# Opinion term	P:0.76984	R:0.86607	F1:0.81513
# triplet	P:0.66667	R:0.64135	F1:0.65376
#
# Epoch:22
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.78298	R:0.89756	F1:0.83636
# Opinion term	P:0.72242	R:0.90625	F1:0.80396
# triplet	P:0.64372	R:0.67089	F1:0.65702
#
# Epoch:23
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.71915	R:0.82439	F1:0.76818
# Opinion term	P:0.74704	R:0.84375	F1:0.79245
# triplet	P:0.59836	R:0.61603	F1:0.60707
#
# Epoch:24
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.80184	R:0.84878	F1:0.82464
# Opinion term	P:0.81532	R:0.80804	F1:0.81166
# triplet	P:0.70984	R:0.57806	F1:0.63721
#
# Epoch:25
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.79646	R:0.87805	F1:0.83527
# Opinion term	P:0.76190	R:0.85714	F1:0.80672
# triplet	P:0.66087	R:0.64135	F1:0.65096
#
# Epoch:26
# 100% 76/76 [00:22<00:00,  3.44it/s]
# Aspect term	P:0.78355	R:0.88293	F1:0.83028
# Opinion term	P:0.74157	R:0.88393	F1:0.80652
# triplet	P:0.63306	R:0.66245	F1:0.64742
#
# Epoch:27
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.79565	R:0.89268	F1:0.84138
# Opinion term	P:0.75000	R:0.85714	F1:0.80000
# triplet	P:0.64228	R:0.66667	F1:0.65424
#
# Epoch:28
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.78059	R:0.90244	F1:0.83710
# Opinion term	P:0.74525	R:0.87500	F1:0.80493
# triplet	P:0.64567	R:0.69198	F1:0.66802
#
# Epoch:29
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.77083	R:0.90244	F1:0.83146
# Opinion term	P:0.74525	R:0.87500	F1:0.80493
# triplet	P:0.63281	R:0.68354	F1:0.65720
#
# Epoch:30
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.81416	R:0.89756	F1:0.85383
# Opinion term	P:0.77075	R:0.87054	F1:0.81761
# triplet	P:0.67347	R:0.69620	F1:0.68465
#
# Epoch:31
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.76423	R:0.91707	F1:0.83370
# Opinion term	P:0.73606	R:0.88393	F1:0.80325
# triplet	P:0.62687	R:0.70886	F1:0.66535
#
# Epoch:32
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.75833	R:0.88780	F1:0.81798
# Opinion term	P:0.75194	R:0.86607	F1:0.80498
# triplet	P:0.62151	R:0.65823	F1:0.63934
#
# Epoch:33
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.79039	R:0.88293	F1:0.83410
# Opinion term	P:0.75194	R:0.86607	F1:0.80498
# triplet	P:0.64228	R:0.66667	F1:0.65424
#
# Epoch:34
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.79646	R:0.87805	F1:0.83527
# Opinion term	P:0.75290	R:0.87054	F1:0.80745
# triplet	P:0.62800	R:0.66245	F1:0.64476
#
# Epoch:35
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.79386	R:0.88293	F1:0.83603
# Opinion term	P:0.75191	R:0.87946	F1:0.81070
# triplet	P:0.64754	R:0.66667	F1:0.65696
#
# Epoch:36
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.79204	R:0.87317	F1:0.83063
# Opinion term	P:0.75781	R:0.86607	F1:0.80833
# triplet	P:0.65289	R:0.66667	F1:0.65971
#
# Epoch:37
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.78448	R:0.88780	F1:0.83295
# Opinion term	P:0.76062	R:0.87946	F1:0.81573
# triplet	P:0.66255	R:0.67932	F1:0.67083
#
# Epoch:38
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.78261	R:0.87805	F1:0.82759
# Opinion term	P:0.75494	R:0.85268	F1:0.80084
# triplet	P:0.65432	R:0.67089	F1:0.66250
#
# Epoch:39
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.70565	R:0.85366	F1:0.77263
# Opinion term	P:0.76471	R:0.87054	F1:0.81420
# triplet	P:0.61811	R:0.66245	F1:0.63951
#
# Epoch:40
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.77447	R:0.88780	F1:0.82727
# Opinion term	P:0.72101	R:0.88839	F1:0.79600
# triplet	P:0.60448	R:0.68354	F1:0.64158
#
# Epoch:41
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.79646	R:0.87805	F1:0.83527
# Opinion term	P:0.75573	R:0.88393	F1:0.81481
# triplet	P:0.61811	R:0.66245	F1:0.63951
#
# Epoch:42
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.78319	R:0.86341	F1:0.82135
# Opinion term	P:0.75385	R:0.87500	F1:0.80992
# triplet	P:0.62249	R:0.65401	F1:0.63786
#
# Epoch:43
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.76230	R:0.90732	F1:0.82851
# Opinion term	P:0.76448	R:0.88393	F1:0.81988
# triplet	P:0.63035	R:0.68354	F1:0.65587
#
# Epoch:44
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.79646	R:0.87805	F1:0.83527
# Opinion term	P:0.76357	R:0.87946	F1:0.81743
# triplet	P:0.63855	R:0.67089	F1:0.65432
#
# Epoch:45
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.77922	R:0.87805	F1:0.82569
# Opinion term	P:0.75191	R:0.87946	F1:0.81070
# triplet	P:0.64463	R:0.65823	F1:0.65136
#
# Epoch:46
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.77215	R:0.89268	F1:0.82805
# Opinion term	P:0.77519	R:0.89286	F1:0.82988
# triplet	P:0.63462	R:0.69620	F1:0.66398
#
# Epoch:47
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.78696	R:0.88293	F1:0.83218
# Opinion term	P:0.72426	R:0.87946	F1:0.79435
# triplet	P:0.63008	R:0.65401	F1:0.64182
#
# Epoch:48
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.76496	R:0.87317	F1:0.81549
# Opinion term	P:0.76628	R:0.89286	F1:0.82474
# triplet	P:0.63934	R:0.65823	F1:0.64865
#
# Epoch:49
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.77922	R:0.87805	F1:0.82569
# Opinion term	P:0.73529	R:0.89286	F1:0.80645
# triplet	P:0.62548	R:0.68354	F1:0.65323
#
# Epoch:50
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.79295	R:0.87805	F1:0.83333
# Opinion term	P:0.75285	R:0.88393	F1:0.81314
# triplet	P:0.61597	R:0.68354	F1:0.64800
#
# Epoch:51
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.76763	R:0.90244	F1:0.82960
# Opinion term	P:0.74349	R:0.89286	F1:0.81136
# triplet	P:0.61742	R:0.68776	F1:0.65070
#
# Epoch:52
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.79487	R:0.90732	F1:0.84738
# Opinion term	P:0.75188	R:0.89286	F1:0.81633
# triplet	P:0.63258	R:0.70464	F1:0.66667
#
# Epoch:53
# 100% 76/76 [00:22<00:00,  3.44it/s]
# Aspect term	P:0.77178	R:0.90732	F1:0.83408
# Opinion term	P:0.69444	R:0.89286	F1:0.78125
# triplet	P:0.56314	R:0.69620	F1:0.62264
#
# Epoch:54
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.81532	R:0.88293	F1:0.84778
# Opinion term	P:0.74621	R:0.87946	F1:0.80738
# triplet	P:0.63035	R:0.68354	F1:0.65587
#
# Epoch:55
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.77824	R:0.90732	F1:0.83784
# Opinion term	P:0.74609	R:0.85268	F1:0.79583
# triplet	P:0.64315	R:0.65401	F1:0.64854
#
# Epoch:56
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.79039	R:0.88293	F1:0.83410
# Opinion term	P:0.74427	R:0.87054	F1:0.80247
# triplet	P:0.63200	R:0.66667	F1:0.64887
#
# Epoch:57
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.72996	R:0.84390	F1:0.78281
# Opinion term	P:0.72963	R:0.87946	F1:0.79757
# triplet	P:0.58704	R:0.61181	F1:0.59917
#
# Epoch:58
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.80889	R:0.88780	F1:0.84651
# Opinion term	P:0.76518	R:0.84375	F1:0.80255
# triplet	P:0.63934	R:0.65823	F1:0.64865
#
# Epoch:59
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.83500	R:0.81463	F1:0.82469
# Opinion term	P:0.76984	R:0.86607	F1:0.81513
# triplet	P:0.66968	R:0.62447	F1:0.64629
#
# Epoch:60
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.77778	R:0.85366	F1:0.81395
# Opinion term	P:0.75191	R:0.87946	F1:0.81070
# triplet	P:0.63374	R:0.64979	F1:0.64167
#
# Epoch:61
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.75847	R:0.87317	F1:0.81179
# Opinion term	P:0.75969	R:0.87500	F1:0.81328
# triplet	P:0.60643	R:0.63713	F1:0.62140
#
# Epoch:62
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.76596	R:0.87805	F1:0.81818
# Opinion term	P:0.71786	R:0.89732	F1:0.79762
# triplet	P:0.61004	R:0.66667	F1:0.63710
#
# Epoch:63
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.78475	R:0.85366	F1:0.81776
# Opinion term	P:0.74809	R:0.87500	F1:0.80658
# triplet	P:0.64000	R:0.67511	F1:0.65708
#
# Epoch:64
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.76682	R:0.83415	F1:0.79907
# Opinion term	P:0.75094	R:0.88839	F1:0.81391
# triplet	P:0.64198	R:0.65823	F1:0.65000
#
# Epoch:65
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.79091	R:0.84878	F1:0.81882
# Opinion term	P:0.75564	R:0.89732	F1:0.82041
# triplet	P:0.64372	R:0.67089	F1:0.65702
#
# Epoch:66
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.77273	R:0.82927	F1:0.80000
# Opinion term	P:0.75000	R:0.87054	F1:0.80579
# triplet	P:0.62602	R:0.64979	F1:0.63768
#
# Epoch:67
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.77434	R:0.85366	F1:0.81206
# Opinion term	P:0.74340	R:0.87946	F1:0.80573
# triplet	P:0.61660	R:0.65823	F1:0.63673
#
# Epoch:68
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.79263	R:0.83902	F1:0.81517
# Opinion term	P:0.74632	R:0.90625	F1:0.81855
# triplet	P:0.64463	R:0.65823	F1:0.65136
#
# Epoch:69
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.77533	R:0.85854	F1:0.81481
# Opinion term	P:0.73978	R:0.88839	F1:0.80730
# triplet	P:0.63636	R:0.67932	F1:0.65714
#
# Epoch:70
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.75214	R:0.85854	F1:0.80182
# Opinion term	P:0.73529	R:0.89286	F1:0.80645
# triplet	P:0.66102	R:0.65823	F1:0.65962
#
# Epoch:71
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.75862	R:0.85854	F1:0.80549
# Opinion term	P:0.77236	R:0.84821	F1:0.80851
# triplet	P:0.61600	R:0.64979	F1:0.63244
#
# Epoch:72
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.76522	R:0.85854	F1:0.80920
# Opinion term	P:0.77432	R:0.88839	F1:0.82744
# triplet	P:0.64173	R:0.68776	F1:0.66395
#
# Epoch:73
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.75652	R:0.84878	F1:0.80000
# Opinion term	P:0.76336	R:0.89286	F1:0.82305
# triplet	P:0.64490	R:0.66667	F1:0.65560
#
# Epoch:74
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.73663	R:0.87317	F1:0.79911
# Opinion term	P:0.76448	R:0.88393	F1:0.81988
# triplet	P:0.62548	R:0.68354	F1:0.65323
#
# Epoch:75
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.76106	R:0.83902	F1:0.79814
# Opinion term	P:0.76136	R:0.89732	F1:0.82377
# triplet	P:0.65182	R:0.67932	F1:0.66529
#
# Epoch:76
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.75000	R:0.84878	F1:0.79634
# Opinion term	P:0.76226	R:0.90179	F1:0.82618
# triplet	P:0.62308	R:0.68354	F1:0.65191
#
# Epoch:77
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.76395	R:0.86829	F1:0.81279
# Opinion term	P:0.77866	R:0.87946	F1:0.82600
# triplet	P:0.63745	R:0.67511	F1:0.65574
#
# Epoch:78
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.79263	R:0.83902	F1:0.81517
# Opinion term	P:0.78049	R:0.85714	F1:0.81702
# triplet	P:0.66094	R:0.64979	F1:0.65532
#
# Epoch:79
# 100% 76/76 [00:22<00:00,  3.40it/s]
# Aspect term	P:0.77682	R:0.88293	F1:0.82648
# Opinion term	P:0.79832	R:0.84821	F1:0.82251
# triplet	P:0.67227	R:0.67511	F1:0.67368
#
# Epoch:80
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.76522	R:0.85854	F1:0.80920
# Opinion term	P:0.76955	R:0.83482	F1:0.80086
# triplet	P:0.64831	R:0.64557	F1:0.64693
#
# Epoch:81
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.75641	R:0.86341	F1:0.80638
# Opinion term	P:0.74319	R:0.85268	F1:0.79418
# triplet	P:0.62651	R:0.65823	F1:0.64198
#
# Epoch:82
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.74694	R:0.89268	F1:0.81333
# Opinion term	P:0.75285	R:0.88393	F1:0.81314
# triplet	P:0.61654	R:0.69198	F1:0.65209
#
# Epoch:83
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.75949	R:0.87805	F1:0.81448
# Opinion term	P:0.76494	R:0.85714	F1:0.80842
# triplet	P:0.65000	R:0.65823	F1:0.65409
#
# Epoch:84
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.77533	R:0.85854	F1:0.81481
# Opinion term	P:0.73864	R:0.87054	F1:0.79918
# triplet	P:0.61826	R:0.62869	F1:0.62343
#
# Epoch:85
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.76419	R:0.85366	F1:0.80645
# Opinion term	P:0.75385	R:0.87500	F1:0.80992
# triplet	P:0.61479	R:0.66667	F1:0.63968
#
# Epoch:86
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.76856	R:0.85854	F1:0.81106
# Opinion term	P:0.70922	R:0.89286	F1:0.79051
# triplet	P:0.59124	R:0.68354	F1:0.63405
#
# Epoch:87
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.78222	R:0.85854	F1:0.81860
# Opinion term	P:0.74436	R:0.88393	F1:0.80816
# triplet	P:0.61719	R:0.66667	F1:0.64097
#
# Epoch:88
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.73307	R:0.89756	F1:0.80702
# Opinion term	P:0.73978	R:0.88839	F1:0.80730
# triplet	P:0.59058	R:0.68776	F1:0.63548
#
# Epoch:89
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.70930	R:0.89268	F1:0.79050
# Opinion term	P:0.67808	R:0.88393	F1:0.76744
# triplet	P:0.52922	R:0.68776	F1:0.59817
#
# Epoch:90
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.75745	R:0.86829	F1:0.80909
# Opinion term	P:0.75769	R:0.87946	F1:0.81405
# triplet	P:0.61765	R:0.62025	F1:0.61895
#
# Epoch:91
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.76471	R:0.88780	F1:0.82167
# Opinion term	P:0.74532	R:0.88839	F1:0.81059
# triplet	P:0.61603	R:0.61603	F1:0.61603
#
# Epoch:92
# 100% 76/76 [00:22<00:00,  3.40it/s]
# Aspect term	P:0.77489	R:0.87317	F1:0.82110
# Opinion term	P:0.72794	R:0.88393	F1:0.79839
# triplet	P:0.61089	R:0.66245	F1:0.63563
#
# Epoch:93
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.74894	R:0.85854	F1:0.80000
# Opinion term	P:0.80252	R:0.85268	F1:0.82684
# triplet	P:0.62195	R:0.64557	F1:0.63354
#
# Epoch:94
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.78166	R:0.87317	F1:0.82488
# Opinion term	P:0.76829	R:0.84375	F1:0.80426
# triplet	P:0.58397	R:0.64557	F1:0.61323
#
# Epoch:95
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.77632	R:0.86341	F1:0.81755
# Opinion term	P:0.76078	R:0.86607	F1:0.81002
# triplet	P:0.65086	R:0.63713	F1:0.64392
#
# Epoch:96
# 100% 76/76 [00:22<00:00,  3.42it/s]
# Aspect term	P:0.76891	R:0.89268	F1:0.82619
# Opinion term	P:0.72963	R:0.87946	F1:0.79757
# triplet	P:0.61069	R:0.67511	F1:0.64128
#
# Epoch:97
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.75934	R:0.89268	F1:0.82063
# Opinion term	P:0.75984	R:0.86161	F1:0.80753
# triplet	P:0.60755	R:0.67932	F1:0.64143
#
# Epoch:98
# 100% 76/76 [00:22<00:00,  3.41it/s]
# Aspect term	P:0.76793	R:0.88780	F1:0.82353
# Opinion term	P:0.73408	R:0.87500	F1:0.79837
# triplet	P:0.60150	R:0.67511	F1:0.63618
#
# Epoch:99
# 100% 76/76 [00:22<00:00,  3.43it/s]
# Aspect term	P:0.76151	R:0.88780	F1:0.81982
# Opinion term	P:0.73962	R:0.87500	F1:0.80164
# triplet	P:0.60385	R:0.66245	F1:0.63179
#
# best epoch: 30	best dev triplet f1: 0.68465
#
#
# Evaluation on testset:
# Aspect term	P:0.75375	R:0.80734	F1:0.77962
# Opinion term	P:0.75098	R:0.82543	F1:0.78645
# triplet	P:0.59175	R:0.58691	F1:0.58932

# %%
# !python main.py --task pair --mode train --dataset res16
# Out:
# 2021-08-10 14:57:34.337456: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 108/108 [00:31<00:00,  3.48it/s]
# Aspect term	P:0.78070	R:0.29866	F1:0.43204
# Opinion term	P:0.89109	R:0.27523	F1:0.42056
# pair	P:0.88462	R:0.06686	F1:0.12432
#
# Epoch:1
# 100% 108/108 [00:31<00:00,  3.47it/s]
# Aspect term	P:0.77365	R:0.76846	F1:0.77104
# Opinion term	P:0.75931	R:0.81040	F1:0.78402
# pair	P:0.71315	R:0.52035	F1:0.60168
#
# Epoch:2
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.78086	R:0.84899	F1:0.81350
# Opinion term	P:0.76796	R:0.85015	F1:0.80697
# pair	P:0.75601	R:0.63953	F1:0.69291
#
# Epoch:3
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.78248	R:0.86913	F1:0.82353
# Opinion term	P:0.78632	R:0.84404	F1:0.81416
# pair	P:0.74919	R:0.66860	F1:0.70661
#
# Epoch:4
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.74328	R:0.83557	F1:0.78673
# Opinion term	P:0.77183	R:0.83792	F1:0.80352
# pair	P:0.65994	R:0.66570	F1:0.66281
#
# Epoch:5
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.78788	R:0.87248	F1:0.82803
# Opinion term	P:0.77384	R:0.86850	F1:0.81844
# pair	P:0.70056	R:0.72093	F1:0.71060
#
# Epoch:6
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.77936	R:0.73490	F1:0.75648
# Opinion term	P:0.80428	R:0.80428	F1:0.80428
# pair	P:0.74539	R:0.58721	F1:0.65691
#
# Epoch:7
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.71858	R:0.88255	F1:0.79217
# Opinion term	P:0.75578	R:0.89908	F1:0.82123
# pair	P:0.72012	R:0.71802	F1:0.71907
#
# Epoch:8
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.77035	R:0.88926	F1:0.82555
# Opinion term	P:0.76330	R:0.87768	F1:0.81650
# pair	P:0.67632	R:0.74709	F1:0.70994
#
# Epoch:9
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.74788	R:0.88591	F1:0.81106
# Opinion term	P:0.76800	R:0.88073	F1:0.82051
# pair	P:0.70300	R:0.75000	F1:0.72574
#
# Epoch:10
# 100% 108/108 [00:31<00:00,  3.47it/s]
# Aspect term	P:0.75575	R:0.88255	F1:0.81424
# Opinion term	P:0.76064	R:0.87462	F1:0.81366
# pair	P:0.65729	R:0.74709	F1:0.69932
#
# Epoch:11
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.76812	R:0.88926	F1:0.82426
# Opinion term	P:0.77838	R:0.88073	F1:0.82640
# pair	P:0.69519	R:0.75581	F1:0.72423
#
# Epoch:12
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.75070	R:0.89933	F1:0.81832
# Opinion term	P:0.72167	R:0.89602	F1:0.79945
# pair	P:0.64865	R:0.76744	F1:0.70306
#
# Epoch:13
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.74286	R:0.87248	F1:0.80247
# Opinion term	P:0.77568	R:0.87768	F1:0.82353
# pair	P:0.68649	R:0.73837	F1:0.71148
#
# Epoch:14
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.77910	R:0.87584	F1:0.82464
# Opinion term	P:0.80398	R:0.86544	F1:0.83358
# pair	P:0.73451	R:0.72384	F1:0.72914
#
# Epoch:15
# 100% 108/108 [00:31<00:00,  3.47it/s]
# Aspect term	P:0.74359	R:0.87584	F1:0.80431
# Opinion term	P:0.77089	R:0.87462	F1:0.81948
# pair	P:0.69890	R:0.73547	F1:0.71671
#
# Epoch:16
# 100% 108/108 [00:31<00:00,  3.47it/s]
# Aspect term	P:0.74022	R:0.88926	F1:0.80793
# Opinion term	P:0.78409	R:0.84404	F1:0.81296
# pair	P:0.69679	R:0.69477	F1:0.69578
#
# Epoch:17
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.77545	R:0.86913	F1:0.81962
# Opinion term	P:0.76267	R:0.87462	F1:0.81481
# pair	P:0.68108	R:0.73256	F1:0.70588
#
# Epoch:18
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.72299	R:0.87584	F1:0.79211
# Opinion term	P:0.75526	R:0.87768	F1:0.81188
# pair	P:0.65873	R:0.72384	F1:0.68975
#
# Epoch:19
# 100% 108/108 [00:31<00:00,  3.47it/s]
# Aspect term	P:0.76608	R:0.87919	F1:0.81875
# Opinion term	P:0.78237	R:0.86850	F1:0.82319
# pair	P:0.66842	R:0.73837	F1:0.70166
#
# Epoch:20
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.74510	R:0.89262	F1:0.81221
# Opinion term	P:0.78415	R:0.87768	F1:0.82828
# pair	P:0.67430	R:0.77035	F1:0.71913
#
# Epoch:21
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.73407	R:0.88926	F1:0.80425
# Opinion term	P:0.76378	R:0.88991	F1:0.82203
# pair	P:0.64477	R:0.77035	F1:0.70199
#
# Epoch:22
# 100% 108/108 [00:31<00:00,  3.47it/s]
# Aspect term	P:0.72603	R:0.88926	F1:0.79940
# Opinion term	P:0.71117	R:0.89602	F1:0.79296
# pair	P:0.61174	R:0.78779	F1:0.68869
#
# Epoch:23
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.72554	R:0.89597	F1:0.80180
# Opinion term	P:0.77957	R:0.88685	F1:0.82976
# pair	P:0.68653	R:0.77035	F1:0.72603
#
# Epoch:24
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.74157	R:0.88591	F1:0.80734
# Opinion term	P:0.80282	R:0.87156	F1:0.83578
# pair	P:0.70300	R:0.75000	F1:0.72574
#
# Epoch:25
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.74148	R:0.87584	F1:0.80308
# Opinion term	P:0.79167	R:0.87156	F1:0.82969
# pair	P:0.67010	R:0.75581	F1:0.71038
#
# Epoch:26
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.76608	R:0.87919	F1:0.81875
# Opinion term	P:0.76139	R:0.86850	F1:0.81143
# pair	P:0.67532	R:0.75581	F1:0.71331
#
# Epoch:27
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.75931	R:0.88926	F1:0.81917
# Opinion term	P:0.78630	R:0.87768	F1:0.82948
# pair	P:0.69945	R:0.74419	F1:0.72113
#
# Epoch:28
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.77745	R:0.87919	F1:0.82520
# Opinion term	P:0.79552	R:0.86850	F1:0.83041
# pair	P:0.70380	R:0.75291	F1:0.72753
#
# Epoch:29
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.76968	R:0.88591	F1:0.82371
# Opinion term	P:0.78202	R:0.87768	F1:0.82709
# pair	P:0.70027	R:0.76744	F1:0.73232
#
# Epoch:30
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.75287	R:0.87919	F1:0.81115
# Opinion term	P:0.79552	R:0.86850	F1:0.83041
# pair	P:0.70541	R:0.75872	F1:0.73109
#
# Epoch:31
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.77219	R:0.87584	F1:0.82075
# Opinion term	P:0.79339	R:0.88073	F1:0.83478
# pair	P:0.69895	R:0.77616	F1:0.73554
#
# Epoch:32
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.73481	R:0.89262	F1:0.80606
# Opinion term	P:0.79890	R:0.88685	F1:0.84058
# pair	P:0.70106	R:0.77035	F1:0.73407
#
# Epoch:33
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.76590	R:0.88926	F1:0.82298
# Opinion term	P:0.78167	R:0.88685	F1:0.83095
# pair	P:0.69870	R:0.78198	F1:0.73800
#
# Epoch:34
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.74167	R:0.89597	F1:0.81155
# Opinion term	P:0.75789	R:0.88073	F1:0.81471
# pair	P:0.66410	R:0.75291	F1:0.70572
#
# Epoch:35
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.76401	R:0.86913	F1:0.81319
# Opinion term	P:0.78320	R:0.88379	F1:0.83046
# pair	P:0.71233	R:0.75581	F1:0.73343
#
# Epoch:36
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.74000	R:0.86913	F1:0.79938
# Opinion term	P:0.79943	R:0.85321	F1:0.82544
# pair	P:0.67105	R:0.74128	F1:0.70442
#
# Epoch:37
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74221	R:0.87919	F1:0.80492
# Opinion term	P:0.79379	R:0.85933	F1:0.82526
# pair	P:0.71268	R:0.73547	F1:0.72389
#
# Epoch:38
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.77876	R:0.88591	F1:0.82889
# Opinion term	P:0.77929	R:0.87462	F1:0.82421
# pair	P:0.66497	R:0.76163	F1:0.71003
#
# Epoch:39
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.75872	R:0.87584	F1:0.81308
# Opinion term	P:0.79096	R:0.85627	F1:0.82232
# pair	P:0.70455	R:0.72093	F1:0.71264
#
# Epoch:40
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.73295	R:0.86577	F1:0.79385
# Opinion term	P:0.76819	R:0.87156	F1:0.81662
# pair	P:0.65152	R:0.75000	F1:0.69730
#
# Epoch:41
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74359	R:0.87584	F1:0.80431
# Opinion term	P:0.79006	R:0.87462	F1:0.83019
# pair	P:0.70360	R:0.73837	F1:0.72057
#
# Epoch:42
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.74545	R:0.82550	F1:0.78344
# Opinion term	P:0.78992	R:0.86239	F1:0.82456
# pair	P:0.67688	R:0.70640	F1:0.69132
#
# Epoch:43
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.75988	R:0.83893	F1:0.79745
# Opinion term	P:0.75862	R:0.87462	F1:0.81250
# pair	P:0.64398	R:0.71512	F1:0.67769
#
# Epoch:44
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.75841	R:0.83221	F1:0.79360
# Opinion term	P:0.80057	R:0.85933	F1:0.82891
# pair	P:0.67935	R:0.72674	F1:0.70225
#
# Epoch:45
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.72676	R:0.86577	F1:0.79020
# Opinion term	P:0.74545	R:0.87768	F1:0.80618
# pair	P:0.68365	R:0.74128	F1:0.71130
#
# Epoch:46
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.71468	R:0.86577	F1:0.78300
# Opinion term	P:0.79272	R:0.86544	F1:0.82749
# pair	P:0.66489	R:0.72674	F1:0.69444
#
# Epoch:47
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74709	R:0.86242	F1:0.80062
# Opinion term	P:0.79603	R:0.85933	F1:0.82647
# pair	P:0.68956	R:0.72965	F1:0.70904
#
# Epoch:48
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.73864	R:0.87248	F1:0.80000
# Opinion term	P:0.80000	R:0.86850	F1:0.83284
# pair	P:0.68338	R:0.75291	F1:0.71646
#
# Epoch:49
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74928	R:0.87248	F1:0.80620
# Opinion term	P:0.78670	R:0.86850	F1:0.82558
# pair	P:0.68852	R:0.73256	F1:0.70986
#
# Epoch:50
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.73938	R:0.87584	F1:0.80184
# Opinion term	P:0.77568	R:0.87768	F1:0.82353
# pair	P:0.66667	R:0.74419	F1:0.70330
#
# Epoch:51
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74359	R:0.87584	F1:0.80431
# Opinion term	P:0.80057	R:0.85933	F1:0.82891
# pair	P:0.70000	R:0.73256	F1:0.71591
#
# Epoch:52
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.75287	R:0.87919	F1:0.81115
# Opinion term	P:0.79109	R:0.86850	F1:0.82799
# pair	P:0.70330	R:0.74419	F1:0.72316
#
# Epoch:53
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.76786	R:0.86577	F1:0.81388
# Opinion term	P:0.79109	R:0.86850	F1:0.82799
# pair	P:0.71469	R:0.73547	F1:0.72493
#
# Epoch:54
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.76246	R:0.87248	F1:0.81377
# Opinion term	P:0.78846	R:0.87768	F1:0.83068
# pair	P:0.68684	R:0.75872	F1:0.72099
#
# Epoch:55
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.76540	R:0.87584	F1:0.81690
# Opinion term	P:0.80056	R:0.87156	F1:0.83455
# pair	P:0.71703	R:0.75872	F1:0.73729
#
# Epoch:56
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.75793	R:0.88255	F1:0.81550
# Opinion term	P:0.80342	R:0.86239	F1:0.83186
# pair	P:0.69231	R:0.75872	F1:0.72399
#
# Epoch:57
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74788	R:0.88591	F1:0.81106
# Opinion term	P:0.80857	R:0.86544	F1:0.83604
# pair	P:0.69811	R:0.75291	F1:0.72448
#
# Epoch:58
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.73950	R:0.88591	F1:0.80611
# Opinion term	P:0.75979	R:0.88991	F1:0.81972
# pair	P:0.68638	R:0.77616	F1:0.72851
#
# Epoch:59
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.75434	R:0.87584	F1:0.81056
# Opinion term	P:0.80627	R:0.86544	F1:0.83481
# pair	P:0.69189	R:0.74419	F1:0.71709
#
# Epoch:60
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.76970	R:0.85235	F1:0.80892
# Opinion term	P:0.84195	R:0.84709	F1:0.84451
# pair	P:0.73607	R:0.72965	F1:0.73285
#
# Epoch:61
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.75075	R:0.83893	F1:0.79239
# Opinion term	P:0.81214	R:0.85933	F1:0.83507
# pair	P:0.69081	R:0.72093	F1:0.70555
#
# Epoch:62
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.78571	R:0.73826	F1:0.76125
# Opinion term	P:0.81449	R:0.85933	F1:0.83631
# pair	P:0.72575	R:0.63081	F1:0.67496
#
# Epoch:63
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.71875	R:0.84899	F1:0.77846
# Opinion term	P:0.75405	R:0.85321	F1:0.80057
# pair	P:0.63144	R:0.71221	F1:0.66940
#
# Epoch:64
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.73410	R:0.85235	F1:0.78882
# Opinion term	P:0.79370	R:0.84709	F1:0.81953
# pair	P:0.68802	R:0.71802	F1:0.70270
#
# Epoch:65
# 100% 108/108 [00:31<00:00,  3.44it/s]
# Aspect term	P:0.74848	R:0.82886	F1:0.78662
# Opinion term	P:0.76374	R:0.85015	F1:0.80463
# pair	P:0.67045	R:0.68605	F1:0.67816
#
# Epoch:66
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.69565	R:0.85906	F1:0.76877
# Opinion term	P:0.74430	R:0.89908	F1:0.81440
# pair	P:0.63171	R:0.75291	F1:0.68700
#
# Epoch:67
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74194	R:0.84899	F1:0.79186
# Opinion term	P:0.80516	R:0.85933	F1:0.83136
# pair	P:0.69613	R:0.73256	F1:0.71388
#
# Epoch:68
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.73214	R:0.82550	F1:0.77603
# Opinion term	P:0.77807	R:0.88991	F1:0.83024
# pair	P:0.65969	R:0.73256	F1:0.69421
#
# Epoch:69
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.70083	R:0.84899	F1:0.76783
# Opinion term	P:0.78552	R:0.86239	F1:0.82216
# pair	P:0.67819	R:0.74128	F1:0.70833
#
# Epoch:70
# 100% 108/108 [00:31<00:00,  3.44it/s]
# Aspect term	P:0.72286	R:0.84899	F1:0.78086
# Opinion term	P:0.77480	R:0.88379	F1:0.82571
# pair	P:0.65641	R:0.74419	F1:0.69755
#
# Epoch:71
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.72493	R:0.84899	F1:0.78207
# Opinion term	P:0.79213	R:0.86239	F1:0.82577
# pair	P:0.70339	R:0.72384	F1:0.71347
#
# Epoch:72
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.71549	R:0.85235	F1:0.77795
# Opinion term	P:0.77686	R:0.86239	F1:0.81739
# pair	P:0.65455	R:0.73256	F1:0.69136
#
# Epoch:73
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.70822	R:0.83893	F1:0.76805
# Opinion term	P:0.75389	R:0.88991	F1:0.81627
# pair	P:0.61985	R:0.74419	F1:0.67635
#
# Epoch:74
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74702	R:0.84228	F1:0.79180
# Opinion term	P:0.80403	R:0.85321	F1:0.82789
# pair	P:0.71053	R:0.70640	F1:0.70845
#
# Epoch:75
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.79048	R:0.83557	F1:0.81240
# Opinion term	P:0.84688	R:0.82875	F1:0.83771
# pair	P:0.76677	R:0.69767	F1:0.73059
#
# Epoch:76
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.76615	R:0.83557	F1:0.79936
# Opinion term	P:0.79832	R:0.87156	F1:0.83333
# pair	P:0.70506	R:0.72965	F1:0.71714
#
# Epoch:77
# 100% 108/108 [00:31<00:00,  3.44it/s]
# Aspect term	P:0.75227	R:0.83557	F1:0.79173
# Opinion term	P:0.79722	R:0.87768	F1:0.83552
# pair	P:0.68937	R:0.73547	F1:0.71167
#
# Epoch:78
# 100% 108/108 [00:31<00:00,  3.46it/s]
# Aspect term	P:0.73837	R:0.85235	F1:0.79128
# Opinion term	P:0.80168	R:0.87768	F1:0.83796
# pair	P:0.68033	R:0.72384	F1:0.70141
#
# Epoch:79
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74852	R:0.84899	F1:0.79560
# Opinion term	P:0.81159	R:0.85627	F1:0.83333
# pair	P:0.70056	R:0.72093	F1:0.71060
#
# Epoch:80
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.76147	R:0.83557	F1:0.79680
# Opinion term	P:0.80347	R:0.85015	F1:0.82615
# pair	P:0.66488	R:0.72093	F1:0.69177
#
# Epoch:81
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.73988	R:0.85906	F1:0.79503
# Opinion term	P:0.75063	R:0.91131	F1:0.82320
# pair	P:0.62326	R:0.77907	F1:0.69251
#
# Epoch:82
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.72316	R:0.85906	F1:0.78528
# Opinion term	P:0.75789	R:0.88073	F1:0.81471
# pair	P:0.70520	R:0.70930	F1:0.70725
#
# Epoch:83
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.76261	R:0.86242	F1:0.80945
# Opinion term	P:0.75515	R:0.89602	F1:0.81958
# pair	P:0.67098	R:0.75291	F1:0.70959
#
# Epoch:84
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.69459	R:0.86242	F1:0.76946
# Opinion term	P:0.75128	R:0.89602	F1:0.81729
# pair	P:0.64677	R:0.75581	F1:0.69705
#
# Epoch:85
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.75000	R:0.85570	F1:0.79937
# Opinion term	P:0.79360	R:0.83486	F1:0.81371
# pair	P:0.69468	R:0.72093	F1:0.70756
#
# Epoch:86
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.73011	R:0.86242	F1:0.79077
# Opinion term	P:0.75328	R:0.87768	F1:0.81073
# pair	P:0.68229	R:0.76163	F1:0.71978
#
# Epoch:87
# 100% 108/108 [00:31<00:00,  3.44it/s]
# Aspect term	P:0.74344	R:0.85570	F1:0.79563
# Opinion term	P:0.79651	R:0.83792	F1:0.81669
# pair	P:0.72093	R:0.72093	F1:0.72093
#
# Epoch:88
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.73333	R:0.84899	F1:0.78694
# Opinion term	P:0.79706	R:0.82875	F1:0.81259
# pair	P:0.65217	R:0.69767	F1:0.67416
#
# Epoch:89
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.69509	R:0.90268	F1:0.78540
# Opinion term	P:0.76216	R:0.86239	F1:0.80918
# pair	P:0.64250	R:0.74709	F1:0.69086
#
# Epoch:90
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74230	R:0.88926	F1:0.80916
# Opinion term	P:0.77095	R:0.84404	F1:0.80584
# pair	P:0.64631	R:0.73837	F1:0.68928
#
# Epoch:91
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.76093	R:0.87584	F1:0.81435
# Opinion term	P:0.78310	R:0.85015	F1:0.81525
# pair	P:0.67116	R:0.72384	F1:0.69650
#
# Epoch:92
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.73816	R:0.88926	F1:0.80670
# Opinion term	P:0.75654	R:0.88379	F1:0.81523
# pair	P:0.64423	R:0.77907	F1:0.70526
#
# Epoch:93
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.69947	R:0.88255	F1:0.78042
# Opinion term	P:0.76230	R:0.85321	F1:0.80519
# pair	P:0.66756	R:0.72384	F1:0.69456
#
# Epoch:94
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.74631	R:0.84899	F1:0.79435
# Opinion term	P:0.78261	R:0.82569	F1:0.80357
# pair	P:0.71951	R:0.68605	F1:0.70238
#
# Epoch:95
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.70889	R:0.88255	F1:0.78625
# Opinion term	P:0.75266	R:0.86544	F1:0.80512
# pair	P:0.63910	R:0.74128	F1:0.68641
#
# Epoch:96
# 100% 108/108 [00:31<00:00,  3.44it/s]
# Aspect term	P:0.73563	R:0.85906	F1:0.79257
# Opinion term	P:0.77841	R:0.83792	F1:0.80707
# pair	P:0.66038	R:0.71221	F1:0.68531
#
# Epoch:97
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.72286	R:0.84899	F1:0.78086
# Opinion term	P:0.80294	R:0.83486	F1:0.81859
# pair	P:0.68169	R:0.70349	F1:0.69242
#
# Epoch:98
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.75075	R:0.83893	F1:0.79239
# Opinion term	P:0.79179	R:0.82569	F1:0.80838
# pair	P:0.67978	R:0.70349	F1:0.69143
#
# Epoch:99
# 100% 108/108 [00:31<00:00,  3.45it/s]
# Aspect term	P:0.73699	R:0.85570	F1:0.79193
# Opinion term	P:0.78693	R:0.84709	F1:0.81591
# pair	P:0.68033	R:0.72384	F1:0.70141
#
# best epoch: 33	best dev pair f1: 0.73800
#
#
# Evaluation on testset:
# Aspect term	P:0.72193	R:0.89011	F1:0.79724
# Opinion term	P:0.77574	R:0.88100	F1:0.82502
# pair	P:0.70423	R:0.77220	F1:0.73665

# %%
# !python main.py --task triplet --mode train --dataset res16
# Out:
# 2021-08-10 15:57:41.988800: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 108/108 [00:31<00:00,  3.38it/s]
# Aspect term	P:0.75532	R:0.23826	F1:0.36224
# Opinion term	P:0.89831	R:0.16208	F1:0.27461
# triplet	P:0.75000	R:0.00872	F1:0.01724
#
# Epoch:1
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.78800	R:0.66107	F1:0.71898
# Opinion term	P:0.79530	R:0.72477	F1:0.75840
# triplet	P:0.76415	R:0.23547	F1:0.36000
#
# Epoch:2
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.78367	R:0.64430	F1:0.70718
# Opinion term	P:0.83058	R:0.61468	F1:0.70650
# triplet	P:0.77778	R:0.20349	F1:0.32258
#
# Epoch:3
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.78859	R:0.78859	F1:0.78859
# Opinion term	P:0.83402	R:0.61468	F1:0.70775
# triplet	P:0.71338	R:0.32558	F1:0.44711
#
# Epoch:4
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.72778	R:0.87919	F1:0.79635
# Opinion term	P:0.80061	R:0.79817	F1:0.79939
# triplet	P:0.70290	R:0.56395	F1:0.62581
#
# Epoch:5
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.78328	R:0.84899	F1:0.81481
# Opinion term	P:0.78286	R:0.83792	F1:0.80945
# triplet	P:0.70164	R:0.62209	F1:0.65948
#
# Epoch:6
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.78370	R:0.83893	F1:0.81037
# Opinion term	P:0.77429	R:0.82875	F1:0.80059
# triplet	P:0.78689	R:0.55814	F1:0.65306
#
# Epoch:7
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.77778	R:0.84564	F1:0.81029
# Opinion term	P:0.78873	R:0.85627	F1:0.82111
# triplet	P:0.74914	R:0.63372	F1:0.68661
#
# Epoch:8
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.78997	R:0.84564	F1:0.81686
# Opinion term	P:0.78630	R:0.87768	F1:0.82948
# triplet	P:0.72203	R:0.61919	F1:0.66667
#
# Epoch:9
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.79801	R:0.80872	F1:0.80333
# Opinion term	P:0.80814	R:0.85015	F1:0.82861
# triplet	P:0.73868	R:0.61628	F1:0.67195
#
# Epoch:10
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.77134	R:0.84899	F1:0.80831
# Opinion term	P:0.81159	R:0.85627	F1:0.83333
# triplet	P:0.74740	R:0.62791	F1:0.68246
#
# Epoch:11
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.76488	R:0.86242	F1:0.81073
# Opinion term	P:0.75989	R:0.88073	F1:0.81586
# triplet	P:0.71290	R:0.64244	F1:0.67584
#
# Epoch:12
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.77273	R:0.85570	F1:0.81210
# Opinion term	P:0.76203	R:0.87156	F1:0.81312
# triplet	P:0.69136	R:0.65116	F1:0.67066
#
# Epoch:13
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.75731	R:0.86913	F1:0.80937
# Opinion term	P:0.75192	R:0.89908	F1:0.81894
# triplet	P:0.69969	R:0.65698	F1:0.67766
#
# Epoch:14
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.74242	R:0.82215	F1:0.78025
# Opinion term	P:0.81818	R:0.85321	F1:0.83533
# triplet	P:0.67823	R:0.62500	F1:0.65053
#
# Epoch:15
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.76596	R:0.84564	F1:0.80383
# Opinion term	P:0.79942	R:0.84098	F1:0.81967
# triplet	P:0.72148	R:0.62500	F1:0.66978
#
# Epoch:16
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.76282	R:0.79866	F1:0.78033
# Opinion term	P:0.76503	R:0.85627	F1:0.80808
# triplet	P:0.74419	R:0.55814	F1:0.63787
#
# Epoch:17
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.67717	R:0.86577	F1:0.75994
# Opinion term	P:0.76738	R:0.87768	F1:0.81883
# triplet	P:0.59126	R:0.66860	F1:0.62756
#
# Epoch:18
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.75000	R:0.85570	F1:0.79937
# Opinion term	P:0.81416	R:0.84404	F1:0.82883
# triplet	P:0.69024	R:0.59593	F1:0.63963
#
# Epoch:19
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.71745	R:0.86913	F1:0.78604
# Opinion term	P:0.77309	R:0.89602	F1:0.83003
# triplet	P:0.59686	R:0.66279	F1:0.62810
#
# Epoch:20
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.73034	R:0.87248	F1:0.79511
# Opinion term	P:0.76546	R:0.90826	F1:0.83077
# triplet	P:0.64611	R:0.70058	F1:0.67225
#
# Epoch:21
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.72472	R:0.86577	F1:0.78899
# Opinion term	P:0.77513	R:0.89602	F1:0.83121
# triplet	P:0.64110	R:0.68023	F1:0.66008
#
# Epoch:22
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.72346	R:0.86913	F1:0.78963
# Opinion term	P:0.78976	R:0.89602	F1:0.83954
# triplet	P:0.64578	R:0.68895	F1:0.66667
#
# Epoch:23
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.73276	R:0.85570	F1:0.78947
# Opinion term	P:0.78919	R:0.89297	F1:0.83788
# triplet	P:0.65909	R:0.67442	F1:0.66667
#
# Epoch:24
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74128	R:0.85570	F1:0.79439
# Opinion term	P:0.79144	R:0.90520	F1:0.84451
# triplet	P:0.65915	R:0.68023	F1:0.66953
#
# Epoch:25
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.75976	R:0.84899	F1:0.80190
# Opinion term	P:0.79348	R:0.89297	F1:0.84029
# triplet	P:0.66197	R:0.68314	F1:0.67239
#
# Epoch:26
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75148	R:0.85235	F1:0.79874
# Opinion term	P:0.78167	R:0.88685	F1:0.83095
# triplet	P:0.66377	R:0.66570	F1:0.66473
#
# Epoch:27
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.72176	R:0.87919	F1:0.79274
# Opinion term	P:0.77023	R:0.90214	F1:0.83099
# triplet	P:0.65556	R:0.68605	F1:0.67045
#
# Epoch:28
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.76347	R:0.85570	F1:0.80696
# Opinion term	P:0.79564	R:0.89297	F1:0.84150
# triplet	P:0.69277	R:0.66860	F1:0.68047
#
# Epoch:29
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.72034	R:0.85570	F1:0.78221
# Opinion term	P:0.77333	R:0.88685	F1:0.82621
# triplet	P:0.66765	R:0.65988	F1:0.66374
#
# Epoch:30
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.80719	R:0.82886	F1:0.81788
# Opinion term	P:0.80229	R:0.85627	F1:0.82840
# triplet	P:0.68111	R:0.63953	F1:0.65967
#
# Epoch:31
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71751	R:0.85235	F1:0.77914
# Opinion term	P:0.79351	R:0.82263	F1:0.80781
# triplet	P:0.62090	R:0.60465	F1:0.61267
#
# Epoch:32
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.73913	R:0.85570	F1:0.79316
# Opinion term	P:0.76757	R:0.86850	F1:0.81492
# triplet	P:0.63944	R:0.65988	F1:0.64950
#
# Epoch:33
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.73487	R:0.85570	F1:0.79070
# Opinion term	P:0.78297	R:0.87156	F1:0.82489
# triplet	P:0.62953	R:0.65698	F1:0.64296
#
# Epoch:34
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75723	R:0.87919	F1:0.81366
# Opinion term	P:0.76344	R:0.86850	F1:0.81259
# triplet	P:0.63662	R:0.65698	F1:0.64664
#
# Epoch:35
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.72131	R:0.88591	F1:0.79518
# Opinion term	P:0.78022	R:0.86850	F1:0.82200
# triplet	P:0.61081	R:0.65698	F1:0.63305
#
# Epoch:36
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.73278	R:0.89262	F1:0.80484
# Opinion term	P:0.75130	R:0.88685	F1:0.81346
# triplet	P:0.61954	R:0.70058	F1:0.65757
#
# Epoch:37
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75219	R:0.86577	F1:0.80499
# Opinion term	P:0.75926	R:0.87768	F1:0.81418
# triplet	P:0.62810	R:0.66279	F1:0.64498
#
# Epoch:38
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74063	R:0.86242	F1:0.79690
# Opinion term	P:0.75668	R:0.86544	F1:0.80742
# triplet	P:0.61433	R:0.64826	F1:0.63083
#
# Epoch:39
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75444	R:0.85570	F1:0.80189
# Opinion term	P:0.76720	R:0.88685	F1:0.82270
# triplet	P:0.65230	R:0.65988	F1:0.65607
#
# Epoch:40
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.68207	R:0.84228	F1:0.75375
# Opinion term	P:0.77507	R:0.87462	F1:0.82184
# triplet	P:0.59788	R:0.65698	F1:0.62604
#
# Epoch:41
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75301	R:0.83893	F1:0.79365
# Opinion term	P:0.78056	R:0.85933	F1:0.81805
# triplet	P:0.57600	R:0.62791	F1:0.60083
#
# Epoch:42
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.71588	R:0.86242	F1:0.78234
# Opinion term	P:0.77260	R:0.86239	F1:0.81503
# triplet	P:0.63687	R:0.66279	F1:0.64957
#
# Epoch:43
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71347	R:0.83557	F1:0.76971
# Opinion term	P:0.79202	R:0.85015	F1:0.82006
# triplet	P:0.65029	R:0.65407	F1:0.65217
#
# Epoch:44
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.73315	R:0.87584	F1:0.79817
# Opinion term	P:0.80110	R:0.88685	F1:0.84180
# triplet	P:0.66759	R:0.70058	F1:0.68369
#
# Epoch:45
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.77711	R:0.86577	F1:0.81905
# Opinion term	P:0.80672	R:0.88073	F1:0.84211
# triplet	P:0.68605	R:0.68605	F1:0.68605
#
# Epoch:46
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74857	R:0.87919	F1:0.80864
# Opinion term	P:0.78591	R:0.88685	F1:0.83333
# triplet	P:0.64865	R:0.69767	F1:0.67227
#
# Epoch:47
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75575	R:0.88255	F1:0.81424
# Opinion term	P:0.79396	R:0.88379	F1:0.83647
# triplet	P:0.67697	R:0.70058	F1:0.68857
#
# Epoch:48
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75872	R:0.87584	F1:0.81308
# Opinion term	P:0.78630	R:0.87768	F1:0.82948
# triplet	P:0.67507	R:0.70058	F1:0.68759
#
# Epoch:49
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74212	R:0.86913	F1:0.80062
# Opinion term	P:0.78474	R:0.88073	F1:0.82997
# triplet	P:0.67127	R:0.70640	F1:0.68839
#
# Epoch:50
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74352	R:0.86577	F1:0.80000
# Opinion term	P:0.78611	R:0.86544	F1:0.82387
# triplet	P:0.64706	R:0.63953	F1:0.64327
#
# Epoch:51
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74713	R:0.87248	F1:0.80495
# Opinion term	P:0.77089	R:0.87462	F1:0.81948
# triplet	P:0.64345	R:0.67151	F1:0.65718
#
# Epoch:52
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75434	R:0.87584	F1:0.81056
# Opinion term	P:0.76757	R:0.86850	F1:0.81492
# triplet	P:0.62881	R:0.65988	F1:0.64397
#
# Epoch:53
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.80000	R:0.85906	F1:0.82848
# Opinion term	P:0.78512	R:0.87156	F1:0.82609
# triplet	P:0.68732	R:0.67733	F1:0.68228
#
# Epoch:54
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.77015	R:0.86577	F1:0.81517
# Opinion term	P:0.79063	R:0.87768	F1:0.83188
# triplet	P:0.65460	R:0.68314	F1:0.66856
#
# Epoch:55
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.76676	R:0.88255	F1:0.82059
# Opinion term	P:0.78320	R:0.88379	F1:0.83046
# triplet	P:0.67227	R:0.69767	F1:0.68474
#
# Epoch:56
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.77219	R:0.87584	F1:0.82075
# Opinion term	P:0.79050	R:0.86544	F1:0.82628
# triplet	P:0.65363	R:0.68023	F1:0.66667
#
# Epoch:57
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.76149	R:0.88926	F1:0.82043
# Opinion term	P:0.73116	R:0.88991	F1:0.80276
# triplet	P:0.66298	R:0.69767	F1:0.67989
#
# Epoch:58
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74581	R:0.89597	F1:0.81402
# Opinion term	P:0.77807	R:0.88991	F1:0.83024
# triplet	P:0.62887	R:0.70930	F1:0.66667
#
# Epoch:59
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.76347	R:0.85570	F1:0.80696
# Opinion term	P:0.81024	R:0.82263	F1:0.81639
# triplet	P:0.71000	R:0.61919	F1:0.66149
#
# Epoch:60
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.70994	R:0.86242	F1:0.77879
# Opinion term	P:0.79320	R:0.85627	F1:0.82353
# triplet	P:0.58629	R:0.67151	F1:0.62602
#
# Epoch:61
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71091	R:0.80872	F1:0.75667
# Opinion term	P:0.75967	R:0.84098	F1:0.79826
# triplet	P:0.64650	R:0.59012	F1:0.61702
#
# Epoch:62
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75371	R:0.85235	F1:0.80000
# Opinion term	P:0.78797	R:0.84098	F1:0.81361
# triplet	P:0.61047	R:0.61047	F1:0.61047
#
# Epoch:63
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74138	R:0.86577	F1:0.79876
# Opinion term	P:0.76280	R:0.86544	F1:0.81089
# triplet	P:0.59249	R:0.64244	F1:0.61646
#
# Epoch:64
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74011	R:0.87919	F1:0.80368
# Opinion term	P:0.76330	R:0.87768	F1:0.81650
# triplet	P:0.64655	R:0.65407	F1:0.65029
#
# Epoch:65
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.69761	R:0.88255	F1:0.77926
# Opinion term	P:0.74550	R:0.88685	F1:0.81006
# triplet	P:0.59124	R:0.70640	F1:0.64371
#
# Epoch:66
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.72145	R:0.86913	F1:0.78843
# Opinion term	P:0.76000	R:0.87156	F1:0.81197
# triplet	P:0.59536	R:0.67151	F1:0.63115
#
# Epoch:67
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71351	R:0.88591	F1:0.79042
# Opinion term	P:0.74300	R:0.89297	F1:0.81111
# triplet	P:0.59591	R:0.67733	F1:0.63401
#
# Epoch:68
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.73034	R:0.87248	F1:0.79511
# Opinion term	P:0.79603	R:0.85933	F1:0.82647
# triplet	P:0.66193	R:0.67733	F1:0.66954
#
# Epoch:69
# 100% 108/108 [00:32<00:00,  3.35it/s]
# Aspect term	P:0.72829	R:0.87248	F1:0.79389
# Opinion term	P:0.77869	R:0.87156	F1:0.82251
# triplet	P:0.64345	R:0.67151	F1:0.65718
#
# Epoch:70
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71271	R:0.86577	F1:0.78182
# Opinion term	P:0.79063	R:0.87768	F1:0.83188
# triplet	P:0.62670	R:0.66860	F1:0.64698
#
# Epoch:71
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71944	R:0.86913	F1:0.78723
# Opinion term	P:0.79006	R:0.87462	F1:0.83019
# triplet	P:0.63760	R:0.68023	F1:0.65823
#
# Epoch:72
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.70777	R:0.88591	F1:0.78689
# Opinion term	P:0.75979	R:0.88991	F1:0.81972
# triplet	P:0.61619	R:0.68605	F1:0.64924
#
# Epoch:73
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.73977	R:0.84899	F1:0.79063
# Opinion term	P:0.77135	R:0.85627	F1:0.81159
# triplet	P:0.62778	R:0.65698	F1:0.64205
#
# Epoch:74
# 100% 108/108 [00:32<00:00,  3.35it/s]
# Aspect term	P:0.71667	R:0.86577	F1:0.78419
# Opinion term	P:0.79379	R:0.85933	F1:0.82526
# triplet	P:0.66286	R:0.67442	F1:0.66859
#
# Epoch:75
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75887	R:0.71812	F1:0.73793
# Opinion term	P:0.76404	R:0.83180	F1:0.79649
# triplet	P:0.64912	R:0.53779	F1:0.58824
#
# Epoch:76
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.70604	R:0.86242	F1:0.77644
# Opinion term	P:0.77778	R:0.85627	F1:0.81514
# triplet	P:0.60051	R:0.68605	F1:0.64043
#
# Epoch:77
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.73487	R:0.85570	F1:0.79070
# Opinion term	P:0.80460	R:0.85627	F1:0.82963
# triplet	P:0.67169	R:0.64826	F1:0.65976
#
# Epoch:78
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.70718	R:0.85906	F1:0.77576
# Opinion term	P:0.78512	R:0.87156	F1:0.82609
# triplet	P:0.62334	R:0.68314	F1:0.65187
#
# Epoch:79
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71507	R:0.87584	F1:0.78733
# Opinion term	P:0.77688	R:0.88379	F1:0.82690
# triplet	P:0.59299	R:0.63953	F1:0.61538
#
# Epoch:80
# 100% 108/108 [00:32<00:00,  3.37it/s]
# Aspect term	P:0.74174	R:0.82886	F1:0.78288
# Opinion term	P:0.72319	R:0.88685	F1:0.79670
# triplet	P:0.59890	R:0.63372	F1:0.61582
#
# Epoch:81
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.70161	R:0.87584	F1:0.77910
# Opinion term	P:0.76800	R:0.88073	F1:0.82051
# triplet	P:0.59326	R:0.66570	F1:0.62740
#
# Epoch:82
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.72857	R:0.85570	F1:0.78704
# Opinion term	P:0.78771	R:0.86239	F1:0.82336
# triplet	P:0.63812	R:0.67151	F1:0.65439
#
# Epoch:83
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71831	R:0.85570	F1:0.78101
# Opinion term	P:0.77869	R:0.87156	F1:0.82251
# triplet	P:0.61067	R:0.66570	F1:0.63700
#
# Epoch:84
# 100% 108/108 [00:32<00:00,  3.35it/s]
# Aspect term	P:0.69399	R:0.85235	F1:0.76506
# Opinion term	P:0.77297	R:0.87462	F1:0.82066
# triplet	P:0.59845	R:0.67151	F1:0.63288
#
# Epoch:85
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71111	R:0.85906	F1:0.77812
# Opinion term	P:0.75591	R:0.88073	F1:0.81356
# triplet	P:0.61640	R:0.67733	F1:0.64543
#
# Epoch:86
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.69837	R:0.86242	F1:0.77177
# Opinion term	P:0.75389	R:0.88991	F1:0.81627
# triplet	P:0.62565	R:0.69477	F1:0.65840
#
# Epoch:87
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.70190	R:0.86913	F1:0.77661
# Opinion term	P:0.75798	R:0.87156	F1:0.81081
# triplet	P:0.61257	R:0.68023	F1:0.64463
#
# Epoch:88
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.69786	R:0.87584	F1:0.77679
# Opinion term	P:0.76000	R:0.87156	F1:0.81197
# triplet	P:0.60000	R:0.68895	F1:0.64141
#
# Epoch:89
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71311	R:0.87584	F1:0.78614
# Opinion term	P:0.75000	R:0.88073	F1:0.81013
# triplet	P:0.62694	R:0.70349	F1:0.66301
#
# Epoch:90
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.72881	R:0.86577	F1:0.79141
# Opinion term	P:0.76819	R:0.87156	F1:0.81662
# triplet	P:0.63636	R:0.69186	F1:0.66295
#
# Epoch:91
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74138	R:0.86577	F1:0.79876
# Opinion term	P:0.78814	R:0.85321	F1:0.81938
# triplet	P:0.65341	R:0.66860	F1:0.66092
#
# Epoch:92
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.71468	R:0.86577	F1:0.78300
# Opinion term	P:0.77260	R:0.86239	F1:0.81503
# triplet	P:0.63934	R:0.68023	F1:0.65915
#
# Epoch:93
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.73295	R:0.86577	F1:0.79385
# Opinion term	P:0.78142	R:0.87462	F1:0.82540
# triplet	P:0.63172	R:0.68314	F1:0.65642
#
# Epoch:94
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74640	R:0.86913	F1:0.80310
# Opinion term	P:0.77507	R:0.87462	F1:0.82184
# triplet	P:0.64324	R:0.69186	F1:0.66667
#
# Epoch:95
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.75516	R:0.85906	F1:0.80377
# Opinion term	P:0.78771	R:0.86239	F1:0.82336
# triplet	P:0.64560	R:0.68314	F1:0.66384
#
# Epoch:96
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74203	R:0.85906	F1:0.79627
# Opinion term	P:0.78512	R:0.87156	F1:0.82609
# triplet	P:0.65565	R:0.69186	F1:0.67327
#
# Epoch:97
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.74063	R:0.86242	F1:0.79690
# Opinion term	P:0.78846	R:0.87768	F1:0.83068
# triplet	P:0.65385	R:0.69186	F1:0.67232
#
# Epoch:98
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.76347	R:0.85570	F1:0.80696
# Opinion term	P:0.77684	R:0.84098	F1:0.80764
# triplet	P:0.62429	R:0.64244	F1:0.63324
#
# Epoch:99
# 100% 108/108 [00:32<00:00,  3.36it/s]
# Aspect term	P:0.67102	R:0.86242	F1:0.75477
# Opinion term	P:0.80059	R:0.83486	F1:0.81737
# triplet	P:0.62060	R:0.66570	F1:0.64236
#
# best epoch: 47	best dev triplet f1: 0.68857
#
#
# Evaluation on testset:
# Aspect term	P:0.70833	R:0.85934	F1:0.77656
# Opinion term	P:0.80075	R:0.88935	F1:0.84273
# triplet	P:0.62898	R:0.68726	F1:0.65683

# %%
# !python main.py --task pair --mode train --dataset lap14
# Out:
# 2021-08-10 17:15:40.304014: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.78453	R:0.42900	F1:0.55469
# Opinion term	P:0.71200	R:0.57051	F1:0.63345
# pair	P:0.68116	R:0.12368	F1:0.20935
#
# Epoch:2
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.78231	R:0.69486	F1:0.73600
# Opinion term	P:0.78261	R:0.69231	F1:0.73469
# pair	P:0.77838	R:0.37895	F1:0.50973
#
# Epoch:3
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.78073	R:0.70997	F1:0.74367
# Opinion term	P:0.71651	R:0.73718	F1:0.72670
# pair	P:0.67769	R:0.43158	F1:0.52733
#
# Epoch:4
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.76833	R:0.79154	F1:0.77976
# Opinion term	P:0.72353	R:0.78846	F1:0.75460
# pair	P:0.67742	R:0.55263	F1:0.60870
#
# Epoch:5
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.74521	R:0.82175	F1:0.78161
# Opinion term	P:0.72093	R:0.79487	F1:0.75610
# pair	P:0.63807	R:0.62632	F1:0.63214
#
# Epoch:6
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.74114	R:0.82175	F1:0.77937
# Opinion term	P:0.73231	R:0.76282	F1:0.74725
# pair	P:0.63855	R:0.55789	F1:0.59551
#
# Epoch:7
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76522	R:0.79758	F1:0.78107
# Opinion term	P:0.71084	R:0.75641	F1:0.73292
# pair	P:0.65541	R:0.51053	F1:0.57396
#
# Epoch:8
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76620	R:0.82175	F1:0.79300
# Opinion term	P:0.69318	R:0.78205	F1:0.73494
# pair	P:0.65350	R:0.56579	F1:0.60649
#
# Epoch:9
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.71320	R:0.84894	F1:0.77517
# Opinion term	P:0.67318	R:0.77244	F1:0.71940
# pair	P:0.61475	R:0.59211	F1:0.60322
#
# Epoch:10
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.77151	R:0.78550	F1:0.77844
# Opinion term	P:0.72647	R:0.79167	F1:0.75767
# pair	P:0.66667	R:0.57895	F1:0.61972
#
# Epoch:11
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.75775	R:0.81269	F1:0.78426
# Opinion term	P:0.77389	R:0.77885	F1:0.77636
# pair	P:0.70288	R:0.57895	F1:0.63492
#
# Epoch:12
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.73727	R:0.83082	F1:0.78125
# Opinion term	P:0.68611	R:0.79167	F1:0.73512
# pair	P:0.63585	R:0.59737	F1:0.61601
#
# Epoch:13
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.74277	R:0.77644	F1:0.75923
# Opinion term	P:0.75399	R:0.75641	F1:0.75520
# pair	P:0.70000	R:0.55263	F1:0.61765
#
# Epoch:14
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.70543	R:0.82477	F1:0.76045
# Opinion term	P:0.71105	R:0.80449	F1:0.75489
# pair	P:0.63612	R:0.62105	F1:0.62850
#
# Epoch:15
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.77193	R:0.79758	F1:0.78455
# Opinion term	P:0.69540	R:0.77564	F1:0.73333
# pair	P:0.66564	R:0.57105	F1:0.61473
#
# Epoch:16
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.78042	R:0.79456	F1:0.78743
# Opinion term	P:0.74164	R:0.78205	F1:0.76131
# pair	P:0.67353	R:0.60263	F1:0.63611
#
# Epoch:17
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.75802	R:0.78550	F1:0.77151
# Opinion term	P:0.79181	R:0.74359	F1:0.76694
# pair	P:0.71536	R:0.50263	F1:0.59042
#
# Epoch:18
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.74124	R:0.83082	F1:0.78348
# Opinion term	P:0.72174	R:0.79808	F1:0.75799
# pair	P:0.65242	R:0.60263	F1:0.62654
#
# Epoch:19
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.73822	R:0.85196	F1:0.79102
# Opinion term	P:0.66931	R:0.81090	F1:0.73333
# pair	P:0.61596	R:0.65000	F1:0.63252
#
# Epoch:20
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.75549	R:0.83082	F1:0.79137
# Opinion term	P:0.64844	R:0.79808	F1:0.71552
# pair	P:0.60836	R:0.61316	F1:0.61075
#
# Epoch:21
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.73958	R:0.85801	F1:0.79441
# Opinion term	P:0.69468	R:0.79487	F1:0.74141
# pair	P:0.62924	R:0.63421	F1:0.63172
#
# Epoch:22
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.75815	R:0.84290	F1:0.79828
# Opinion term	P:0.71221	R:0.78526	F1:0.74695
# pair	P:0.65546	R:0.61579	F1:0.63501
#
# Epoch:23
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.73028	R:0.86707	F1:0.79282
# Opinion term	P:0.71726	R:0.77244	F1:0.74383
# pair	P:0.62500	R:0.60526	F1:0.61497
#
# Epoch:24
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.71139	R:0.84894	F1:0.77410
# Opinion term	P:0.67500	R:0.77885	F1:0.72321
# pair	P:0.55220	R:0.62632	F1:0.58693
#
# Epoch:25
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.71867	R:0.84894	F1:0.77839
# Opinion term	P:0.70769	R:0.73718	F1:0.72214
# pair	P:0.63529	R:0.56842	F1:0.60000
#
# Epoch:26
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.73087	R:0.83686	F1:0.78028
# Opinion term	P:0.68768	R:0.76923	F1:0.72617
# pair	P:0.57653	R:0.59474	F1:0.58549
#
# Epoch:27
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76620	R:0.82175	F1:0.79300
# Opinion term	P:0.68286	R:0.76603	F1:0.72205
# pair	P:0.62431	R:0.59474	F1:0.60916
#
# Epoch:28
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.74722	R:0.81269	F1:0.77858
# Opinion term	P:0.69444	R:0.80128	F1:0.74405
# pair	P:0.61008	R:0.60526	F1:0.60766
#
# Epoch:29
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.76012	R:0.79456	F1:0.77696
# Opinion term	P:0.72861	R:0.79167	F1:0.75883
# pair	P:0.65015	R:0.58684	F1:0.61687
#
# Epoch:30
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76944	R:0.83686	F1:0.80174
# Opinion term	P:0.69883	R:0.76603	F1:0.73089
# pair	P:0.62903	R:0.61579	F1:0.62234
#
# Epoch:31
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.77681	R:0.80967	F1:0.79290
# Opinion term	P:0.71225	R:0.80128	F1:0.75415
# pair	P:0.67143	R:0.61842	F1:0.64384
#
# Epoch:32
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.75074	R:0.76435	F1:0.75749
# Opinion term	P:0.68539	R:0.78205	F1:0.73054
# pair	P:0.63173	R:0.58684	F1:0.60846
#
# Epoch:33
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.74302	R:0.80363	F1:0.77213
# Opinion term	P:0.70238	R:0.75641	F1:0.72840
# pair	P:0.65706	R:0.60000	F1:0.62724
#
# Epoch:34
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.75284	R:0.80060	F1:0.77599
# Opinion term	P:0.72189	R:0.78205	F1:0.75077
# pair	P:0.65169	R:0.61053	F1:0.63043
#
# Epoch:35
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.74667	R:0.84592	F1:0.79320
# Opinion term	P:0.69429	R:0.77885	F1:0.73414
# pair	P:0.65460	R:0.61842	F1:0.63599
#
# Epoch:36
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76033	R:0.83384	F1:0.79539
# Opinion term	P:0.69714	R:0.78205	F1:0.73716
# pair	P:0.64578	R:0.62368	F1:0.63454
#
# Epoch:37
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.75424	R:0.80665	F1:0.77956
# Opinion term	P:0.72156	R:0.77244	F1:0.74613
# pair	P:0.65169	R:0.61053	F1:0.63043
#
# Epoch:38
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.75921	R:0.80967	F1:0.78363
# Opinion term	P:0.72590	R:0.77244	F1:0.74845
# pair	P:0.66077	R:0.58947	F1:0.62309
#
# Epoch:39
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76667	R:0.76435	F1:0.76551
# Opinion term	P:0.68627	R:0.78526	F1:0.73244
# pair	P:0.64095	R:0.56842	F1:0.60251
#
# Epoch:40
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.68657	R:0.83384	F1:0.75307
# Opinion term	P:0.65946	R:0.78205	F1:0.71554
# pair	P:0.57711	R:0.61053	F1:0.59335
#
# Epoch:41
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.78431	R:0.72508	F1:0.75353
# Opinion term	P:0.74922	R:0.76603	F1:0.75753
# pair	P:0.66000	R:0.52105	F1:0.58235
#
# Epoch:42
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.74230	R:0.80060	F1:0.77035
# Opinion term	P:0.72303	R:0.79487	F1:0.75725
# pair	P:0.61127	R:0.57105	F1:0.59048
#
# Epoch:43
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.77143	R:0.81571	F1:0.79295
# Opinion term	P:0.71976	R:0.78205	F1:0.74962
# pair	P:0.64571	R:0.59474	F1:0.61918
#
# Epoch:44
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.72703	R:0.83686	F1:0.77809
# Opinion term	P:0.71060	R:0.79487	F1:0.75038
# pair	P:0.63043	R:0.61053	F1:0.62032
#
# Epoch:45
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.77681	R:0.80967	F1:0.79290
# Opinion term	P:0.74085	R:0.77885	F1:0.75938
# pair	P:0.66374	R:0.59737	F1:0.62881
#
# Epoch:46
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.70000	R:0.86707	F1:0.77463
# Opinion term	P:0.72372	R:0.77244	F1:0.74729
# pair	P:0.62778	R:0.59474	F1:0.61081
#
# Epoch:47
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.78042	R:0.79456	F1:0.78743
# Opinion term	P:0.70520	R:0.78205	F1:0.74164
# pair	P:0.62466	R:0.60000	F1:0.61208
#
# Epoch:48
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.69975	R:0.85196	F1:0.76839
# Opinion term	P:0.68232	R:0.79167	F1:0.73294
# pair	P:0.58987	R:0.61316	F1:0.60129
#
# Epoch:49
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76033	R:0.83384	F1:0.79539
# Opinion term	P:0.68362	R:0.77564	F1:0.72673
# pair	P:0.61394	R:0.60263	F1:0.60823
#
# Epoch:50
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76163	R:0.79154	F1:0.77630
# Opinion term	P:0.73585	R:0.75000	F1:0.74286
# pair	P:0.64387	R:0.59474	F1:0.61833
#
# Epoch:51
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76991	R:0.78852	F1:0.77910
# Opinion term	P:0.70175	R:0.76923	F1:0.73394
# pair	P:0.61828	R:0.60526	F1:0.61170
#
# Epoch:52
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76522	R:0.79758	F1:0.78107
# Opinion term	P:0.69942	R:0.77564	F1:0.73556
# pair	P:0.61622	R:0.60000	F1:0.60800
#
# Epoch:53
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.78042	R:0.79456	F1:0.78743
# Opinion term	P:0.77258	R:0.74038	F1:0.75614
# pair	P:0.68339	R:0.57368	F1:0.62375
#
# Epoch:54
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.78221	R:0.77039	F1:0.77626
# Opinion term	P:0.73520	R:0.75641	F1:0.74566
# pair	P:0.64553	R:0.58947	F1:0.61623
#
# Epoch:55
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76638	R:0.81269	F1:0.78886
# Opinion term	P:0.72107	R:0.77885	F1:0.74884
# pair	P:0.63661	R:0.61316	F1:0.62466
#
# Epoch:56
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.73224	R:0.80967	F1:0.76901
# Opinion term	P:0.72561	R:0.76282	F1:0.74375
# pair	P:0.62022	R:0.59737	F1:0.60858
#
# Epoch:57
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76232	R:0.79456	F1:0.77811
# Opinion term	P:0.72871	R:0.74038	F1:0.73450
# pair	P:0.62327	R:0.59211	F1:0.60729
#
# Epoch:58
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76488	R:0.77644	F1:0.77061
# Opinion term	P:0.77815	R:0.75321	F1:0.76547
# pair	P:0.65957	R:0.57105	F1:0.61213
#
# Epoch:59
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76724	R:0.80665	F1:0.78645
# Opinion term	P:0.71069	R:0.72436	F1:0.71746
# pair	P:0.65000	R:0.54737	F1:0.59429
#
# Epoch:60
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.77941	R:0.80060	F1:0.78987
# Opinion term	P:0.69795	R:0.76282	F1:0.72894
# pair	P:0.64912	R:0.58421	F1:0.61496
#
# Epoch:61
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76301	R:0.79758	F1:0.77991
# Opinion term	P:0.71513	R:0.77244	F1:0.74268
# pair	P:0.65318	R:0.59474	F1:0.62259
#
# Epoch:62
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76771	R:0.81873	F1:0.79240
# Opinion term	P:0.70349	R:0.77564	F1:0.73780
# pair	P:0.62169	R:0.61842	F1:0.62005
#
# Epoch:63
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.75414	R:0.82477	F1:0.78788
# Opinion term	P:0.69275	R:0.76603	F1:0.72755
# pair	P:0.60055	R:0.57368	F1:0.58681
#
# Epoch:64
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.71717	R:0.85801	F1:0.78129
# Opinion term	P:0.69492	R:0.78846	F1:0.73874
# pair	P:0.60652	R:0.63684	F1:0.62131
#
# Epoch:65
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.75581	R:0.78550	F1:0.77037
# Opinion term	P:0.68182	R:0.76923	F1:0.72289
# pair	P:0.61318	R:0.56316	F1:0.58711
#
# Epoch:66
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.75207	R:0.82477	F1:0.78674
# Opinion term	P:0.68376	R:0.76923	F1:0.72398
# pair	P:0.61757	R:0.62895	F1:0.62321
#
# Epoch:67
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.75358	R:0.79456	F1:0.77353
# Opinion term	P:0.71772	R:0.76603	F1:0.74109
# pair	P:0.60811	R:0.59211	F1:0.60000
#
# Epoch:68
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.73829	R:0.80967	F1:0.77233
# Opinion term	P:0.69741	R:0.77564	F1:0.73445
# pair	P:0.61299	R:0.62105	F1:0.61699
#
# Epoch:69
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76081	R:0.79758	F1:0.77876
# Opinion term	P:0.70501	R:0.76603	F1:0.73425
# pair	P:0.61257	R:0.61579	F1:0.61417
#
# Epoch:70
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76970	R:0.76737	F1:0.76853
# Opinion term	P:0.68696	R:0.75962	F1:0.72146
# pair	P:0.61473	R:0.57105	F1:0.59209
#
# Epoch:71
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.75224	R:0.76133	F1:0.75676
# Opinion term	P:0.69162	R:0.74038	F1:0.71517
# pair	P:0.63422	R:0.56579	F1:0.59805
#
# Epoch:72
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.69576	R:0.84290	F1:0.76230
# Opinion term	P:0.72347	R:0.72115	F1:0.72231
# pair	P:0.62985	R:0.55526	F1:0.59021
#
# Epoch:73
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.75000	R:0.84290	F1:0.79374
# Opinion term	P:0.68539	R:0.78205	F1:0.73054
# pair	P:0.59045	R:0.61842	F1:0.60411
#
# Epoch:74
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76731	R:0.83686	F1:0.80058
# Opinion term	P:0.71429	R:0.75321	F1:0.73323
# pair	P:0.63102	R:0.62105	F1:0.62599
#
# Epoch:75
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76608	R:0.79154	F1:0.77860
# Opinion term	P:0.75399	R:0.75641	F1:0.75520
# pair	P:0.63559	R:0.59211	F1:0.61308
#
# Epoch:76
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.75482	R:0.82779	F1:0.78963
# Opinion term	P:0.71681	R:0.77885	F1:0.74654
# pair	P:0.58647	R:0.61579	F1:0.60077
#
# Epoch:77
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.74860	R:0.80967	F1:0.77794
# Opinion term	P:0.72590	R:0.77244	F1:0.74845
# pair	P:0.60156	R:0.60789	F1:0.60471
#
# Epoch:78
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.73118	R:0.82175	F1:0.77383
# Opinion term	P:0.69492	R:0.78846	F1:0.73874
# pair	P:0.56731	R:0.62105	F1:0.59296
#
# Epoch:79
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.75910	R:0.81873	F1:0.78779
# Opinion term	P:0.70845	R:0.77885	F1:0.74198
# pair	P:0.59398	R:0.62368	F1:0.60847
#
# Epoch:80
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.79225	R:0.67976	F1:0.73171
# Opinion term	P:0.74919	R:0.73718	F1:0.74313
# pair	P:0.66340	R:0.53421	F1:0.59184
#
# Epoch:81
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.77326	R:0.80363	F1:0.78815
# Opinion term	P:0.72524	R:0.72756	F1:0.72640
# pair	P:0.62674	R:0.59211	F1:0.60893
#
# Epoch:82
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.70000	R:0.86707	F1:0.77463
# Opinion term	P:0.64948	R:0.80769	F1:0.72000
# pair	P:0.51318	R:0.66579	F1:0.57961
#
# Epoch:83
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76571	R:0.80967	F1:0.78708
# Opinion term	P:0.70857	R:0.79487	F1:0.74924
# pair	P:0.59250	R:0.62368	F1:0.60769
#
# Epoch:84
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.78299	R:0.80665	F1:0.79464
# Opinion term	P:0.71598	R:0.77564	F1:0.74462
# pair	P:0.62632	R:0.62632	F1:0.62632
#
# Epoch:85
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.77950	R:0.75831	F1:0.76876
# Opinion term	P:0.73355	R:0.71474	F1:0.72403
# pair	P:0.64396	R:0.54737	F1:0.59175
#
# Epoch:86
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76751	R:0.82779	F1:0.79651
# Opinion term	P:0.65854	R:0.77885	F1:0.71366
# pair	P:0.59305	R:0.62895	F1:0.61047
#
# Epoch:87
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76554	R:0.81873	F1:0.79124
# Opinion term	P:0.69341	R:0.77564	F1:0.73222
# pair	P:0.60406	R:0.62632	F1:0.61499
#
# Epoch:88
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.74862	R:0.81873	F1:0.78211
# Opinion term	P:0.66935	R:0.79808	F1:0.72807
# pair	P:0.60582	R:0.60263	F1:0.60422
#
# Epoch:89
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.75510	R:0.78248	F1:0.76855
# Opinion term	P:0.70029	R:0.77885	F1:0.73748
# pair	P:0.60590	R:0.59474	F1:0.60027
#
# Epoch:90
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.73626	R:0.80967	F1:0.77122
# Opinion term	P:0.66146	R:0.81410	F1:0.72989
# pair	P:0.59591	R:0.61316	F1:0.60441
#
# Epoch:91
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.76316	R:0.78852	F1:0.77563
# Opinion term	P:0.69034	R:0.77885	F1:0.73193
# pair	P:0.60158	R:0.60000	F1:0.60079
#
# Epoch:92
# 100% 113/113 [00:32<00:00,  3.47it/s]
# Aspect term	P:0.78182	R:0.77946	F1:0.78064
# Opinion term	P:0.67049	R:0.75000	F1:0.70802
# pair	P:0.60773	R:0.57895	F1:0.59299
#
# Epoch:93
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.77337	R:0.82477	F1:0.79825
# Opinion term	P:0.66575	R:0.77244	F1:0.71513
# pair	P:0.60677	R:0.61316	F1:0.60995
#
# Epoch:94
# 100% 113/113 [00:32<00:00,  3.48it/s]
# Aspect term	P:0.77448	R:0.78852	F1:0.78144
# Opinion term	P:0.68362	R:0.77564	F1:0.72673
# pair	P:0.63085	R:0.60263	F1:0.61642
#
# Epoch:95
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.76744	R:0.79758	F1:0.78222
# Opinion term	P:0.70760	R:0.77564	F1:0.74006
# pair	P:0.62707	R:0.59737	F1:0.61186
#
# Epoch:96
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.73370	R:0.81571	F1:0.77253
# Opinion term	P:0.67204	R:0.80128	F1:0.73099
# pair	P:0.55196	R:0.62895	F1:0.58795
#
# Epoch:97
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.74054	R:0.82779	F1:0.78174
# Opinion term	P:0.70060	R:0.75000	F1:0.72446
# pair	P:0.60270	R:0.58684	F1:0.59467
#
# Epoch:98
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.71429	R:0.83082	F1:0.76816
# Opinion term	P:0.67313	R:0.77885	F1:0.72214
# pair	P:0.55990	R:0.60263	F1:0.58048
#
# Epoch:99
# 100% 113/113 [00:32<00:00,  3.46it/s]
# Aspect term	P:0.73529	R:0.83082	F1:0.78014
# Opinion term	P:0.71473	R:0.73077	F1:0.72266
# pair	P:0.60270	R:0.58684	F1:0.59467
#
# best epoch: 31	best dev pair f1: 0.64384
#
#
# Evaluation on testset:
# Aspect term	P:0.78586	R:0.83298	F1:0.80873
# Opinion term	P:0.75432	R:0.82563	F1:0.78837
# pair	P:0.68288	R:0.64404	F1:0.66289

# %%
# !python main.py --task triplet --mode train --dataset lap14
# Out:
# 2021-08-10 18:21:05.737601: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Epoch:0
# 100% 113/113 [00:33<00:00,  3.39it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 113/113 [00:33<00:00,  3.38it/s]
# Aspect term	P:0.79882	R:0.40785	F1:0.54000
# Opinion term	P:0.91667	R:0.10577	F1:0.18966
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 113/113 [00:33<00:00,  3.38it/s]
# Aspect term	P:0.80176	R:0.54985	F1:0.65233
# Opinion term	P:0.75000	R:0.50962	F1:0.60687
# triplet	P:0.92308	R:0.03158	F1:0.06107
#
# Epoch:3
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.68322	R:0.87311	F1:0.76658
# Opinion term	P:0.69253	R:0.77244	F1:0.73030
# triplet	P:0.57947	R:0.46053	F1:0.51320
#
# Epoch:4
# 100% 113/113 [00:33<00:00,  3.38it/s]
# Aspect term	P:0.77199	R:0.71601	F1:0.74295
# Opinion term	P:0.80377	R:0.68269	F1:0.73830
# triplet	P:0.70482	R:0.30789	F1:0.42857
#
# Epoch:5
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76580	R:0.62236	F1:0.68667
# Opinion term	P:0.75254	R:0.71154	F1:0.73147
# triplet	P:0.65161	R:0.26579	F1:0.37757
#
# Epoch:6
# 100% 113/113 [00:33<00:00,  3.38it/s]
# Aspect term	P:0.79365	R:0.75529	F1:0.77399
# Opinion term	P:0.69298	R:0.75962	F1:0.72477
# triplet	P:0.62030	R:0.43421	F1:0.51084
#
# Epoch:7
# 100% 113/113 [00:33<00:00,  3.38it/s]
# Aspect term	P:0.75900	R:0.82779	F1:0.79191
# Opinion term	P:0.71386	R:0.77564	F1:0.74347
# triplet	P:0.61290	R:0.50000	F1:0.55072
#
# Epoch:8
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73936	R:0.83988	F1:0.78642
# Opinion term	P:0.73353	R:0.78526	F1:0.75851
# triplet	P:0.61592	R:0.46842	F1:0.53214
#
# Epoch:9
# 100% 113/113 [00:33<00:00,  3.38it/s]
# Aspect term	P:0.70792	R:0.86405	F1:0.77823
# Opinion term	P:0.68785	R:0.79808	F1:0.73887
# triplet	P:0.56637	R:0.50526	F1:0.53408
#
# Epoch:10
# 100% 113/113 [00:33<00:00,  3.38it/s]
# Aspect term	P:0.75623	R:0.82477	F1:0.78902
# Opinion term	P:0.69405	R:0.78526	F1:0.73684
# triplet	P:0.59119	R:0.49474	F1:0.53868
#
# Epoch:11
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.75793	R:0.79456	F1:0.77581
# Opinion term	P:0.68056	R:0.78526	F1:0.72917
# triplet	P:0.57669	R:0.49474	F1:0.53258
#
# Epoch:12
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77419	R:0.79758	F1:0.78571
# Opinion term	P:0.72537	R:0.77885	F1:0.75116
# triplet	P:0.61386	R:0.48947	F1:0.54466
#
# Epoch:13
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76970	R:0.76737	F1:0.76853
# Opinion term	P:0.71221	R:0.78526	F1:0.74695
# triplet	P:0.62701	R:0.51316	F1:0.56440
#
# Epoch:14
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73352	R:0.80665	F1:0.76835
# Opinion term	P:0.72973	R:0.77885	F1:0.75349
# triplet	P:0.60066	R:0.47895	F1:0.53294
#
# Epoch:15
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73714	R:0.77946	F1:0.75771
# Opinion term	P:0.76012	R:0.78205	F1:0.77093
# triplet	P:0.61076	R:0.50789	F1:0.55460
#
# Epoch:16
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77108	R:0.77341	F1:0.77225
# Opinion term	P:0.72515	R:0.79487	F1:0.75841
# triplet	P:0.60625	R:0.51053	F1:0.55429
#
# Epoch:17
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76364	R:0.76133	F1:0.76248
# Opinion term	P:0.66489	R:0.80128	F1:0.72674
# triplet	P:0.52279	R:0.51316	F1:0.51793
#
# Epoch:18
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73901	R:0.81269	F1:0.77410
# Opinion term	P:0.76562	R:0.78526	F1:0.77532
# triplet	P:0.66118	R:0.52895	F1:0.58772
#
# Epoch:19
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77508	R:0.77039	F1:0.77273
# Opinion term	P:0.77558	R:0.75321	F1:0.76423
# triplet	P:0.67029	R:0.48684	F1:0.56402
#
# Epoch:20
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76857	R:0.81269	F1:0.79001
# Opinion term	P:0.73214	R:0.78846	F1:0.75926
# triplet	P:0.61631	R:0.53684	F1:0.57384
#
# Epoch:21
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76000	R:0.80363	F1:0.78120
# Opinion term	P:0.72965	R:0.80449	F1:0.76524
# triplet	P:0.59412	R:0.53158	F1:0.56111
#
# Epoch:22
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.72105	R:0.82779	F1:0.77075
# Opinion term	P:0.66071	R:0.83013	F1:0.73580
# triplet	P:0.53056	R:0.57105	F1:0.55006
#
# Epoch:23
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73262	R:0.82779	F1:0.77730
# Opinion term	P:0.62972	R:0.80128	F1:0.70522
# triplet	P:0.50363	R:0.54737	F1:0.52459
#
# Epoch:24
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.71618	R:0.81571	F1:0.76271
# Opinion term	P:0.69516	R:0.78205	F1:0.73605
# triplet	P:0.54918	R:0.52895	F1:0.53887
#
# Epoch:25
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.75821	R:0.76737	F1:0.76276
# Opinion term	P:0.76066	R:0.74359	F1:0.75203
# triplet	P:0.58900	R:0.47895	F1:0.52830
#
# Epoch:26
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76488	R:0.77644	F1:0.77061
# Opinion term	P:0.63317	R:0.80769	F1:0.70986
# triplet	P:0.58514	R:0.49737	F1:0.53770
#
# Epoch:27
# 100% 113/113 [00:33<00:00,  3.38it/s]
# Aspect term	P:0.72289	R:0.72508	F1:0.72398
# Opinion term	P:0.70774	R:0.79167	F1:0.74735
# triplet	P:0.55709	R:0.42368	F1:0.48132
#
# Epoch:28
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73829	R:0.80967	F1:0.77233
# Opinion term	P:0.74636	R:0.82051	F1:0.78168
# triplet	P:0.57835	R:0.53421	F1:0.55540
#
# Epoch:29
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.67536	R:0.86103	F1:0.75697
# Opinion term	P:0.68901	R:0.82372	F1:0.75036
# triplet	P:0.54377	R:0.53947	F1:0.54161
#
# Epoch:30
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74576	R:0.79758	F1:0.77080
# Opinion term	P:0.74030	R:0.79487	F1:0.76662
# triplet	P:0.57567	R:0.51053	F1:0.54114
#
# Epoch:31
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.75575	R:0.79456	F1:0.77467
# Opinion term	P:0.72254	R:0.80128	F1:0.75988
# triplet	P:0.59130	R:0.53684	F1:0.56276
#
# Epoch:32
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77612	R:0.78550	F1:0.78078
# Opinion term	P:0.73939	R:0.78205	F1:0.76012
# triplet	P:0.59036	R:0.51579	F1:0.55056
#
# Epoch:33
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73387	R:0.82477	F1:0.77667
# Opinion term	P:0.73887	R:0.79808	F1:0.76733
# triplet	P:0.59249	R:0.53947	F1:0.56474
#
# Epoch:34
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74561	R:0.77039	F1:0.75780
# Opinion term	P:0.75298	R:0.81090	F1:0.78086
# triplet	P:0.60060	R:0.52632	F1:0.56101
#
# Epoch:35
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73280	R:0.83686	F1:0.78138
# Opinion term	P:0.73099	R:0.80128	F1:0.76453
# triplet	P:0.55707	R:0.53947	F1:0.54813
#
# Epoch:36
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77326	R:0.80363	F1:0.78815
# Opinion term	P:0.78135	R:0.77885	F1:0.78010
# triplet	P:0.61610	R:0.52368	F1:0.56615
#
# Epoch:37
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74044	R:0.81873	F1:0.77762
# Opinion term	P:0.75949	R:0.76923	F1:0.76433
# triplet	P:0.58065	R:0.52105	F1:0.54924
#
# Epoch:38
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.70677	R:0.85196	F1:0.77260
# Opinion term	P:0.68044	R:0.79167	F1:0.73185
# triplet	P:0.56325	R:0.49211	F1:0.52528
#
# Epoch:39
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76190	R:0.82175	F1:0.79070
# Opinion term	P:0.72464	R:0.80128	F1:0.76104
# triplet	P:0.56464	R:0.56316	F1:0.56390
#
# Epoch:40
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77493	R:0.82175	F1:0.79765
# Opinion term	P:0.73353	R:0.78526	F1:0.75851
# triplet	P:0.58028	R:0.54211	F1:0.56054
#
# Epoch:41
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76257	R:0.82477	F1:0.79245
# Opinion term	P:0.74699	R:0.79487	F1:0.77019
# triplet	P:0.56983	R:0.53684	F1:0.55285
#
# Epoch:42
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.80000	R:0.80967	F1:0.80480
# Opinion term	P:0.72271	R:0.78526	F1:0.75269
# triplet	P:0.59760	R:0.52368	F1:0.55820
#
# Epoch:43
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.78286	R:0.82779	F1:0.80470
# Opinion term	P:0.72549	R:0.83013	F1:0.77429
# triplet	P:0.58065	R:0.56842	F1:0.57447
#
# Epoch:44
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76901	R:0.82477	F1:0.79592
# Opinion term	P:0.72905	R:0.83654	F1:0.77910
# triplet	P:0.55297	R:0.56316	F1:0.55802
#
# Epoch:45
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74263	R:0.83686	F1:0.78693
# Opinion term	P:0.71823	R:0.83333	F1:0.77151
# triplet	P:0.57867	R:0.57105	F1:0.57483
#
# Epoch:46
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77586	R:0.81571	F1:0.79529
# Opinion term	P:0.72099	R:0.83654	F1:0.77448
# triplet	P:0.60167	R:0.56842	F1:0.58457
#
# Epoch:47
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77946	R:0.77946	F1:0.77946
# Opinion term	P:0.76825	R:0.77564	F1:0.77193
# triplet	P:0.64263	R:0.53947	F1:0.58655
#
# Epoch:48
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.75562	R:0.81269	F1:0.78311
# Opinion term	P:0.77199	R:0.75962	F1:0.76575
# triplet	P:0.60767	R:0.54211	F1:0.57302
#
# Epoch:49
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77143	R:0.81571	F1:0.79295
# Opinion term	P:0.76190	R:0.76923	F1:0.76555
# triplet	P:0.61224	R:0.55263	F1:0.58091
#
# Epoch:50
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.79808	R:0.75227	F1:0.77449
# Opinion term	P:0.82264	R:0.69872	F1:0.75563
# triplet	P:0.67669	R:0.47368	F1:0.55728
#
# Epoch:51
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.71253	R:0.87613	F1:0.78591
# Opinion term	P:0.70670	R:0.81090	F1:0.75522
# triplet	P:0.56836	R:0.55789	F1:0.56308
#
# Epoch:52
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.71503	R:0.83384	F1:0.76987
# Opinion term	P:0.69359	R:0.79808	F1:0.74218
# triplet	P:0.61111	R:0.55000	F1:0.57895
#
# Epoch:53
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77231	R:0.75831	F1:0.76524
# Opinion term	P:0.74312	R:0.77885	F1:0.76056
# triplet	P:0.60681	R:0.51579	F1:0.55761
#
# Epoch:54
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.72296	R:0.82779	F1:0.77183
# Opinion term	P:0.75472	R:0.76923	F1:0.76190
# triplet	P:0.59306	R:0.49474	F1:0.53945
#
# Epoch:55
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.78963	R:0.78248	F1:0.78604
# Opinion term	P:0.79211	R:0.70833	F1:0.74788
# triplet	P:0.63265	R:0.48947	F1:0.55193
#
# Epoch:56
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74247	R:0.81873	F1:0.77874
# Opinion term	P:0.72647	R:0.79167	F1:0.75767
# triplet	P:0.56091	R:0.52105	F1:0.54025
#
# Epoch:57
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74317	R:0.82175	F1:0.78049
# Opinion term	P:0.72700	R:0.78526	F1:0.75501
# triplet	P:0.58333	R:0.53421	F1:0.55769
#
# Epoch:58
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76522	R:0.79758	F1:0.78107
# Opinion term	P:0.75076	R:0.79167	F1:0.77067
# triplet	P:0.55780	R:0.50789	F1:0.53168
#
# Epoch:59
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74862	R:0.81873	F1:0.78211
# Opinion term	P:0.68407	R:0.79808	F1:0.73669
# triplet	P:0.54278	R:0.53421	F1:0.53846
#
# Epoch:60
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.75581	R:0.78550	F1:0.77037
# Opinion term	P:0.73290	R:0.72115	F1:0.72698
# triplet	P:0.58013	R:0.47632	F1:0.52312
#
# Epoch:61
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76453	R:0.75529	F1:0.75988
# Opinion term	P:0.69540	R:0.77564	F1:0.73333
# triplet	P:0.59416	R:0.48158	F1:0.53198
#
# Epoch:62
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73797	R:0.83384	F1:0.78298
# Opinion term	P:0.72254	R:0.80128	F1:0.75988
# triplet	P:0.55956	R:0.53158	F1:0.54521
#
# Epoch:63
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.78193	R:0.75831	F1:0.76994
# Opinion term	P:0.74919	R:0.73718	F1:0.74313
# triplet	P:0.62376	R:0.49737	F1:0.55344
#
# Epoch:64
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.78078	R:0.78550	F1:0.78313
# Opinion term	P:0.71810	R:0.77564	F1:0.74576
# triplet	P:0.58453	R:0.53684	F1:0.55967
#
# Epoch:65
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74044	R:0.81873	F1:0.77762
# Opinion term	P:0.68548	R:0.81731	F1:0.74561
# triplet	P:0.53846	R:0.53421	F1:0.53633
#
# Epoch:66
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.75931	R:0.80060	F1:0.77941
# Opinion term	P:0.71554	R:0.78205	F1:0.74732
# triplet	P:0.58382	R:0.53158	F1:0.55647
#
# Epoch:67
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.79487	R:0.74924	F1:0.77138
# Opinion term	P:0.70360	R:0.81410	F1:0.75483
# triplet	P:0.59118	R:0.52895	F1:0.55833
#
# Epoch:68
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76765	R:0.78852	F1:0.77794
# Opinion term	P:0.75472	R:0.76923	F1:0.76190
# triplet	P:0.61231	R:0.52368	F1:0.56454
#
# Epoch:69
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74797	R:0.83384	F1:0.78857
# Opinion term	P:0.73214	R:0.78846	F1:0.75926
# triplet	P:0.58840	R:0.56053	F1:0.57412
#
# Epoch:70
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.77059	R:0.79154	F1:0.78092
# Opinion term	P:0.78947	R:0.76923	F1:0.77922
# triplet	P:0.65033	R:0.52368	F1:0.58017
#
# Epoch:71
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77882	R:0.75529	F1:0.76687
# Opinion term	P:0.76875	R:0.78846	F1:0.77848
# triplet	P:0.62763	R:0.55000	F1:0.58626
#
# Epoch:72
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.71939	R:0.85196	F1:0.78008
# Opinion term	P:0.72353	R:0.78846	F1:0.75460
# triplet	P:0.58793	R:0.58947	F1:0.58870
#
# Epoch:73
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76471	R:0.78550	F1:0.77496
# Opinion term	P:0.72171	R:0.75641	F1:0.73865
# triplet	P:0.60479	R:0.53158	F1:0.56583
#
# Epoch:74
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.75793	R:0.79456	F1:0.77581
# Opinion term	P:0.74922	R:0.76603	F1:0.75753
# triplet	P:0.58951	R:0.50263	F1:0.54261
#
# Epoch:75
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.78125	R:0.75529	F1:0.76805
# Opinion term	P:0.76768	R:0.73077	F1:0.74877
# triplet	P:0.63366	R:0.50526	F1:0.56223
#
# Epoch:76
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.65268	R:0.84592	F1:0.73684
# Opinion term	P:0.69369	R:0.74038	F1:0.71628
# triplet	P:0.50392	R:0.50789	F1:0.50590
#
# Epoch:77
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.72105	R:0.82779	F1:0.77075
# Opinion term	P:0.67945	R:0.79487	F1:0.73264
# triplet	P:0.50948	R:0.56579	F1:0.53616
#
# Epoch:78
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76968	R:0.79758	F1:0.78338
# Opinion term	P:0.72321	R:0.77885	F1:0.75000
# triplet	P:0.60237	R:0.53421	F1:0.56625
#
# Epoch:79
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77353	R:0.79456	F1:0.78390
# Opinion term	P:0.69492	R:0.78846	F1:0.73874
# triplet	P:0.56044	R:0.53684	F1:0.54839
#
# Epoch:80
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77313	R:0.78248	F1:0.77778
# Opinion term	P:0.74121	R:0.74359	F1:0.74240
# triplet	P:0.59940	R:0.52368	F1:0.55899
#
# Epoch:81
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.77946	R:0.77946	F1:0.77946
# Opinion term	P:0.69767	R:0.76923	F1:0.73171
# triplet	P:0.59375	R:0.55000	F1:0.57104
#
# Epoch:82
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.74260	R:0.75831	F1:0.75037
# Opinion term	P:0.74143	R:0.76282	F1:0.75197
# triplet	P:0.59292	R:0.52895	F1:0.55911
#
# Epoch:83
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.75074	R:0.76435	F1:0.75749
# Opinion term	P:0.74839	R:0.74359	F1:0.74598
# triplet	P:0.59531	R:0.53421	F1:0.56311
#
# Epoch:84
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76453	R:0.79456	F1:0.77926
# Opinion term	P:0.74233	R:0.77564	F1:0.75862
# triplet	P:0.59944	R:0.56316	F1:0.58073
#
# Epoch:85
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.76765	R:0.78852	F1:0.77794
# Opinion term	P:0.71733	R:0.75641	F1:0.73635
# triplet	P:0.58610	R:0.51053	F1:0.54571
#
# Epoch:86
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.76380	R:0.75227	F1:0.75799
# Opinion term	P:0.75159	R:0.75641	F1:0.75399
# triplet	P:0.59692	R:0.51053	F1:0.55035
#
# Epoch:87
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.77581	R:0.79456	F1:0.78507
# Opinion term	P:0.75710	R:0.76923	F1:0.76312
# triplet	P:0.59524	R:0.52632	F1:0.55866
#
# Epoch:88
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.72174	R:0.75227	F1:0.73669
# Opinion term	P:0.71471	R:0.77885	F1:0.74540
# triplet	P:0.56686	R:0.51316	F1:0.53867
#
# Epoch:89
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74925	R:0.75831	F1:0.75375
# Opinion term	P:0.74608	R:0.76282	F1:0.75436
# triplet	P:0.60417	R:0.53421	F1:0.56704
#
# Epoch:90
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73775	R:0.77341	F1:0.75516
# Opinion term	P:0.69577	R:0.79167	F1:0.74063
# triplet	P:0.56906	R:0.54211	F1:0.55526
#
# Epoch:91
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.75575	R:0.79456	F1:0.77467
# Opinion term	P:0.74687	R:0.76603	F1:0.75633
# triplet	P:0.56983	R:0.53684	F1:0.55285
#
# Epoch:92
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.76147	R:0.75227	F1:0.75684
# Opinion term	P:0.72810	R:0.77244	F1:0.74961
# triplet	P:0.56707	R:0.48947	F1:0.52542
#
# Epoch:93
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.75294	R:0.77341	F1:0.76304
# Opinion term	P:0.71221	R:0.78526	F1:0.74695
# triplet	P:0.55348	R:0.54474	F1:0.54907
#
# Epoch:94
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.75793	R:0.79456	F1:0.77581
# Opinion term	P:0.76038	R:0.76282	F1:0.76160
# triplet	P:0.57184	R:0.52368	F1:0.54670
#
# Epoch:95
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.73109	R:0.78852	F1:0.75872
# Opinion term	P:0.75649	R:0.74679	F1:0.75161
# triplet	P:0.56857	R:0.52368	F1:0.54521
#
# Epoch:96
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.74107	R:0.75227	F1:0.74663
# Opinion term	P:0.76510	R:0.73077	F1:0.74754
# triplet	P:0.61350	R:0.52632	F1:0.56657
#
# Epoch:97
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.73639	R:0.77644	F1:0.75588
# Opinion term	P:0.75079	R:0.76282	F1:0.75676
# triplet	P:0.56936	R:0.51842	F1:0.54270
#
# Epoch:98
# 100% 113/113 [00:33<00:00,  3.36it/s]
# Aspect term	P:0.73714	R:0.77946	F1:0.75771
# Opinion term	P:0.74684	R:0.75641	F1:0.75159
# triplet	P:0.56286	R:0.51842	F1:0.53973
#
# Epoch:99
# 100% 113/113 [00:33<00:00,  3.37it/s]
# Aspect term	P:0.73669	R:0.75227	F1:0.74439
# Opinion term	P:0.73585	R:0.75000	F1:0.74286
# triplet	P:0.59939	R:0.51579	F1:0.55446
#
# best epoch: 72	best dev triplet f1: 0.58870
#
#
# Evaluation on testset:
# Aspect term	P:0.73118	R:0.87366	F1:0.79610
# Opinion term	P:0.73524	R:0.81092	F1:0.77123
# triplet	P:0.55166	R:0.57798	F1:0.56452
