# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/GTS-main/code/NNModel
# Out:
# /content/drive/MyDrive/GTS-main/code/NNModel

# %%
# !python main.py --task pair --model bilstm --mode train --dataset res14
# Out:
# Epoch:0
# 100% 40/40 [00:00<00:00, 64.23it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 40/40 [00:00<00:00, 89.22it/s]
# Aspect term	P:0.18182	R:0.01646	F1:0.03019
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 40/40 [00:00<00:00, 91.59it/s]
# Aspect term	P:0.36842	R:0.04321	F1:0.07735
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 40/40 [00:00<00:00, 90.55it/s]
# Aspect term	P:0.54545	R:0.12346	F1:0.20134
# Opinion term	P:0.87179	R:0.06869	F1:0.12734
# pair	P:0.20000	R:0.00176	F1:0.00348
#
# Epoch:4
# 100% 40/40 [00:00<00:00, 91.21it/s]
# Aspect term	P:0.61905	R:0.24074	F1:0.34667
# Opinion term	P:0.83178	R:0.17980	F1:0.29568
# pair	P:0.38462	R:0.00879	F1:0.01718
#
# Epoch:5
# 100% 40/40 [00:00<00:00, 88.73it/s]
# Aspect term	P:0.68724	R:0.34362	F1:0.45816
# ...

# %%
# !python main.py --task pair --model bilstm --mode train --dataset lap14
# Out:
# Epoch:0
# 100% 29/29 [00:00<00:00, 63.50it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 29/29 [00:00<00:00, 78.37it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 29/29 [00:00<00:00, 76.72it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 29/29 [00:00<00:00, 79.96it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 29/29 [00:00<00:00, 79.32it/s]
# Aspect term	P:0.50000	R:0.00302	F1:0.00601
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 29/29 [00:00<00:00, 76.70it/s]
# Aspect term	P:0.40541	R:0.04532	F1:0.08152
# ...

# %%
# !python main.py --task pair --model bilstm --mode train --dataset res15
# Out:
# Epoch:0
# 100% 19/19 [00:00<00:00, 75.79it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 19/19 [00:00<00:00, 87.75it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 19/19 [00:00<00:00, 93.07it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 19/19 [00:00<00:00, 96.30it/s]
# Aspect term	P:0.35714	R:0.02439	F1:0.04566
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 19/19 [00:00<00:00, 96.17it/s]
# Aspect term	P:0.56250	R:0.08780	F1:0.15190
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 19/19 [00:00<00:00, 92.13it/s]
# Aspect term	P:0.67568	R:0.12195	F1:0.20661
# ...

# %%
# !python main.py --task pair --model bilstm --mode train --dataset res16
# Out:
# Epoch:0
# 100% 27/27 [00:00<00:00, 72.54it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 27/27 [00:00<00:00, 85.77it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 27/27 [00:00<00:00, 84.35it/s]
# Aspect term	P:0.35417	R:0.05705	F1:0.09827
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 27/27 [00:00<00:00, 90.93it/s]
# Aspect term	P:0.59184	R:0.19463	F1:0.29293
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 27/27 [00:00<00:00, 89.46it/s]
# Aspect term	P:0.56557	R:0.23154	F1:0.32857
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 27/27 [00:00<00:00, 90.50it/s]
# Aspect term	P:0.61481	R:0.27852	F1:0.38337
# ...

# %%
# !python main.py --task triplet --model bilstm --mode train --dataset res14
# Out:
# Epoch:0
# 100% 40/40 [00:00<00:00, 79.28it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 40/40 [00:00<00:00, 90.61it/s]
# Aspect term	P:0.38889	R:0.01440	F1:0.02778
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 40/40 [00:00<00:00, 83.88it/s]
# Aspect term	P:0.50000	R:0.07407	F1:0.12903
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 40/40 [00:00<00:00, 84.97it/s]
# Aspect term	P:0.58333	R:0.14403	F1:0.23102
# Opinion term	P:1.00000	R:0.01010	F1:0.02000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 40/40 [00:00<00:00, 90.15it/s]
# Aspect term	P:0.60965	R:0.28601	F1:0.38936
# Opinion term	P:0.86022	R:0.16162	F1:0.27211
# triplet	P:1.00000	R:0.00176	F1:0.00351
#
# Epoch:5
# 100% 40/40 [00:00<00:00, 90.11it/s]
# ...

# %%
# !python main.py --task triplet --model bilstm --mode train --dataset lap14
# Out:
# Epoch:0
# 100% 29/29 [00:00<00:00, 62.75it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 29/29 [00:00<00:00, 74.73it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 29/29 [00:00<00:00, 78.21it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 29/29 [00:00<00:00, 78.91it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 29/29 [00:00<00:00, 77.23it/s]
# Aspect term	P:0.42857	R:0.00906	F1:0.01775
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 29/29 [00:00<00:00, 78.83it/s]
# ...

# %%
# !python main.py --task triplet --model bilstm --mode train --dataset res15
# Out:
# Epoch:0
# 100% 19/19 [00:00<00:00, 77.97it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 19/19 [00:00<00:00, 84.66it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 19/19 [00:00<00:00, 88.55it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 19/19 [00:00<00:00, 89.88it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 19/19 [00:00<00:00, 93.86it/s]
# Aspect term	P:0.41176	R:0.03415	F1:0.06306
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 19/19 [00:00<00:00, 94.21it/s]
# ...

# %%
# !python main.py --task triplet --model bilstm --mode train --dataset res16
# Out:
# Epoch:0
# 100% 27/27 [00:00<00:00, 73.09it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 27/27 [00:00<00:00, 83.72it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 27/27 [00:00<00:00, 89.14it/s]
# Aspect term	P:0.40426	R:0.06376	F1:0.11014
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 27/27 [00:00<00:00, 88.82it/s]
# Aspect term	P:0.49451	R:0.15101	F1:0.23136
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 27/27 [00:00<00:00, 88.93it/s]
# Aspect term	P:0.56881	R:0.20805	F1:0.30467
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 27/27 [00:00<00:00, 90.76it/s]
# ...
