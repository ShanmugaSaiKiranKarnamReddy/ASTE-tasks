# %%
pwd
# Out:
# '/content'

# %%
cd //content/drive/MyDrive/GTS-main/code/NNModel/
# Out:
# /content/drive/MyDrive/GTS-main/code/NNModel

# %%
# !python main.py --task pair --model cnn --mode train --dataset res14
# Out:
# Streaming output truncated to the last 5000 lines.
# [[1, 4, 16, 16], [7, 9, 16, 16], [13, 13, 16, 16]]
# [[13, 13, 16, 16]]
# [[4, 4, 6, 7]]
# [[1, 1, 7, 7], [3, 4, 7, 7], [3, 4, 9, 9]]
# [[5, 7, 11, 11]]
# [[5, 7, 11, 11]]
# [[3, 3, 10, 10], [6, 6, 10, 10], [13, 13, 15, 15]]
# [[3, 3, 10, 10], [6, 6, 10, 10], [13, 13, 10, 10], [13, 13, 15, 15]]
# [[4, 5, 2, 2]]
# [[4, 5, 2, 2], [12, 14, 2, 2]]
# [[1, 2, 0, 0]]
# [[1, 2, 0, 0]]
# [[13, 13, 12, 12]]
# [[10, 10, 9, 9], [13, 13, 9, 9], [13, 13, 12, 12]]
# [[1, 1, 2, 3], [6, 7, 10, 10]]
# [[1, 2, 3, 3], [6, 7, 10, 10]]
# [[2, 4, 9, 9]]
# [[2, 4, 8, 9]]
# [[3, 3, 8, 8]]
# [[3, 3, 8, 8]]
# [[1, 1, 3, 3]]
# [[1, 1, 3, 3]]
# [[1, 2, 4, 4], [1, 2, 7, 8]]
# [[1, 2, 4, 4], [1, 2, 7, 8]]
# [[4, 5, 0, 0], [4, 5, 2, 2], [8, 8, 7, 7]]
# [[4, 5, 2, 2], [8, 8, 7, 7]]
# [[3, 3, 5, 5]]
# [[3, 3, 5, 5], [3, 3, 7, 7]]
# [[4, 5, 3, 3], [7, 7, 3, 3]]
# []
# [[3, 3, 2, 2]]
# []
# [[0, 0, 2, 3]]
# [[0, 0, 4, 4]]
# [[1, 1, 0, 0]]
# [[1, 1, 0, 0]]
# ...

# %%
# !python main.py --task pair --model cnn --mode train --dataset lap14
# Out:
# Epoch:0
# 100% 29/29 [00:00<00:00, 44.85it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 29/29 [00:00<00:00, 54.22it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 29/29 [00:00<00:00, 54.46it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 29/29 [00:00<00:00, 54.51it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 29/29 [00:00<00:00, 54.58it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 29/29 [00:00<00:00, 54.27it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# ...

# %%
# !python main.py --task pair --model cnn --mode train --dataset res15
# Out:
# Epoch:0
# 100% 19/19 [00:00<00:00, 49.56it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 19/19 [00:00<00:00, 66.19it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 19/19 [00:00<00:00, 66.50it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 19/19 [00:00<00:00, 66.49it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 19/19 [00:00<00:00, 66.44it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 19/19 [00:00<00:00, 66.83it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# ...

# %%
# !python main.py --task pair --model cnn --mode train --dataset res16
# Out:
# Epoch:0
# 100% 27/27 [00:00<00:00, 48.69it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 27/27 [00:00<00:00, 63.08it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 27/27 [00:00<00:00, 63.11it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 27/27 [00:00<00:00, 63.01it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 27/27 [00:00<00:00, 62.89it/s]
# Aspect term	P:0.50000	R:0.00671	F1:0.01325
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# pair	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 27/27 [00:00<00:00, 62.73it/s]
# Aspect term	P:0.73684	R:0.09396	F1:0.16667
# ...

# %%
# !python main.py --task triplet --model cnn --mode train --dataset res14
# Out:
# Epoch:0
# 100% 40/40 [00:00<00:00, 53.38it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 40/40 [00:00<00:00, 62.15it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 40/40 [00:00<00:00, 62.45it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 40/40 [00:00<00:00, 62.18it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 40/40 [00:00<00:00, 62.33it/s]
# Aspect term	P:0.31250	R:0.04115	F1:0.07273
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 40/40 [00:00<00:00, 62.50it/s]
# ...

# %%
# !python main.py --task triplet --model cnn --mode train --dataset lap14
# Out:
# Epoch:0
# 100% 29/29 [00:00<00:00, 45.68it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 29/29 [00:00<00:00, 52.88it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 29/29 [00:00<00:00, 53.46it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 29/29 [00:00<00:00, 53.37it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 29/29 [00:00<00:00, 53.25it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 29/29 [00:00<00:00, 53.22it/s]
# ...

# %%
# !python main.py --task triplet --model cnn --mode train --dataset res15
# Out:
# Epoch:0
# 100% 19/19 [00:00<00:00, 49.81it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 19/19 [00:00<00:00, 65.33it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 19/19 [00:00<00:00, 65.86it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 19/19 [00:00<00:00, 66.08it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 19/19 [00:00<00:00, 65.48it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 19/19 [00:00<00:00, 65.85it/s]
# ...

# %%
# !python main.py --task triplet --model cnn --mode train --dataset res16
# Out:
# Epoch:0
# 100% 27/27 [00:00<00:00, 48.72it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:1
# 100% 27/27 [00:00<00:00, 62.34it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:2
# 100% 27/27 [00:00<00:00, 62.73it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:3
# 100% 27/27 [00:00<00:00, 63.00it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:4
# 100% 27/27 [00:00<00:00, 62.68it/s]
# Aspect term	P:0.00000	R:0.00000	F1:0.00000
# Opinion term	P:0.00000	R:0.00000	F1:0.00000
# triplet	P:0.00000	R:0.00000	F1:0.00000
#
# Epoch:5
# 100% 27/27 [00:00<00:00, 62.70it/s]
# ...
